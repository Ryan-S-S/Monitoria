# %%
# Importando as libs que iremos usar
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# ## DATASET
# - Importando o dataset que iremos usar

# %%
# Dataset Iris
from sklearn.datasets import load_iris

# Carrega o Dataset
input_data = load_iris()

print(f"Base de dados com {len(input_data['data'])} linhas")
# Out:
# Base de dados com 150 linhas

# %% [markdown]
# - Separa os dados e as labels

# %%
# Principio do Aprendizado de Maquina Supervisionado
data = input_data['data']
labels = input_data['target']

# %% [markdown]
# - Dividindo dados para o processo de *treino*, *teste* e *validação*

# %%
data_train, data_test, labels_train, labels_test = train_test_split(data, labels,
                                                                    test_size=0.2, 
                                                                    random_state=41)

data_train, data_validation, labels_train, labels_validation = train_test_split(data_train, labels_train,
                                                                                test_size=0.1,
                                                                                random_state=1)

print(f'Quantidade de Dados para Treinamento : {len(data_train)}')
print(f'Quantidade de Dados para Validação : {len(data_test)}')
print(f'Quantidade de Dados para Teste : {len(data_validation)}')
# Out:
# Quantidade de Dados para Treinamento : 108
# Quantidade de Dados para Validação : 30
# Quantidade de Dados para Teste : 12

# %%
# Construindo a classe que será usada pelo Torch para acessar o dataset
class DataSet(torch.utils.data.Dataset):
    def __init__(self,data,labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self,idx):
        return self.data[idx], self.labels[idx]

# %%
# Carregando nossos datasets de treino, teste e validação
dataset = DataSet(data_train,labels_train)
data_train = DataLoader(dataset, batch_size=32, shuffle=True, num_workers=0)

dataset = DataSet(data_validation,labels_validation)
data_validation = DataLoader(dataset, batch_size=len(data_validation), shuffle=True, num_workers=0)

dataset = DataSet(data_test,labels_test)
data_test = DataLoader(dataset, batch_size=len(data_test), shuffle=True, num_workers=0)

# %% [markdown]
# ## Modelo de Rede
# - 4 Entradas (4 Caracteristicas da Flor)
# - 2 CAMADAS de Neuronios ocultos
# - 3 Saídas (3 Rotulos de Flor)

# %%
class IrisClassifier(nn.Module) :
    def __init__(self, input_size = 4, 
                 hidden_size1=20, 
                 hidden_size2 = 10, 
                 output_size = 3) :
        
        super().__init__()
        # Camada de entrada --> Primeira camada oculta
        self.fc1 = nn.Linear(input_size, hidden_size1)
        # Primeira camada oculta --> Segunda camada oculta
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        # Segunda camada oculta --> Camada de saída
        self.output = nn.Linear(hidden_size2, output_size)
        # Função de ativação
        self.relu = nn.ReLU()

    # Fluxo dos dados da entrada para saída
    def forward(self, data) :
        data = self.relu(self.fc1(data))
        data = self.relu(self.fc2(data))
        data = self.output(data)
        return data

# %% [markdown]
# ## Instanciando e configurando a rede

# %%
net = IrisClassifier()
learning_rate = 0.01
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)

# %%
# Processo de treino
def train_one_epoch(model,loss_function,optimizer,data_train):
    model.train()
    current_loss = 0.0
    current_accuracy = 0.0
    total_samples = 0

    for i,data in enumerate(data_train):
        x,y = data
        x = x.to(torch.float)
        optimizer.zero_grad()
        output = model(x)
        loss = loss_function(output,y)
        loss.backward()
        optimizer.step()
        current_loss += loss.item()

        output = output.argmax(dim=1)
        batch_accuracy = torch.eq(output,y)
        batch_accuracy = batch_accuracy.sum()
        current_accuracy += batch_accuracy
        total_samples += len(x)
    return current_loss/(i+1), current_accuracy/total_samples

# %%
# Processo de validação
def validation_one_epoch(model,loss_function, data_validation):
    model.train(False)
    current_loss = 0.0
    current_accuracy = 0.0
    total_samples = 0
    for i,data in enumerate(data_validation):
        x,y = data
        x = x.to(torch.float)
        output = model(x)
        loss = loss_function(output,y)
        current_loss += loss.item()

        output = output.argmax(dim=1)
        batch_accuracy = torch.eq(output,y)
        batch_accuracy = batch_accuracy.sum()
        current_accuracy += batch_accuracy
        total_samples += len(x)
    return current_loss/(i+1), current_accuracy/total_samples

# %% [markdown]
# ## Executando

# %%
epochs = 100
train_loss_all_epoch = []
train_accuracy_all_epoch = []
val_loss_all_epoch = []
val_accuracy_all_epoch = []
best_val_loss = 1e9

for epoch in range(epochs):

    train_loss_per_epoch, train_accuracy_per_epoch = train_one_epoch(net,criterion,optimizer,data_train)

    train_loss_all_epoch.append(train_loss_per_epoch)
    train_accuracy_all_epoch.append(train_accuracy_per_epoch)

    val_loss_per_epoch,val_accuracy_per_epoch = validation_one_epoch(net,criterion, data_validation)

    val_loss_all_epoch.append(val_loss_per_epoch)
    val_accuracy_all_epoch.append(val_accuracy_per_epoch)

    # Salva o melhor modelo
    if val_loss_per_epoch < best_val_loss:
      best_val_loss = val_loss_per_epoch
      model_path = 'best_model_iris'
      torch.save(net.state_dict(),model_path)

    if(epoch % 1 == 0) :
      print(f'Epóca [: {epoch}]')
      print(f'Erro de Treinamento: {train_loss_per_epoch}')
      print(f'Erro de Validação: {val_loss_per_epoch}')
      print(f'Acurácia de Treinamento: {train_accuracy_per_epoch}')
      print(f'Acurácia de Validação: {val_accuracy_per_epoch}')
      print()
# Out:
# Epóca [: 0]
# Erro de Treinamento: 0.020950402016751468
# Erro de Validação: 0.0005115117528475821
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 1]
# Erro de Treinamento: 0.01319833769230172
# Erro de Validação: 0.0006293536280281842
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 2]
# Erro de Treinamento: 0.0257356968941167
# Erro de Validação: 0.0005006378632970154
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 3]
# Erro de Treinamento: 0.007782292959745973
# Erro de Validação: 0.0004868543765041977
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 4]
# Erro de Treinamento: 0.02535147788876202
# Erro de Validação: 0.0005019610980525613
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 5]
# Erro de Treinamento: 0.01600998468347825
# Erro de Validação: 0.0005222713225521147
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 6]
# Erro de Treinamento: 0.013150429251254536
# Erro de Validação: 0.00048247750964947045
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 7]
# Erro de Treinamento: 0.011922373494599015
# Erro de Validação: 0.0004782578907907009
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 8]
# Erro de Treinamento: 0.010523200515308417
# Erro de Validação: 0.00048453640192747116
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 9]
# Erro de Treinamento: 0.010267425896017812
# Erro de Validação: 0.00047414866276085377
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 10]
# Erro de Treinamento: 0.009451715319301002
# Erro de Validação: 0.00047089229337871075
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 11]
# Erro de Treinamento: 0.012688479153439403
# Erro de Validação: 0.00047257207916118205
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 12]
# Erro de Treinamento: 0.013500549248419702
# Erro de Validação: 0.00046047588693909347
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 13]
# Erro de Treinamento: 0.016548323910683393
# Erro de Validação: 0.00045423986739479005
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 14]
# Erro de Treinamento: 0.01032012673385907
# Erro de Validação: 0.0004689504858106375
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 15]
# Erro de Treinamento: 0.014608405530452728
# Erro de Validação: 0.00046657773782499135
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 16]
# Erro de Treinamento: 0.01038074484677054
# Erro de Validação: 0.00045045872684568167
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 17]
# Erro de Treinamento: 0.01606826092756819
# Erro de Validação: 0.00044556325883604586
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 18]
# Erro de Treinamento: 0.010947576723992825
# Erro de Validação: 0.0004941424704156816
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 19]
# Erro de Treinamento: 0.013546280591981485
# Erro de Validação: 0.0004639566468540579
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 20]
# Erro de Treinamento: 0.008405246131587774
# Erro de Validação: 0.00044353000703267753
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 21]
# Erro de Treinamento: 0.021902546694036573
# Erro de Validação: 0.0004440871998667717
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 22]
# Erro de Treinamento: 0.0163635083445115
# Erro de Validação: 0.0004864394722972065
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 23]
# Erro de Treinamento: 0.01227427685080329
# Erro de Validação: 0.00043924213969148695
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 24]
# Erro de Treinamento: 0.011300453130388632
# Erro de Validação: 0.00043753476347774267
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 25]
# Erro de Treinamento: 0.011323267099214718
# Erro de Validação: 0.00044613712816499174
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 26]
# Erro de Treinamento: 0.012098961393348873
# Erro de Validação: 0.00045237274025566876
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 27]
# Erro de Treinamento: 0.012794721027603373
# Erro de Validação: 0.00043588876724243164
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 28]
# Erro de Treinamento: 0.028090005711419508
# Erro de Validação: 0.0004420280165504664
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 29]
# Erro de Treinamento: 0.01794954208889976
# Erro de Validação: 0.000572867167647928
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 30]
# Erro de Treinamento: 0.022706709685735404
# Erro de Validação: 0.0004312031960580498
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 31]
# Erro de Treinamento: 0.01385970920091495
# Erro de Validação: 0.0004262284201104194
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 32]
# Erro de Treinamento: 0.01657394546782598
# Erro de Validação: 0.00043554548756219447
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 33]
# Erro de Treinamento: 0.018422093300614506
# Erro de Validação: 0.0004463426594156772
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 34]
# Erro de Treinamento: 0.014978189647081308
# Erro de Validação: 0.0004241153073962778
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 35]
# Erro de Treinamento: 0.025213563349097967
# Erro de Validação: 0.00043057207949459553
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 36]
# Erro de Treinamento: 0.007308574189664796
# Erro de Validação: 0.0006722099496982992
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 37]
# Erro de Treinamento: 0.03759603947401047
# Erro de Validação: 0.0004299477150198072
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 38]
# Erro de Treinamento: 0.009879061093670316
# Erro de Validação: 0.0004197586385998875
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 39]
# Erro de Treinamento: 0.030466070398688316
# Erro de Validação: 0.0004546098643913865
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 40]
# Erro de Treinamento: 0.0153433661616873
# Erro de Validação: 0.00043628690764307976
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 41]
# Erro de Treinamento: 0.01363225674140267
# Erro de Validação: 0.00042353454045951366
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 42]
# Erro de Treinamento: 0.010653021570760757
# Erro de Validação: 0.0004178545204922557
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 43]
# Erro de Treinamento: 0.014762366365175694
# Erro de Validação: 0.0004212321946397424
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 44]
# Erro de Treinamento: 0.02486525729909772
# Erro de Validação: 0.0004249659541528672
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 45]
# Erro de Treinamento: 0.007012021334958263
# Erro de Validação: 0.0004122159443795681
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 46]
# Erro de Treinamento: 0.021380473030149005
# Erro de Validação: 0.00042112547089345753
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 47]
# Erro de Treinamento: 0.008493374130921438
# Erro de Validação: 0.0004500751383602619
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 48]
# Erro de Treinamento: 0.012867051555076614
# Erro de Validação: 0.0004171741020400077
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 49]
# Erro de Treinamento: 0.012757517455611378
# Erro de Validação: 0.0004127153370063752
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 50]
# Erro de Treinamento: 0.015543996472842991
# Erro de Validação: 0.0004126565472688526
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 51]
# Erro de Treinamento: 0.01183248299639672
# Erro de Validação: 0.0004076119512319565
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 52]
# Erro de Treinamento: 0.008608902593550738
# Erro de Validação: 0.00042921691783703864
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 53]
# Erro de Treinamento: 0.009185750139295124
# Erro de Validação: 0.00042325290269218385
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 54]
# Erro de Treinamento: 0.008648164191981778
# Erro de Validação: 0.0004060946812387556
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 55]
# Erro de Treinamento: 0.011151441256515682
# Erro de Validação: 0.0004062146181240678
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 56]
# Erro de Treinamento: 0.011166550641064532
# Erro de Validação: 0.00040259011439047754
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 57]
# Erro de Treinamento: 0.009502825007075444
# Erro de Validação: 0.0004022730281576514
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 58]
# Erro de Treinamento: 0.011764984636101872
# Erro de Validação: 0.0004069122951477766
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 59]
# Erro de Treinamento: 0.016644363407976925
# Erro de Validação: 0.0004015594895463437
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 60]
# Erro de Treinamento: 0.013603113053250127
# Erro de Validação: 0.00039459788240492344
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 61]
# Erro de Treinamento: 0.012143511208705604
# Erro de Validação: 0.00041328780935145915
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 62]
# Erro de Treinamento: 0.021624309243634343
# Erro de Validação: 0.0004201596602797508
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 63]
# Erro de Treinamento: 0.011097887880168855
# Erro de Validação: 0.0003925540659110993
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 64]
# Erro de Treinamento: 0.02724973252043128
# Erro de Validação: 0.00039215738070197403
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 65]
# Erro de Treinamento: 0.004477291600778699
# Erro de Validação: 0.0005242050974629819
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 66]
# Erro de Treinamento: 0.03264629887416959
# Erro de Validação: 0.00039480082341469824
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 67]
# Erro de Treinamento: 0.011560501952772029
# Erro de Validação: 0.00038877257611602545
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 68]
# Erro de Treinamento: 0.013709644365007989
# Erro de Validação: 0.0004007912939414382
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 69]
# Erro de Treinamento: 0.010147020555450581
# Erro de Validação: 0.00040270888712257147
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 70]
# Erro de Treinamento: 0.009919968229951337
# Erro de Validação: 0.0003903635370079428
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 71]
# Erro de Treinamento: 0.017027083769789897
# Erro de Validação: 0.0003876328992191702
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 72]
# Erro de Treinamento: 0.007960027804074343
# Erro de Validação: 0.00039366271812468767
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 73]
# Erro de Treinamento: 0.011723785049980506
# Erro de Validação: 0.0003884985635522753
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 74]
# Erro de Treinamento: 0.00850292133691255
# Erro de Validação: 0.0003844168677460402
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 75]
# Erro de Treinamento: 0.007783283042954281
# Erro de Validação: 0.0003878006536979228
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 76]
# Erro de Treinamento: 0.008708037028554827
# Erro de Validação: 0.00038231248618103564
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 77]
# Erro de Treinamento: 0.008120561629766598
# Erro de Validação: 0.0003823930455837399
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 78]
# Erro de Treinamento: 0.009061418459168635
# Erro de Validação: 0.0003792949428316206
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 79]
# Erro de Treinamento: 0.007596641255076975
# Erro de Validação: 0.00038084512925706804
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 80]
# Erro de Treinamento: 0.008829003621940501
# Erro de Validação: 0.0003781242994591594
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 81]
# Erro de Treinamento: 0.007719891567830928
# Erro de Validação: 0.00037579084164462984
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 82]
# Erro de Treinamento: 0.01136751456942875
# Erro de Validação: 0.0003757717495318502
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 83]
# Erro de Treinamento: 0.009107966281590052
# Erro de Validação: 0.0003886284539476037
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 84]
# Erro de Treinamento: 0.010902585490839556
# Erro de Validação: 0.0003719293454196304
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 85]
# Erro de Treinamento: 0.007311416804441251
# Erro de Validação: 0.00036812605685554445
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 86]
# Erro de Treinamento: 0.010193988724495284
# Erro de Validação: 0.00037043087650090456
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 87]
# Erro de Treinamento: 0.007038415438728407
# Erro de Validação: 0.0003821445570793003
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 88]
# Erro de Treinamento: 0.012428966962033883
# Erro de Validação: 0.0003695979539770633
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 89]
# Erro de Treinamento: 0.007429462420986965
# Erro de Validação: 0.00036451328196562827
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 90]
# Erro de Treinamento: 0.010062483132060152
# Erro de Validação: 0.0003671360027510673
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 91]
# Erro de Treinamento: 0.00856778264278546
# Erro de Validação: 0.0003699675726238638
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 92]
# Erro de Treinamento: 0.011571621667826548
# Erro de Validação: 0.00036379016819410026
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 93]
# Erro de Treinamento: 0.00944783556042239
# Erro de Validação: 0.00036030457704328
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 94]
# Erro de Treinamento: 0.010851703729713336
# Erro de Validação: 0.0003620531933847815
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 95]
# Erro de Treinamento: 0.007159930872148834
# Erro de Validação: 0.0003621631767600775
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 96]
# Erro de Treinamento: 0.008728523840545677
# Erro de Validação: 0.00036183607880957425
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 97]
# Erro de Treinamento: 0.007820282495231368
# Erro de Validação: 0.00035842988290823996
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 98]
# Erro de Treinamento: 0.007476007711375132
# Erro de Validação: 0.0003570301050785929
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 99]
# Erro de Treinamento: 0.007459711123374291
# Erro de Validação: 0.00035765653592534363
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0

# %% [markdown]
# ## Métricas e resultados
# - Plotando as curvas de perda para treino e validação

# %%
# Criando os graficos
plt.plot(train_loss_all_epoch, label='Treino')
plt.plot(val_loss_all_epoch, label='Validação')

# Adicionando título e rótulos aos eixos
plt.title('Curva de Perda por Época', fontsize=14)
plt.xlabel('Épocas', fontsize=12)
plt.ylabel('Perda (Loss)', fontsize=12)

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True, linestyle='--', alpha=0.7)  # Adicionando grade
plt.tight_layout()  # Ajuste para não cortar o gráfico
plt.show()

# %% [markdown]
# - Plotando as curvas de acuracia para treino e validação

# %%
# Criando os graficos
plt.plot(train_accuracy_all_epoch, label='Treino')
plt.plot(val_accuracy_all_epoch, label='Validação')

# Adicionando título e rótulos aos eixos
plt.title('Curva de Acurácia por Época', fontsize=14)
plt.xlabel('Épocas', fontsize=12)
plt.ylabel('Acurácia (accuracy)', fontsize=12)

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True, linestyle='--', alpha=0.7)  # Adicionando grade
plt.tight_layout()  # Ajuste para não cortar o gráfico
plt.show()

# %% [markdown]
# - Plotando a matriz de confusão

# %%
# Montando a matriz
net.train(False)
for data in data_test:
    x_test, y_test = data
    x_test = x_test.to(torch.float32)
    y_pred = net(x_test)
    y_pred = torch.Tensor.argmax(y_pred, dim=1)
    cm = confusion_matrix(y_test, y_pred, labels=range(3))

# Exibindo a matriz de confusão graficamente
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['sedosa', 'versicolor', 'virginica'])
fig, ax = plt.subplots(figsize=(4, 4))
disp.plot(ax=ax, cmap='Blues', colorbar=False)

# Melhorando o gráfico
ax.set_title('Matriz de Confusão para Dados de Treino', fontsize=14)
ax.set_xlabel('Classe Predita', fontsize=12)
ax.set_ylabel('Classe Verdadeira', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# - Exibindo métricas de Classificação

# %%
# Calculando e imprimindo o relatório de classificação
print(classification_report(y_test, y_pred, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       0.91      0.91      0.91        11
#            2       0.90      0.90      0.90        10
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.94      0.94        30
# weighted avg       0.93      0.93      0.93        30
