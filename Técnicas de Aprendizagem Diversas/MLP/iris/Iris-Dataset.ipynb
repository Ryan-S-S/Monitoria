# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

# %%
# Dataset Iris
from sklearn.datasets import load_iris
data = load_iris()
df = pd.DataFrame(data.data)
df.columns = data.feature_names
df['target'] = data.target

# %%
print(f"Base de dados com {len(df)} linhas")
# Out:
# Base de dados com 150 linhas

# %%
# Principio do Aprendizado de Maquina Supervisionado
data = df.drop('target', axis=1) # Dados
labels = df['target'] # Labels

# %%
# csv -> dados
data = data.values
labels = labels.values

# %%
# Dividindo dados para o processo de treino, teste e validação
data_train, data_test, labels_train, labels_test = train_test_split(data, labels,
                                                                    test_size=0.2, random_state=41)
data_train, data_validation, labels_train, labels_validation = train_test_split(data_train, labels_train,
                                                                                test_size=0.1,
                                                                                random_state=1)
#https://justpaste.it/cf7rw
print(f'Quantidade de Dados para Treinamento : {len(data_train)}')
print(f'Quantidade de Dados para Validação : {len(data_test)}')
print(f'Quantidade de Dados para Teste : {len(data_validation)}')
# Out:
# Quantidade de Dados para Treinamento : 108
# Quantidade de Dados para Validação : 30
# Quantidade de Dados para Teste : 12

# %%
class DataSet(torch.utils.data.Dataset):
    def __init__(self,data,labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self,idx):
        return self.data[idx], self.labels[idx]

# %%
dataset = DataSet(data_train,labels_train)
data_train = DataLoader(dataset, batch_size=32, shuffle=True, num_workers=0)

dataset = DataSet(data_validation,labels_validation)
data_validation = DataLoader(dataset, batch_size=len(data_validation), shuffle=True, num_workers=0)

dataset = DataSet(data_test,labels_test)
data_test = DataLoader(dataset, batch_size=len(data_test), shuffle=True, num_workers=0)

# %%
# Criação do Modelo de Rede
    # 4 Entradas (4 Caracteristicas da Flor)
    # 2 Camadas de Neuronio
    # 3 Saidas (3 Rotulos de Flor)
class IrisClassifier(nn.Module) :
    def __init__(self, input_size = 4, hidden_size1=20, hidden_size2 = 10, output_size = 3) :
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.output = nn.Linear(hidden_size2, output_size)
        self.relu = nn.ReLU()

    def forward(self, data) :
        data = self.relu(self.fc1(data))
        data = self.relu(self.fc2(data))
        data = self.output(data)
        return data

# %%
net = IrisClassifier()
learning_rate = 0.01
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)

# %%
def train_one_epoch(model,loss_function,optimizer,data_train):
    model.train()
    current_loss = 0.0
    current_accuracy = 0.0
    total_samples = 0

    for i,data in enumerate(data_train):
        x,y = data
        x = x.to(torch.float)
        optimizer.zero_grad()
        output = model(x)
        loss = loss_function(output,y)
        loss.backward()
        optimizer.step()
        current_loss += loss.item()

        output = output.argmax(dim=1)
        batch_accuracy = torch.eq(output,y)
        batch_accuracy = batch_accuracy.sum()
        current_accuracy += batch_accuracy
        total_samples += len(x)
    return current_loss/(i+1), current_accuracy/total_samples

# %%
def validation_one_epoch(model,loss_function, data_validation):
    model.train(False)
    current_loss = 0.0
    current_accuracy = 0.0
    total_samples = 0
    for i,data in enumerate(data_validation):
        x,y = data
        x = x.to(torch.float)
        output = model(x)
        loss = loss_function(output,y)
        current_loss += loss.item()

        output = output.argmax(dim=1)
        batch_accuracy = torch.eq(output,y)
        batch_accuracy = batch_accuracy.sum()
        current_accuracy += batch_accuracy
        total_samples += len(x)
    return current_loss/(i+1), current_accuracy/total_samples

# %%
epochs = 1000
train_loss_all_epoch = []
train_accuracy_all_epoch = []
val_loss_all_epoch = []
val_accuracy_all_epoch = []
best_val_loss = 1e9

for epoch in range(epochs):

    train_loss_per_epoch, train_accuracy_per_epoch = train_one_epoch(net,criterion,optimizer,data_train)

    train_loss_all_epoch.append(train_loss_per_epoch)
    train_accuracy_all_epoch.append(train_accuracy_per_epoch)

    val_loss_per_epoch,val_accuracy_per_epoch = validation_one_epoch(net,criterion, data_validation)

    val_loss_all_epoch.append(val_loss_per_epoch)
    val_accuracy_all_epoch.append(val_accuracy_per_epoch)

    if val_loss_per_epoch < best_val_loss:
        best_val_loss = val_loss_per_epoch
        model_path = 'test_model'
        torch.save(net.state_dict(),model_path)

    if(epoch % 1 == 0) :
      print(f'Epóca [: {epoch}]')
      print(f'Erro de Treinamento: {train_loss_per_epoch}')
      print(f'Erro de Validação: {val_loss_per_epoch}')
      print(f'Acurácia de Treinamento: {train_accuracy_per_epoch}')
      print(f'Acurácia de Validação: {val_accuracy_per_epoch}')
      print()
# Out:
# Epóca [: 0]
# Erro de Treinamento: 1.1222160160541534
# Erro de Validação: 1.0406509637832642
# Acurácia de Treinamento: 0.26851850748062134
# Acurácia de Validação: 0.3333333432674408
#
# Epóca [: 1]
# Erro de Treinamento: 1.0364865362644196
# Erro de Validação: 0.9900458455085754
# Acurácia de Treinamento: 0.37037035822868347
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 2]
# Erro de Treinamento: 0.9603658765554428
# Erro de Validação: 0.911292314529419
# Acurácia de Treinamento: 0.6851851940155029
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 3]
# Erro de Treinamento: 0.8598757088184357
# Erro de Validação: 0.8196525573730469
# Acurácia de Treinamento: 0.6851851940155029
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 4]
# Erro de Treinamento: 0.7556104511022568
# Erro de Validação: 0.7390986084938049
# Acurácia de Treinamento: 0.6851851940155029
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 5]
# Erro de Treinamento: 0.6604265868663788
# Erro de Validação: 0.6807865500450134
# Acurácia de Treinamento: 0.6851851940155029
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 6]
# Erro de Treinamento: 0.6044590696692467
# Erro de Validação: 0.5896231532096863
# Acurácia de Treinamento: 0.6851851940155029
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 7]
# Erro de Treinamento: 0.49680087715387344
# Erro de Validação: 0.5156764984130859
# Acurácia de Treinamento: 0.7037037014961243
# Acurácia de Validação: 0.75
#
# Epóca [: 8]
# Erro de Treinamento: 0.4538636803627014
# Erro de Validação: 0.4858926236629486
# Acurácia de Treinamento: 0.7222222089767456
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 9]
# Erro de Treinamento: 0.4084811136126518
# Erro de Validação: 0.4501934349536896
# Acurácia de Treinamento: 0.7314814925193787
# Acurácia de Validação: 0.6666666865348816
#
# Epóca [: 10]
# Erro de Treinamento: 0.39196520298719406
# Erro de Validação: 0.41650548577308655
# Acurácia de Treinamento: 0.7407407164573669
# Acurácia de Validação: 0.75
#
# Epóca [: 11]
# Erro de Treinamento: 0.3575277179479599
# Erro de Validação: 0.36859461665153503
# Acurácia de Treinamento: 0.7870370149612427
# Acurácia de Validação: 0.9166666865348816
#
# Epóca [: 12]
# Erro de Treinamento: 0.3510948047041893
# Erro de Validação: 0.31304219365119934
# Acurácia de Treinamento: 0.9166666865348816
# Acurácia de Validação: 1.0
#
# Epóca [: 13]
# Erro de Treinamento: 0.32147450745105743
# Erro de Validação: 0.3044784665107727
# Acurácia de Treinamento: 0.9166666865348816
# Acurácia de Validação: 1.0
#
# Epóca [: 14]
# Erro de Treinamento: 0.282889187335968
# Erro de Validação: 0.24577312171459198
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 15]
# Erro de Treinamento: 0.26180481165647507
# Erro de Validação: 0.25224342942237854
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 1.0
#
# Epóca [: 16]
# Erro de Treinamento: 0.2599474862217903
# Erro de Validação: 0.21742169559001923
# Acurácia de Treinamento: 0.9074074029922485
# Acurácia de Validação: 1.0
#
# Epóca [: 17]
# Erro de Treinamento: 0.2284713126718998
# Erro de Validação: 0.16808883845806122
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 18]
# Erro de Treinamento: 0.20501303672790527
# Erro de Validação: 0.17242032289505005
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 19]
# Erro de Treinamento: 0.19055943936109543
# Erro de Validação: 0.12789751589298248
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 20]
# Erro de Treinamento: 0.1960839331150055
# Erro de Validação: 0.11402184516191483
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 1.0
#
# Epóca [: 21]
# Erro de Treinamento: 0.17380376532673836
# Erro de Validação: 0.13097019493579865
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 22]
# Erro de Treinamento: 0.15484420768916607
# Erro de Validação: 0.09038152545690536
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 23]
# Erro de Treinamento: 0.1805050540715456
# Erro de Validação: 0.0906795859336853
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 24]
# Erro de Treinamento: 0.17945802211761475
# Erro de Validação: 0.09803684800863266
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 25]
# Erro de Treinamento: 0.16698719933629036
# Erro de Validação: 0.0821777805685997
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 26]
# Erro de Treinamento: 0.15115559846162796
# Erro de Validação: 0.07213469594717026
# Acurácia de Treinamento: 0.9351851940155029
# Acurácia de Validação: 1.0
#
# Epóca [: 27]
# Erro de Treinamento: 0.10909623466432095
# Erro de Validação: 0.05842430517077446
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 28]
# Erro de Treinamento: 0.11294754967093468
# Erro de Validação: 0.0532161146402359
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 29]
# Erro de Treinamento: 0.11082705669105053
# Erro de Validação: 0.051456060260534286
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 30]
# Erro de Treinamento: 0.10714328661561012
# Erro de Validação: 0.05054770037531853
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 31]
# Erro de Treinamento: 0.11765867099165916
# Erro de Validação: 0.04159459471702576
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 32]
# Erro de Treinamento: 0.14836012572050095
# Erro de Validação: 0.041213344782590866
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 33]
# Erro de Treinamento: 0.10235965065658092
# Erro de Validação: 0.04773837700486183
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 34]
# Erro de Treinamento: 0.11578324250876904
# Erro de Validação: 0.03730352595448494
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 35]
# Erro de Treinamento: 0.08949737995862961
# Erro de Validação: 0.03200427442789078
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 36]
# Erro de Treinamento: 0.07272731862030923
# Erro de Validação: 0.03538648039102554
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 37]
# Erro de Treinamento: 0.08628194872289896
# Erro de Validação: 0.030241981148719788
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 38]
# Erro de Treinamento: 0.08330626785755157
# Erro de Validação: 0.02665756642818451
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 39]
# Erro de Treinamento: 0.07036304147914052
# Erro de Validação: 0.025130480527877808
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 40]
# Erro de Treinamento: 0.09018529858440161
# Erro de Validação: 0.024936139583587646
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 41]
# Erro de Treinamento: 0.08223806787282228
# Erro de Validação: 0.025575563311576843
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 42]
# Erro de Treinamento: 0.10880438517779112
# Erro de Validação: 0.025597574189305305
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 43]
# Erro de Treinamento: 0.06538612861186266
# Erro de Validação: 0.032870709896087646
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 44]
# Erro de Treinamento: 0.08107213606126606
# Erro de Validação: 0.020009217783808708
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 45]
# Erro de Treinamento: 0.08218121062964201
# Erro de Validação: 0.02022613026201725
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 46]
# Erro de Treinamento: 0.08269407413899899
# Erro de Validação: 0.022008249536156654
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 47]
# Erro de Treinamento: 0.07079755002632737
# Erro de Validação: 0.020809460431337357
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 48]
# Erro de Treinamento: 0.07612181734293699
# Erro de Validação: 0.01993904449045658
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 49]
# Erro de Treinamento: 0.0780178951099515
# Erro de Validação: 0.02256355993449688
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 50]
# Erro de Treinamento: 0.07497507147490978
# Erro de Validação: 0.014764513820409775
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 51]
# Erro de Treinamento: 0.108397101983428
# Erro de Validação: 0.01411797571927309
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 52]
# Erro de Treinamento: 0.08813984785228968
# Erro de Validação: 0.026641538366675377
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 1.0
#
# Epóca [: 53]
# Erro de Treinamento: 0.07015989115461707
# Erro de Validação: 0.015312663279473782
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 54]
# Erro de Treinamento: 0.07707001082599163
# Erro de Validação: 0.016368644312024117
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 55]
# Erro de Treinamento: 0.074554274789989
# Erro de Validação: 0.01860128901898861
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 56]
# Erro de Treinamento: 0.05863039253745228
# Erro de Validação: 0.011875975877046585
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 57]
# Erro de Treinamento: 0.05907889874652028
# Erro de Validação: 0.011462668888270855
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 58]
# Erro de Treinamento: 0.06763811502605677
# Erro de Validação: 0.01295637246221304
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 59]
# Erro de Treinamento: 0.057213525753468275
# Erro de Validação: 0.011247447691857815
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 60]
# Erro de Treinamento: 0.06154584977775812
# Erro de Validação: 0.010511010885238647
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 61]
# Erro de Treinamento: 0.05590832279995084
# Erro de Validação: 0.010424531996250153
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 62]
# Erro de Treinamento: 0.07194855669513345
# Erro de Validação: 0.00939379446208477
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 63]
# Erro de Treinamento: 0.04829366086050868
# Erro de Validação: 0.014676396735012531
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 64]
# Erro de Treinamento: 0.06095178611576557
# Erro de Validação: 0.008829808793962002
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 65]
# Erro de Treinamento: 0.05707519443240017
# Erro de Validação: 0.009072577580809593
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 66]
# Erro de Treinamento: 0.059181008487939835
# Erro de Validação: 0.012503284960985184
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 67]
# Erro de Treinamento: 0.062356055714190006
# Erro de Validação: 0.008039572276175022
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 68]
# Erro de Treinamento: 0.07290800055488944
# Erro de Validação: 0.00798215251415968
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 69]
# Erro de Treinamento: 0.06146546732634306
# Erro de Validação: 0.011175178922712803
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 70]
# Erro de Treinamento: 0.07367266481742263
# Erro de Validação: 0.007520303130149841
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 71]
# Erro de Treinamento: 0.044791478430852294
# Erro de Validação: 0.01211883407086134
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 72]
# Erro de Treinamento: 0.06719468953087926
# Erro de Validação: 0.007053003180772066
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 73]
# Erro de Treinamento: 0.07659210357815027
# Erro de Validação: 0.006607282441109419
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 74]
# Erro de Treinamento: 0.05450772400945425
# Erro de Validação: 0.015143834054470062
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 75]
# Erro de Treinamento: 0.053964338498190045
# Erro de Validação: 0.006395956035703421
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 76]
# Erro de Treinamento: 0.059075572760775685
# Erro de Validação: 0.006362553220242262
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 77]
# Erro de Treinamento: 0.04644708498381078
# Erro de Validação: 0.012444175779819489
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 78]
# Erro de Treinamento: 0.05379416898358613
# Erro de Validação: 0.006530445069074631
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 79]
# Erro de Treinamento: 0.062225091736763716
# Erro de Validação: 0.005459730047732592
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 80]
# Erro de Treinamento: 0.055868775583803654
# Erro de Validação: 0.008534286171197891
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 81]
# Erro de Treinamento: 0.04279674123972654
# Erro de Validação: 0.005484151188284159
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 82]
# Erro de Treinamento: 0.05146442959085107
# Erro de Validação: 0.005252439994364977
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 83]
# Erro de Treinamento: 0.04925663024187088
# Erro de Validação: 0.006094732787460089
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 84]
# Erro de Treinamento: 0.044660213869065046
# Erro de Validação: 0.004866089206188917
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 85]
# Erro de Treinamento: 0.06969914864748716
# Erro de Validação: 0.0046906787902116776
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 86]
# Erro de Treinamento: 0.05329873180016875
# Erro de Validação: 0.006748605519533157
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 87]
# Erro de Treinamento: 0.0608195373788476
# Erro de Validação: 0.009377392008900642
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 88]
# Erro de Treinamento: 0.0713896038942039
# Erro de Validação: 0.0059472038410604
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 89]
# Erro de Treinamento: 0.08016527630388737
# Erro de Validação: 0.004643215797841549
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 90]
# Erro de Treinamento: 0.04724980832543224
# Erro de Validação: 0.01901024393737316
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 91]
# Erro de Treinamento: 0.062026545871049166
# Erro de Validação: 0.003952887374907732
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 92]
# Erro de Treinamento: 0.08532414073124528
# Erro de Validação: 0.0038921572268009186
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 93]
# Erro de Treinamento: 0.05212618410587311
# Erro de Validação: 0.020984454080462456
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 94]
# Erro de Treinamento: 0.07131147291511297
# Erro de Validação: 0.003903281642124057
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 95]
# Erro de Treinamento: 0.050613613333553076
# Erro de Validação: 0.003813809948042035
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 96]
# Erro de Treinamento: 0.04060063441284001
# Erro de Validação: 0.011584167368710041
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 97]
# Erro de Treinamento: 0.06344690383411944
# Erro de Validação: 0.003709646174684167
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 98]
# Erro de Treinamento: 0.048782094730995595
# Erro de Validação: 0.0044898078776896
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 99]
# Erro de Treinamento: 0.05222469847649336
# Erro de Validação: 0.006557525601238012
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 100]
# Erro de Treinamento: 0.04039005283266306
# Erro de Validação: 0.004088501445949078
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 101]
# Erro de Treinamento: 0.03383907343959436
# Erro de Validação: 0.0038272689562290907
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 102]
# Erro de Treinamento: 0.03444046666845679
# Erro de Validação: 0.00401724549010396
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 103]
# Erro de Treinamento: 0.03627425152808428
# Erro de Validação: 0.0036553768441081047
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 104]
# Erro de Treinamento: 0.04681129439268261
# Erro de Validação: 0.003825697349384427
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 105]
# Erro de Treinamento: 0.04453916661441326
# Erro de Validação: 0.006420212332159281
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 106]
# Erro de Treinamento: 0.06135019101202488
# Erro de Validação: 0.0031426793430000544
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 107]
# Erro de Treinamento: 0.03632219781866297
# Erro de Validação: 0.007091124076396227
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 108]
# Erro de Treinamento: 0.046242580749094486
# Erro de Validação: 0.002731940010562539
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 109]
# Erro de Treinamento: 0.04471778299193829
# Erro de Validação: 0.002942178398370743
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 110]
# Erro de Treinamento: 0.0521209123544395
# Erro de Validação: 0.004788619000464678
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 111]
# Erro de Treinamento: 0.06186723057180643
# Erro de Validação: 0.0047395238652825356
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 112]
# Erro de Treinamento: 0.04078841023147106
# Erro de Validação: 0.0026788313407450914
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 113]
# Erro de Treinamento: 0.04865521099418402
# Erro de Validação: 0.004420685116201639
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 114]
# Erro de Treinamento: 0.048263820353895426
# Erro de Validação: 0.0038537902291864157
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 115]
# Erro de Treinamento: 0.05081080016680062
# Erro de Validação: 0.0022926677484065294
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 116]
# Erro de Treinamento: 0.061794732231646776
# Erro de Validação: 0.003223325125873089
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 117]
# Erro de Treinamento: 0.06941628968343139
# Erro de Validação: 0.002420080592855811
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 118]
# Erro de Treinamento: 0.05270572262816131
# Erro de Validação: 0.006947772111743689
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 119]
# Erro de Treinamento: 0.03789125895127654
# Erro de Validação: 0.002183132106438279
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 120]
# Erro de Treinamento: 0.05349902855232358
# Erro de Validação: 0.0025020726025104523
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 121]
# Erro de Treinamento: 0.044674509670585394
# Erro de Validação: 0.00598209910094738
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 122]
# Erro de Treinamento: 0.03489017870742828
# Erro de Validação: 0.0021228620316833258
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 123]
# Erro de Treinamento: 0.038826079573482275
# Erro de Validação: 0.001988567179068923
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 124]
# Erro de Treinamento: 0.04778137127868831
# Erro de Validação: 0.004480892326682806
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 125]
# Erro de Treinamento: 0.02988655836088583
# Erro de Validação: 0.001939366920851171
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 126]
# Erro de Treinamento: 0.0359337218105793
# Erro de Validação: 0.00211278791539371
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 127]
# Erro de Treinamento: 0.038351163966581225
# Erro de Validação: 0.004293878562748432
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 128]
# Erro de Treinamento: 0.03203903650864959
# Erro de Validação: 0.0019073690054938197
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 129]
# Erro de Treinamento: 0.03005545597989112
# Erro de Validação: 0.0017557319952175021
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 130]
# Erro de Treinamento: 0.033945668023079634
# Erro de Validação: 0.0034710050094872713
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 131]
# Erro de Treinamento: 0.03614995861425996
# Erro de Validação: 0.002313789213076234
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 132]
# Erro de Treinamento: 0.033415800193324685
# Erro de Validação: 0.0018179829930886626
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 133]
# Erro de Treinamento: 0.03355134930461645
# Erro de Validação: 0.002283881651237607
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 134]
# Erro de Treinamento: 0.04008933273144066
# Erro de Validação: 0.0023616005200892687
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 135]
# Erro de Treinamento: 0.04362952383235097
# Erro de Validação: 0.0029129970353096724
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 136]
# Erro de Treinamento: 0.04338991711847484
# Erro de Validação: 0.0014448555884882808
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 137]
# Erro de Treinamento: 0.04596468387171626
# Erro de Validação: 0.0025020150933414698
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 138]
# Erro de Treinamento: 0.03146926127374172
# Erro de Validação: 0.0018749794689938426
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 139]
# Erro de Treinamento: 0.04195019602775574
# Erro de Validação: 0.0014796493342146277
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 140]
# Erro de Treinamento: 0.03089395258575678
# Erro de Validação: 0.0038440851494669914
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 141]
# Erro de Treinamento: 0.04671105369925499
# Erro de Validação: 0.0013002798659726977
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 142]
# Erro de Treinamento: 0.03852615010691807
# Erro de Validação: 0.002183914417400956
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 143]
# Erro de Treinamento: 0.05606283573433757
# Erro de Validação: 0.0033158964943140745
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 144]
# Erro de Treinamento: 0.03004997700918466
# Erro de Validação: 0.0021479676943272352
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 145]
# Erro de Treinamento: 0.032486626878380775
# Erro de Validação: 0.0013886726228520274
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 146]
# Erro de Treinamento: 0.02972350176423788
# Erro de Validação: 0.0021071042865514755
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 147]
# Erro de Treinamento: 0.028110112063586712
# Erro de Validação: 0.002588138449937105
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 148]
# Erro de Treinamento: 0.025649064322351478
# Erro de Validação: 0.001313481479883194
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 149]
# Erro de Treinamento: 0.028214905061759055
# Erro de Validação: 0.0015570492250844836
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 150]
# Erro de Treinamento: 0.027483903104439378
# Erro de Validação: 0.0017679996090009809
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 151]
# Erro de Treinamento: 0.02560516011726577
# Erro de Validação: 0.001389985904097557
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 152]
# Erro de Treinamento: 0.033468610141426325
# Erro de Validação: 0.0012926732888445258
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 153]
# Erro de Treinamento: 0.04370879824273288
# Erro de Validação: 0.0015508056385442615
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 154]
# Erro de Treinamento: 0.031662531109759584
# Erro de Validação: 0.00448185857385397
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 155]
# Erro de Treinamento: 0.031753705348819494
# Erro de Validação: 0.0009648629347793758
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 156]
# Erro de Treinamento: 0.05123157240450382
# Erro de Validação: 0.0015030436916276813
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 157]
# Erro de Treinamento: 0.043711068108677864
# Erro de Validação: 0.004167465027421713
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 158]
# Erro de Treinamento: 0.024719018285395578
# Erro de Validação: 0.0010996491182595491
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 159]
# Erro de Treinamento: 0.05696699325926602
# Erro de Validação: 0.0011434314073994756
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 160]
# Erro de Treinamento: 0.023355076846200973
# Erro de Validação: 0.004409526474773884
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 161]
# Erro de Treinamento: 0.04444494447670877
# Erro de Validação: 0.0009900523582473397
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 162]
# Erro de Treinamento: 0.0393346628989093
# Erro de Validação: 0.0010314414976164699
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 163]
# Erro de Treinamento: 0.04744278755970299
# Erro de Validação: 0.007521263789385557
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 164]
# Erro de Treinamento: 0.050090890377759933
# Erro de Validação: 0.0009840779239311814
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 165]
# Erro de Treinamento: 0.034197917906567454
# Erro de Validação: 0.0011982476571574807
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 166]
# Erro de Treinamento: 0.036367737455293536
# Erro de Validação: 0.0032777292653918266
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 167]
# Erro de Treinamento: 0.04519395239185542
# Erro de Validação: 0.0017577582038939
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 168]
# Erro de Treinamento: 0.04528109263628721
# Erro de Validação: 0.0008723375503905118
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 169]
# Erro de Treinamento: 0.03767580824205652
# Erro de Validação: 0.0038778481539338827
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 170]
# Erro de Treinamento: 0.037014860194176435
# Erro de Validação: 0.0034283234272152185
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 171]
# Erro de Treinamento: 0.03294017189182341
# Erro de Validação: 0.0008205517078749835
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 172]
# Erro de Treinamento: 0.057096004606137285
# Erro de Validação: 0.001023589284159243
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 173]
# Erro de Treinamento: 0.050796094350516796
# Erro de Validação: 0.0022606432903558016
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 174]
# Erro de Treinamento: 0.024464994145091623
# Erro de Validação: 0.0008804670069366693
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 175]
# Erro de Treinamento: 0.041887202649377286
# Erro de Validação: 0.0013625979190692306
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 176]
# Erro de Treinamento: 0.030734284810023382
# Erro de Validação: 0.002700995421037078
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 177]
# Erro de Treinamento: 0.06332038203254342
# Erro de Validação: 0.0014469701563939452
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 178]
# Erro de Treinamento: 0.0280901275400538
# Erro de Validação: 0.0041047087870538235
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 179]
# Erro de Treinamento: 0.03733663185266778
# Erro de Validação: 0.0007688908954150975
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 180]
# Erro de Treinamento: 0.09201019466854632
# Erro de Validação: 0.0010032322024926543
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 181]
# Erro de Treinamento: 0.14922829484567046
# Erro de Validação: 0.004631959367543459
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 182]
# Erro de Treinamento: 0.06609421584289521
# Erro de Validação: 0.005516605451703072
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 183]
# Erro de Treinamento: 0.12874691281467676
# Erro de Validação: 0.0009069712832570076
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 184]
# Erro de Treinamento: 0.021992490394040942
# Erro de Validação: 0.029568856582045555
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 185]
# Erro de Treinamento: 0.08733452367596328
# Erro de Validação: 0.0010518812341615558
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 186]
# Erro de Treinamento: 0.05995235044974834
# Erro de Validação: 0.0011391636217013001
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 187]
# Erro de Treinamento: 0.04239029163727537
# Erro de Validação: 0.0023400892969220877
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 188]
# Erro de Treinamento: 0.0562571045011282
# Erro de Validação: 0.003983247559517622
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 189]
# Erro de Treinamento: 0.031079216802027076
# Erro de Validação: 0.0011585602769628167
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 190]
# Erro de Treinamento: 0.044159580778796226
# Erro de Validação: 0.0013358774594962597
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 191]
# Erro de Treinamento: 0.03191178757697344
# Erro de Validação: 0.0025640251114964485
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 192]
# Erro de Treinamento: 0.03920445777475834
# Erro de Validação: 0.001249796594493091
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 193]
# Erro de Treinamento: 0.0337901022285223
# Erro de Validação: 0.0015975851565599442
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 194]
# Erro de Treinamento: 0.030739448382519186
# Erro de Validação: 0.0011920862598344684
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 195]
# Erro de Treinamento: 0.03152375156059861
# Erro de Validação: 0.0012797943782061338
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 196]
# Erro de Treinamento: 0.03030187846161425
# Erro de Validação: 0.0014318189350888133
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 197]
# Erro de Treinamento: 0.021530631012865342
# Erro de Validação: 0.001068138750270009
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 198]
# Erro de Treinamento: 0.034348887391388416
# Erro de Validação: 0.001332609448581934
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 199]
# Erro de Treinamento: 0.038527203258126974
# Erro de Validação: 0.0013968456769362092
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 200]
# Erro de Treinamento: 0.024868073873221874
# Erro de Validação: 0.0009158511529676616
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 201]
# Erro de Treinamento: 0.04444305505603552
# Erro de Validação: 0.001268991269171238
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 202]
# Erro de Treinamento: 0.03427017969079316
# Erro de Validação: 0.0024522177409380674
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 203]
# Erro de Treinamento: 0.058241986436769366
# Erro de Validação: 0.0009940426098182797
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 204]
# Erro de Treinamento: 0.02992726577213034
# Erro de Validação: 0.0024878480471670628
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 205]
# Erro de Treinamento: 0.03175728912174236
# Erro de Validação: 0.0009746886207722127
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 206]
# Erro de Treinamento: 0.02387715212535113
# Erro de Validação: 0.0007986701675690711
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 207]
# Erro de Treinamento: 0.03825334110297263
# Erro de Validação: 0.0014194757677614689
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 208]
# Erro de Treinamento: 0.03218485752586275
# Erro de Validação: 0.0036008607130497694
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 209]
# Erro de Treinamento: 0.031685661524534225
# Erro de Validação: 0.0008308528922498226
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 210]
# Erro de Treinamento: 0.024536534067010507
# Erro de Validação: 0.0007340352167375386
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 211]
# Erro de Treinamento: 0.03434197785099968
# Erro de Validação: 0.0009748333250172436
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 212]
# Erro de Treinamento: 0.04799976176582277
# Erro de Validação: 0.002156768459826708
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 213]
# Erro de Treinamento: 0.04945284593850374
# Erro de Validação: 0.0007069287239573896
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 214]
# Erro de Treinamento: 0.029103845125064254
# Erro de Validação: 0.0030605478677898645
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 215]
# Erro de Treinamento: 0.032689321553334594
# Erro de Validação: 0.00117520394269377
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 216]
# Erro de Treinamento: 0.022332592401653528
# Erro de Validação: 0.0006830215570516884
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 217]
# Erro de Treinamento: 0.03754407539963722
# Erro de Validação: 0.0007460092310793698
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 218]
# Erro de Treinamento: 0.022683264105580747
# Erro de Validação: 0.002587134949862957
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 219]
# Erro de Treinamento: 0.028527422924526036
# Erro de Validação: 0.0008107697940431535
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 220]
# Erro de Treinamento: 0.022407228883821517
# Erro de Validação: 0.0007292533409781754
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 221]
# Erro de Treinamento: 0.021124726510606706
# Erro de Validação: 0.00109559774864465
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 222]
# Erro de Treinamento: 0.021628257585689425
# Erro de Validação: 0.001172028947621584
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 223]
# Erro de Treinamento: 0.02030025195563212
# Erro de Validação: 0.0007969155558384955
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 224]
# Erro de Treinamento: 0.039934095460921526
# Erro de Validação: 0.0008048336603678763
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 225]
# Erro de Treinamento: 0.021372899238485843
# Erro de Validação: 0.0018956508720293641
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 226]
# Erro de Treinamento: 0.02349171087553259
# Erro de Validação: 0.0006595826707780361
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 227]
# Erro de Treinamento: 0.02283520926721394
# Erro de Validação: 0.0006412013317458332
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 228]
# Erro de Treinamento: 0.019848338735755533
# Erro de Validação: 0.0013374326517805457
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 229]
# Erro de Treinamento: 0.0382608323416207
# Erro de Validação: 0.0007386354263871908
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 230]
# Erro de Treinamento: 0.037188413087278605
# Erro de Validação: 0.0005462522967718542
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 231]
# Erro de Treinamento: 0.03055856528226286
# Erro de Validação: 0.0017737162997946143
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 232]
# Erro de Treinamento: 0.046507497085258365
# Erro de Validação: 0.0009159196051768959
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 233]
# Erro de Treinamento: 0.02197510260157287
# Erro de Validação: 0.0005602547898888588
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 234]
# Erro de Treinamento: 0.036977909330744296
# Erro de Validação: 0.0007083273958414793
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 235]
# Erro de Treinamento: 0.031717788660898805
# Erro de Validação: 0.0014300538459792733
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 236]
# Erro de Treinamento: 0.023371147603029385
# Erro de Validação: 0.0005222451291047037
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 237]
# Erro de Treinamento: 0.022263255814323202
# Erro de Validação: 0.0006681557861156762
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 238]
# Erro de Treinamento: 0.019698953023180366
# Erro de Validação: 0.0007971581653691828
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 239]
# Erro de Treinamento: 0.03410034021362662
# Erro de Validação: 0.0006595667800866067
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 240]
# Erro de Treinamento: 0.04957197071053088
# Erro de Validação: 0.0004812650440726429
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 241]
# Erro de Treinamento: 0.016591600884567015
# Erro de Validação: 0.0021163246128708124
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 242]
# Erro de Treinamento: 0.039923491392983124
# Erro de Validação: 0.0007262769504450262
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 243]
# Erro de Treinamento: 0.025842820527032018
# Erro de Validação: 0.0006464847247116268
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 244]
# Erro de Treinamento: 0.019262773217633367
# Erro de Validação: 0.00046870330697856843
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 245]
# Erro de Treinamento: 0.027419158373959363
# Erro de Validação: 0.0005836400086991489
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 246]
# Erro de Treinamento: 0.028533523087389767
# Erro de Validação: 0.0007988540455698967
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 247]
# Erro de Treinamento: 0.044547021156176925
# Erro de Validação: 0.0004492863081395626
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 248]
# Erro de Treinamento: 0.020427395589649677
# Erro de Validação: 0.0019340725848451257
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 249]
# Erro de Treinamento: 0.028192267687700223
# Erro de Validação: 0.0006528965313918889
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 250]
# Erro de Treinamento: 0.02633119816891849
# Erro de Validação: 0.0004299235006328672
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 251]
# Erro de Treinamento: 0.026628899853676558
# Erro de Validação: 0.0004260483256075531
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 252]
# Erro de Treinamento: 0.019409387241466902
# Erro de Validação: 0.0008847152930684388
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 253]
# Erro de Treinamento: 0.027469389140605927
# Erro de Validação: 0.0006652117590419948
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 254]
# Erro de Treinamento: 0.026957693393342197
# Erro de Validação: 0.0003986360097769648
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 255]
# Erro de Treinamento: 0.020227252854965627
# Erro de Validação: 0.0010430649854242802
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 256]
# Erro de Treinamento: 0.03634311235509813
# Erro de Validação: 0.0004934456082992256
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 257]
# Erro de Treinamento: 0.028395744688168634
# Erro de Validação: 0.0003818285185843706
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 258]
# Erro de Treinamento: 0.028656254522502422
# Erro de Validação: 0.0007627231534570456
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 259]
# Erro de Treinamento: 0.043791153468191624
# Erro de Validação: 0.0005781055078841746
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 260]
# Erro de Treinamento: 0.032569514311035164
# Erro de Validação: 0.0004416315641719848
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 261]
# Erro de Treinamento: 0.04253947583492845
# Erro de Validação: 0.0005314464797265828
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 262]
# Erro de Treinamento: 0.023955988697707653
# Erro de Validação: 0.000788335979450494
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 263]
# Erro de Treinamento: 0.017818358435761184
# Erro de Validação: 0.00037065986543893814
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 264]
# Erro de Treinamento: 0.021428123553050682
# Erro de Validação: 0.00045684303040616214
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 265]
# Erro de Treinamento: 0.022353861073497683
# Erro de Validação: 0.0006670940783806145
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 266]
# Erro de Treinamento: 0.023344329791143537
# Erro de Validação: 0.00039721940993331373
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 267]
# Erro de Treinamento: 0.01960067095933482
# Erro de Validação: 0.0004032218421343714
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 268]
# Erro de Treinamento: 0.01715112617239356
# Erro de Validação: 0.0005962359136901796
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 269]
# Erro de Treinamento: 0.01842519681667909
# Erro de Validação: 0.0005594613030552864
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 270]
# Erro de Treinamento: 0.018590486521134153
# Erro de Validação: 0.00044649126357398927
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 271]
# Erro de Treinamento: 0.018265138030983508
# Erro de Validação: 0.0005308710387907922
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 272]
# Erro de Treinamento: 0.02073358022607863
# Erro de Validação: 0.0004164715064689517
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 273]
# Erro de Treinamento: 0.021327816080884077
# Erro de Validação: 0.0003970229299739003
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 274]
# Erro de Treinamento: 0.024073571374174207
# Erro de Validação: 0.00041594341746531427
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 275]
# Erro de Treinamento: 0.027473566820845008
# Erro de Validação: 0.0003631303261499852
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 276]
# Erro de Treinamento: 0.016729057300835848
# Erro de Validação: 0.0008339486084878445
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 277]
# Erro de Treinamento: 0.019471124454867095
# Erro de Validação: 0.000356128643034026
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 278]
# Erro de Treinamento: 0.01981785031966865
# Erro de Validação: 0.0003439738939050585
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 279]
# Erro de Treinamento: 0.024346674792468548
# Erro de Validação: 0.0004936216282658279
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 280]
# Erro de Treinamento: 0.021248377015581354
# Erro de Validação: 0.00033767466084100306
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 281]
# Erro de Treinamento: 0.018704105401411653
# Erro de Validação: 0.0003675617044791579
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 282]
# Erro de Treinamento: 0.027214322704821825
# Erro de Validação: 0.0005675560678355396
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 283]
# Erro de Treinamento: 0.03546884172828868
# Erro de Validação: 0.0005016920040361583
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 284]
# Erro de Treinamento: 0.05395556899020448
# Erro de Validação: 0.00025785662000998855
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 285]
# Erro de Treinamento: 0.04746881686151028
# Erro de Validação: 0.0008569229976274073
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 286]
# Erro de Treinamento: 0.018940343303256668
# Erro de Validação: 0.00029025707044638693
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 287]
# Erro de Treinamento: 0.037657470151316375
# Erro de Validação: 0.00048458235687576234
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 288]
# Erro de Treinamento: 0.01759412839601282
# Erro de Validação: 0.0006003536400385201
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 289]
# Erro de Treinamento: 0.024924199853558093
# Erro de Validação: 0.00032563702552579343
# Acurácia de Treinamento: 0.9907407164573669
# ...
# Acurácia de Validação: 1.0
#
# Epóca [: 899]
# Erro de Treinamento: 0.008226358098909259
# Erro de Validação: 2.944394691439811e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 900]
# Erro de Treinamento: 0.00798983918139129
# Erro de Validação: 2.906647750933189e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 901]
# Erro de Treinamento: 0.006636528504714079
# Erro de Validação: 3.273164838901721e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 902]
# Erro de Treinamento: 0.009900352844852023
# Erro de Validação: 2.8768432457582094e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 903]
# Erro de Treinamento: 0.0071225096380658215
# Erro de Validação: 2.890746145567391e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 904]
# Erro de Treinamento: 0.008409794016188243
# Erro de Validação: 2.8818045393563807e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 905]
# Erro de Treinamento: 0.00717776018245786
# Erro de Validação: 2.7506875994731672e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 906]
# Erro de Treinamento: 0.010783598758280277
# Erro de Validação: 2.6811540010385215e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 907]
# Erro de Treinamento: 0.010884054936468601
# Erro de Validação: 2.9592740247608162e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 908]
# Erro de Treinamento: 0.010003930619859602
# Erro de Validação: 2.578840940259397e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 909]
# Erro de Treinamento: 0.013626756681333063
# Erro de Validação: 2.713925096031744e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 910]
# Erro de Treinamento: 0.0122177409066353
# Erro de Validação: 2.9672126402147114e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 911]
# Erro de Treinamento: 0.00889212118636351
# Erro de Validação: 2.616588790260721e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 912]
# Erro de Treinamento: 0.020649202667300415
# Erro de Validação: 2.5073124561458826e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 913]
# Erro de Treinamento: 0.011839022256936005
# Erro de Validação: 4.0587561670690775e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 914]
# Erro de Treinamento: 0.014124652117970982
# Erro de Validação: 2.4467221010127105e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 915]
# Erro de Treinamento: 0.010113451207871549
# Erro de Validação: 2.6245354092679918e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 916]
# Erro de Treinamento: 0.019630292461442878
# Erro de Validação: 2.4626104277558625e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 917]
# Erro de Treinamento: 0.009032965241203783
# Erro de Validação: 2.4278431737911887e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 918]
# Erro de Treinamento: 0.008626619601272978
# Erro de Validação: 2.408968430245295e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 919]
# Erro de Treinamento: 0.006199696217663586
# Erro de Validação: 2.328509981452953e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 920]
# Erro de Treinamento: 0.015204593430098612
# Erro de Validação: 2.3592992874910124e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 921]
# Erro de Treinamento: 0.04117676249734359
# Erro de Validação: 2.4040064090513624e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 922]
# Erro de Treinamento: 0.04944013287240523
# Erro de Validação: 0.0001605737052159384
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 923]
# Erro de Treinamento: 0.14716220145055559
# Erro de Validação: 3.7747729948023334e-05
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 924]
# Erro de Treinamento: 0.025374930646648863
# Erro de Validação: 0.00015426021127495915
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 925]
# Erro de Treinamento: 0.030914591618056875
# Erro de Validação: 5.123788650962524e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 926]
# Erro de Treinamento: 0.030349224762176163
# Erro de Validação: 5.652153413393535e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 927]
# Erro de Treinamento: 0.0043602596706477925
# Erro de Validação: 0.00010834488784894347
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 928]
# Erro de Treinamento: 0.017076818796340376
# Erro de Validação: 7.044597441563383e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 929]
# Erro de Treinamento: 0.009467049385420978
# Erro de Validação: 6.31473449175246e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 930]
# Erro de Treinamento: 0.012449629852198996
# Erro de Validação: 7.481563807232305e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 931]
# Erro de Treinamento: 0.008274983592855278
# Erro de Validação: 7.042625657049939e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 932]
# Erro de Treinamento: 0.006489550774858799
# Erro de Validação: 6.190562999108806e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 933]
# Erro de Treinamento: 0.008461659381282516
# Erro de Validação: 6.676257908111438e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 934]
# Erro de Treinamento: 0.007403943920508027
# Erro de Validação: 6.831208884250373e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 935]
# Erro de Treinamento: 0.006752009296178585
# Erro de Validação: 6.859008863102645e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 936]
# Erro de Treinamento: 0.008590651006670669
# Erro de Validação: 6.655378820141777e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 937]
# Erro de Treinamento: 0.007963139723869972
# Erro de Validação: 6.375269731506705e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 938]
# Erro de Treinamento: 0.009488454496022314
# Erro de Validação: 5.750525451730937e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 939]
# Erro de Treinamento: 0.006659430859144777
# Erro de Validação: 5.850797242601402e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 940]
# Erro de Treinamento: 0.009711061040434288
# Erro de Validação: 5.236975266598165e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 941]
# Erro de Treinamento: 0.00844124453215045
# Erro de Validação: 5.001556928618811e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 942]
# Erro de Treinamento: 0.012232746856170706
# Erro de Validação: 4.464200173970312e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 943]
# Erro de Treinamento: 0.006616730428504525
# Erro de Validação: 4.5774122554576024e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 944]
# Erro de Treinamento: 0.0077113537954573985
# Erro de Validação: 4.668775727623142e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 945]
# Erro de Treinamento: 0.0069251988315954804
# Erro de Validação: 4.2466414015507326e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 946]
# Erro de Treinamento: 0.006377386176609434
# Erro de Validação: 3.8989946915535256e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 947]
# Erro de Treinamento: 0.007590035960674868
# Erro de Validação: 3.9436821680283174e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 948]
# Erro de Treinamento: 0.00956390442661359
# Erro de Validação: 4.053923476021737e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 949]
# Erro de Treinamento: 0.0065355580591131
# Erro de Validação: 3.4549790143501014e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 950]
# Erro de Treinamento: 0.008300610807054909
# Erro de Validação: 3.486755667836405e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 951]
# Erro de Treinamento: 0.006598112721349025
# Erro de Validação: 3.750959149328992e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 952]
# Erro de Treinamento: 0.007484378555091098
# Erro de Validação: 3.2414023735327646e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 953]
# Erro de Treinamento: 0.007065448226057924
# Erro de Validação: 3.200671562808566e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 954]
# Erro de Treinamento: 0.006069362954804092
# Erro de Validação: 3.2900639780564234e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 955]
# Erro de Treinamento: 0.006927858048584312
# Erro de Validação: 3.2105966965900734e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 956]
# Erro de Treinamento: 0.00814854766940698
# Erro de Validação: 2.994054193550255e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 957]
# Erro de Treinamento: 0.006577063321401511
# Erro de Validação: 3.0238488761824556e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 958]
# Erro de Treinamento: 0.008416789660259383
# Erro de Validação: 2.8907432351843454e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 959]
# Erro de Treinamento: 0.01322569669719087
# Erro de Validação: 2.827168100338895e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 960]
# Erro de Treinamento: 0.010096850688569248
# Erro de Validação: 2.66227525571594e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 961]
# Erro de Treinamento: 0.009123691039803816
# Erro de Validação: 3.0913808586774394e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 962]
# Erro de Treinamento: 0.0083870068192482
# Erro de Validação: 2.600684638309758e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 963]
# Erro de Treinamento: 0.01098661828746117
# Erro de Validação: 2.513270010240376e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 964]
# Erro de Treinamento: 0.021224151307251304
# Erro de Validação: 2.4735350962146185e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 965]
# Erro de Treinamento: 0.03291939222981455
# Erro de Validação: 2.430822678434197e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 966]
# Erro de Treinamento: 0.0068902015627827495
# Erro de Validação: 0.000258796353591606
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 967]
# Erro de Treinamento: 0.07579050758158701
# Erro de Validação: 2.4814829885144718e-05
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 968]
# Erro de Treinamento: 0.025495973193756072
# Erro de Validação: 2.8271817427594215e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 969]
# Erro de Treinamento: 0.02012726981774904
# Erro de Validação: 4.687459659180604e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 970]
# Erro de Treinamento: 0.037188401071034605
# Erro de Validação: 2.6265159249305725e-05
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 971]
# Erro de Treinamento: 0.007655031844478799
# Erro de Validação: 2.685120671230834e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 972]
# Erro de Treinamento: 0.009335071117675398
# Erro de Validação: 3.314866262371652e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 973]
# Erro de Treinamento: 0.007594458540552296
# Erro de Validação: 2.788425626931712e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 974]
# Erro de Treinamento: 0.007720489928033203
# Erro de Validação: 2.6851244911085814e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 975]
# Erro de Treinamento: 0.008887044033144775
# Erro de Validação: 2.673201379366219e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 976]
# Erro de Treinamento: 0.005198586919505033
# Erro de Validação: 3.197658952558413e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 977]
# Erro de Treinamento: 0.010455119547259528
# Erro de Validação: 2.719883377721999e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 978]
# Erro de Treinamento: 0.006478969635281828
# Erro de Validação: 2.5917512175510637e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 979]
# Erro de Treinamento: 0.012931650227983482
# Erro de Validação: 3.020849726453889e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 980]
# Erro de Treinamento: 0.008291039266623557
# Erro de Validação: 2.557968400651589e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 981]
# Erro de Treinamento: 0.006273961771512404
# Erro de Validação: 2.455656613165047e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 982]
# Erro de Treinamento: 0.008488689192745369
# Erro de Validação: 2.7774864065577276e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 983]
# Erro de Treinamento: 0.008511795649610576
# Erro de Validação: 2.557963307481259e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 984]
# Erro de Treinamento: 0.010948847066174494
# Erro de Validação: 2.3364513253909536e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 985]
# Erro de Treinamento: 0.014072282599954633
# Erro de Validação: 2.3086386136128567e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 986]
# Erro de Treinamento: 0.005297490280099737
# Erro de Validação: 2.7327814677846618e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 987]
# Erro de Treinamento: 0.008164193550328491
# Erro de Validação: 2.5430585083086044e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 988]
# Erro de Treinamento: 0.0059801506458825315
# Erro de Validação: 2.2132737285573967e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 989]
# Erro de Treinamento: 0.009917054515426571
# Erro de Validação: 2.288765062985476e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 990]
# Erro de Treinamento: 0.007050945698210853
# Erro de Validação: 2.5212017135345377e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 991]
# Erro de Treinamento: 0.008846508226270089
# Erro de Validação: 2.2857826479594223e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 992]
# Erro de Treinamento: 0.016693538290383003
# Erro de Validação: 2.1993617338011973e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 993]
# Erro de Treinamento: 0.01794130505004432
# Erro de Validação: 2.6582760256133042e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 994]
# Erro de Treinamento: 0.0068135691681163735
# Erro de Validação: 2.2391041056835093e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 995]
# Erro de Treinamento: 0.020234705494658556
# Erro de Validação: 2.073205541819334e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 996]
# Erro de Treinamento: 0.014911784961668673
# Erro de Validação: 2.4774913981673308e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 997]
# Erro de Treinamento: 0.009913434862028225
# Erro de Validação: 2.026518814091105e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 998]
# Erro de Treinamento: 0.006028692690506432
# Erro de Validação: 2.146711813111324e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 999]
# Erro de Treinamento: 0.008339590560353827
# Erro de Validação: 2.194391709053889e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0

# %%
# Plotando as curvas de perda para treino e validação
plt.plot(train_loss_all_epoch, label='Treino')
plt.plot(val_loss_all_epoch, label='Validação')

# Adicionando título e rótulos aos eixos
plt.title('Curva de Perda por Época', fontsize=14)
plt.xlabel('Épocas', fontsize=12)
plt.ylabel('Perda (Loss)', fontsize=12)

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True, linestyle='--', alpha=0.7)  # Adicionando grade
plt.tight_layout()  # Ajuste para não cortar o gráfico
plt.show()

# %%
# Plotando as curvas de acuracia para treino e validação
plt.plot(train_accuracy_all_epoch, label='Treino')
plt.plot(val_accuracy_all_epoch, label='Validação')

# Adicionando título e rótulos aos eixos
plt.title('Curva de Acuracia por Época', fontsize=14)
plt.xlabel('Épocas', fontsize=12)
plt.ylabel('Perda (Loss)', fontsize=12)

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True, linestyle='--', alpha=0.7)  # Adicionando grade
plt.tight_layout()  # Ajuste para não cortar o gráfico
plt.show()

# %%
net.train(False)
for data in data_test:
    x_test, y_test = data
    x_test = x_test.to(torch.float32)
    y_pred = net(x_test)
    y_pred = torch.Tensor.argmax(y_pred, dim=1)
    cm = confusion_matrix(y_test, y_pred, labels=range(3))

# Exibindo a matriz de confusão graficamente
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['sedosa', 'versicolor', 'virginica'])
fig, ax = plt.subplots(figsize=(4, 4))
disp.plot(ax=ax, cmap='Blues', colorbar=False)

# Melhorando o gráfico
ax.set_title('Matriz de Confusão para Dados de Treino', fontsize=14)
ax.set_xlabel('Classe Predita', fontsize=12)
ax.set_ylabel('Classe Verdadeira', fontsize=12)

plt.tight_layout()
plt.show()

# %%
# Colocando o modelo em modo de avaliação (desabilita dropout, batchnorm, etc.)
net.eval()

# Percorrendo os dados de teste
for data in data_test:
    x_test, y_test = data

    # Garantindo que os dados estejam no formato correto (float32)
    x_test = x_test.to(torch.float32)

    # Realizando a previsão
    with torch.no_grad():  # Desabilita o cálculo de gradientes durante a avaliação
        y_pred = net(x_test)
        # Convertendo as predições para as classes com maior probabilidade
        y_pred = torch.argmax(y_pred, dim=1)

    # Convertendo para arrays NumPy ou listas para usar com classification_report
    y_test = y_test.cpu().numpy() if isinstance(y_test, torch.Tensor) else y_test
    y_pred = y_pred.cpu().numpy() if isinstance(y_pred, torch.Tensor) else y_pred

    # Calculando e imprimindo o relatório de classificação
    print(classification_report(y_test, y_pred, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       0.91      0.91      0.91        11
#            2       0.90      0.90      0.90        10
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.94      0.94        30
# weighted avg       0.93      0.93      0.93        30
