# %%
# Importando as libs que iremos usar
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# ## DATASET
# - Importando o dataset que iremos usar

# %%
# Dataset Iris
from sklearn.datasets import load_iris

# Carrega o Dataset
input_data = load_iris()

print(f"Base de dados com {len(input_data['data'])} linhas")
# Out:
# Base de dados com 150 linhas

# %% [markdown]
# - Separa os dados e as labels

# %%
# Principio do Aprendizado de Maquina Supervisionado
data = input_data['data']
labels = input_data['target']

# %% [markdown]
# - Dividindo dados para o processo de *treino*, *teste* e *validação*

# %%
data_train, data_test, labels_train, labels_test = train_test_split(data, labels,
                                                                    test_size=0.2, 
                                                                    random_state=41)

data_train, data_validation, labels_train, labels_validation = train_test_split(data_train, labels_train,
                                                                                test_size=0.1,
                                                                                random_state=1)

print(f'Quantidade de Dados para Treinamento : {len(data_train)}')
print(f'Quantidade de Dados para Validação : {len(data_test)}')
print(f'Quantidade de Dados para Teste : {len(data_validation)}')
# Out:
# Quantidade de Dados para Treinamento : 108
# Quantidade de Dados para Validação : 30
# Quantidade de Dados para Teste : 12

# %%
# Construindo a classe que será usada pelo Torch para acessar o dataset
class DataSet(torch.utils.data.Dataset):
    def __init__(self,data,labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self,idx):
        return self.data[idx], self.labels[idx]

# %%
# Carregando nossos datasets de treino, teste e validação
dataset = DataSet(data_train,labels_train)
data_train = DataLoader(dataset, batch_size=32, shuffle=True, num_workers=0)

dataset = DataSet(data_validation,labels_validation)
data_validation = DataLoader(dataset, batch_size=len(data_validation), shuffle=True, num_workers=0)

dataset = DataSet(data_test,labels_test)
data_test = DataLoader(dataset, batch_size=len(data_test), shuffle=True, num_workers=0)

# %% [markdown]
# ## Modelo de Rede
# - 4 Entradas (4 Caracteristicas da Flor)
# - 2 CAMADAS de Neuronios ocultos
# - 3 Saídas (3 Rotulos de Flor)

# %%
class IrisClassifier(nn.Module) :
    def __init__(self, input_size = 4, 
                 hidden_size1=20, 
                 hidden_size2 = 10, 
                 output_size = 3) :
        
        super().__init__()
        # Camada de entrada --> Primeira camada oculta
        self.fc1 = nn.Linear(input_size, hidden_size1)
        # Primeira camada oculta --> Segunda camada oculta
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        # Segunda camada oculta --> Camada de saída
        self.output = nn.Linear(hidden_size2, output_size)
        # Função de ativação
        self.relu = nn.ReLU()

    # Fluxo dos dados da entrada para saída
    def forward(self, data) :
        data = self.relu(self.fc1(data))
        data = self.relu(self.fc2(data))
        data = self.output(data)
        return data

# %% [markdown]
# ## Instanciando e configurando a rede

# %%
net = IrisClassifier()
learning_rate = 0.01
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)

# %%
# Processo de treino
def train_one_epoch(model,loss_function,optimizer,data_train):
    model.train()
    current_loss = 0.0
    current_accuracy = 0.0
    total_samples = 0

    for i,data in enumerate(data_train):
        x,y = data
        x = x.to(torch.float)
        optimizer.zero_grad()
        output = model(x)
        loss = loss_function(output,y)
        loss.backward()
        optimizer.step()
        current_loss += loss.item()

        output = output.argmax(dim=1)
        batch_accuracy = torch.eq(output,y)
        batch_accuracy = batch_accuracy.sum()
        current_accuracy += batch_accuracy
        total_samples += len(x)
    return current_loss/(i+1), current_accuracy/total_samples

# %%
# Processo de validação
def validation_one_epoch(model,loss_function, data_validation):
    model.train(False)
    current_loss = 0.0
    current_accuracy = 0.0
    total_samples = 0
    for i,data in enumerate(data_validation):
        x,y = data
        x = x.to(torch.float)
        output = model(x)
        loss = loss_function(output,y)
        current_loss += loss.item()

        output = output.argmax(dim=1)
        batch_accuracy = torch.eq(output,y)
        batch_accuracy = batch_accuracy.sum()
        current_accuracy += batch_accuracy
        total_samples += len(x)
    return current_loss/(i+1), current_accuracy/total_samples

# %% [markdown]
# ## Executando

# %%
epochs = 1000
train_loss_all_epoch = []
train_accuracy_all_epoch = []
val_loss_all_epoch = []
val_accuracy_all_epoch = []
best_val_loss = 1e9

for epoch in range(epochs):

    train_loss_per_epoch, train_accuracy_per_epoch = train_one_epoch(net,criterion,optimizer,data_train)

    train_loss_all_epoch.append(train_loss_per_epoch)
    train_accuracy_all_epoch.append(train_accuracy_per_epoch)

    val_loss_per_epoch,val_accuracy_per_epoch = validation_one_epoch(net,criterion, data_validation)

    val_loss_all_epoch.append(val_loss_per_epoch)
    val_accuracy_all_epoch.append(val_accuracy_per_epoch)

    # Salva o melhor modelo
    if val_loss_per_epoch < best_val_loss:
      best_val_loss = val_loss_per_epoch
      model_path = 'best_model_iris'
      torch.save(net.state_dict(),model_path)

    if(epoch % 1 == 0) :
      print(f'Epóca [: {epoch}]')
      print(f'Erro de Treinamento: {train_loss_per_epoch}')
      print(f'Erro de Validação: {val_loss_per_epoch}')
      print(f'Acurácia de Treinamento: {train_accuracy_per_epoch}')
      print(f'Acurácia de Validação: {val_accuracy_per_epoch}')
      print()
# Out:
# Epóca [: 0]
# Erro de Treinamento: 0.9828659147024155
# Erro de Validação: 0.9309239983558655
# Acurácia de Treinamento: 0.3333333432674408
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 1]
# Erro de Treinamento: 0.8786186724901199
# Erro de Validação: 0.8513231873512268
# Acurácia de Treinamento: 0.6666666865348816
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 2]
# Erro de Treinamento: 0.8041624426841736
# Erro de Validação: 0.7923710346221924
# Acurácia de Treinamento: 0.6851851940155029
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 3]
# Erro de Treinamento: 0.7616578489542007
# Erro de Validação: 0.7347846627235413
# Acurácia de Treinamento: 0.6851851940155029
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 4]
# Erro de Treinamento: 0.7247608155012131
# Erro de Validação: 0.6943041682243347
# Acurácia de Treinamento: 0.6851851940155029
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 5]
# Erro de Treinamento: 0.6832872182130814
# Erro de Validação: 0.6805310249328613
# Acurácia de Treinamento: 0.6851851940155029
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 6]
# Erro de Treinamento: 0.7040776163339615
# Erro de Validação: 0.6576945781707764
# Acurácia de Treinamento: 0.6851851940155029
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 7]
# Erro de Treinamento: 0.6337205767631531
# Erro de Validação: 0.6134853363037109
# Acurácia de Treinamento: 0.8148148059844971
# Acurácia de Validação: 1.0
#
# Epóca [: 8]
# Erro de Treinamento: 0.6227387636899948
# Erro de Validação: 0.5723127126693726
# Acurácia de Treinamento: 0.8796296119689941
# Acurácia de Validação: 0.75
#
# Epóca [: 9]
# Erro de Treinamento: 0.6059900224208832
# Erro de Validação: 0.6137856245040894
# Acurácia de Treinamento: 0.7222222089767456
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 10]
# Erro de Treinamento: 0.5718832314014435
# Erro de Validação: 0.5124987959861755
# Acurácia de Treinamento: 0.7685185074806213
# Acurácia de Validação: 1.0
#
# Epóca [: 11]
# Erro de Treinamento: 0.5425786525011063
# Erro de Validação: 0.47741758823394775
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 1.0
#
# Epóca [: 12]
# Erro de Treinamento: 0.4955713748931885
# Erro de Validação: 0.461819052696228
# Acurácia de Treinamento: 0.8796296119689941
# Acurácia de Validação: 0.75
#
# Epóca [: 13]
# Erro de Treinamento: 0.46805479377508163
# Erro de Validação: 0.41050028800964355
# Acurácia de Treinamento: 0.8981481194496155
# Acurácia de Validação: 1.0
#
# Epóca [: 14]
# Erro de Treinamento: 0.4399406686425209
# Erro de Validação: 0.37571945786476135
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 15]
# Erro de Treinamento: 0.41949380934238434
# Erro de Validação: 0.31994324922561646
# Acurácia de Treinamento: 0.8981481194496155
# Acurácia de Validação: 1.0
#
# Epóca [: 16]
# Erro de Treinamento: 0.37857726216316223
# Erro de Validação: 0.28738465905189514
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 17]
# Erro de Treinamento: 0.36763644963502884
# Erro de Validação: 0.2511636018753052
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 18]
# Erro de Treinamento: 0.3300604596734047
# Erro de Validação: 0.21976129710674286
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 19]
# Erro de Treinamento: 0.3106323108077049
# Erro de Validação: 0.20227943360805511
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 20]
# Erro de Treinamento: 0.29585593938827515
# Erro de Validação: 0.18470102548599243
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 21]
# Erro de Treinamento: 0.3195979818701744
# Erro de Validação: 0.16701792180538177
# Acurácia de Treinamento: 0.9259259104728699
# Acurácia de Validação: 1.0
#
# Epóca [: 22]
# Erro de Treinamento: 0.30707794427871704
# Erro de Validação: 0.14970925450325012
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 1.0
#
# Epóca [: 23]
# Erro de Treinamento: 0.24924802780151367
# Erro de Validação: 0.21002097427845
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 24]
# Erro de Treinamento: 0.26876235380768776
# Erro de Validação: 0.1586751639842987
# Acurácia de Treinamento: 0.9351851940155029
# Acurácia de Validação: 1.0
#
# Epóca [: 25]
# Erro de Treinamento: 0.22982456907629967
# Erro de Validação: 0.12927687168121338
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 26]
# Erro de Treinamento: 0.23363195732235909
# Erro de Validação: 0.11385190486907959
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 27]
# Erro de Treinamento: 0.2148284576833248
# Erro de Validação: 0.11084768921136856
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 28]
# Erro de Treinamento: 0.1919599287211895
# Erro de Validação: 0.1086956188082695
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 29]
# Erro de Treinamento: 0.18342338874936104
# Erro de Validação: 0.10231071710586548
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 30]
# Erro de Treinamento: 0.18161864951252937
# Erro de Validação: 0.0896022841334343
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 31]
# Erro de Treinamento: 0.16362841054797173
# Erro de Validação: 0.08452709764242172
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 32]
# Erro de Treinamento: 0.1471146009862423
# Erro de Validação: 0.08058055490255356
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 33]
# Erro de Treinamento: 0.14283418282866478
# Erro de Validação: 0.07661475986242294
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 34]
# Erro de Treinamento: 0.1349163055419922
# Erro de Validação: 0.0726347342133522
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 35]
# Erro de Treinamento: 0.13956014439463615
# Erro de Validação: 0.06905607134103775
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 36]
# Erro de Treinamento: 0.15124524757266045
# Erro de Validação: 0.06583024561405182
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 37]
# Erro de Treinamento: 0.12448352575302124
# Erro de Validação: 0.07180292904376984
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 38]
# Erro de Treinamento: 0.12287400849163532
# Erro de Validação: 0.06461667269468307
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 39]
# Erro de Treinamento: 0.13676655292510986
# Erro de Validação: 0.05816133692860603
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 40]
# Erro de Treinamento: 0.11834601126611233
# Erro de Validação: 0.05965689942240715
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 41]
# Erro de Treinamento: 0.11977047845721245
# Erro de Validação: 0.05364532396197319
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 42]
# Erro de Treinamento: 0.13401388749480247
# Erro de Validação: 0.051473382860422134
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 43]
# Erro de Treinamento: 0.13290325459092855
# Erro de Validação: 0.052054282277822495
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 44]
# Erro de Treinamento: 0.09666414838284254
# Erro de Validação: 0.05517008900642395
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 45]
# Erro de Treinamento: 0.11634033545851707
# Erro de Validação: 0.050794120877981186
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 46]
# Erro de Treinamento: 0.13258580677211285
# Erro de Validação: 0.044775333255529404
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 47]
# Erro de Treinamento: 0.1318657286465168
# Erro de Validação: 0.044556159526109695
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 48]
# Erro de Treinamento: 0.10536756180226803
# Erro de Validação: 0.04856410622596741
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 49]
# Erro de Treinamento: 0.099333256483078
# Erro de Validação: 0.04407156631350517
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 50]
# Erro de Treinamento: 0.11405270546674728
# Erro de Validação: 0.04052384942770004
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 51]
# Erro de Treinamento: 0.10642402432858944
# Erro de Validação: 0.03850919380784035
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 52]
# Erro de Treinamento: 0.11520438082516193
# Erro de Validação: 0.03726836293935776
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 53]
# Erro de Treinamento: 0.07921388372778893
# Erro de Validação: 0.04408584162592888
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 54]
# Erro de Treinamento: 0.10194798093289137
# Erro de Validação: 0.036039236932992935
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 55]
# Erro de Treinamento: 0.09759357664734125
# Erro de Validação: 0.03808263689279556
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 56]
# Erro de Treinamento: 0.09282143227756023
# Erro de Validação: 0.033152490854263306
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 57]
# Erro de Treinamento: 0.08422239311039448
# Erro de Validação: 0.032141268253326416
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 58]
# Erro de Treinamento: 0.07317628804594278
# Erro de Validação: 0.034104958176612854
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 59]
# Erro de Treinamento: 0.07567633781582117
# Erro de Validação: 0.030478566884994507
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 60]
# Erro de Treinamento: 0.0692116105929017
# Erro de Validação: 0.029837407171726227
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 61]
# Erro de Treinamento: 0.07798354793339968
# Erro de Validação: 0.029526839032769203
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 62]
# Erro de Treinamento: 0.07149559911340475
# Erro de Validação: 0.02809436433017254
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 63]
# Erro de Treinamento: 0.0763830803334713
# Erro de Validação: 0.027346739545464516
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 64]
# Erro de Treinamento: 0.07563892379403114
# Erro de Validação: 0.028537780046463013
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 65]
# Erro de Treinamento: 0.06325269304215908
# Erro de Validação: 0.026234768331050873
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 66]
# Erro de Treinamento: 0.08332519326359034
# Erro de Validação: 0.025920314714312553
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 67]
# Erro de Treinamento: 0.07013365440070629
# Erro de Validação: 0.02495371736586094
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 68]
# Erro de Treinamento: 0.06789890769869089
# Erro de Validação: 0.02430584281682968
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 69]
# Erro de Treinamento: 0.055960085708647966
# Erro de Validação: 0.024556444957852364
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 70]
# Erro de Treinamento: 0.059466104954481125
# Erro de Validação: 0.023164553567767143
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 71]
# Erro de Treinamento: 0.06391016766428947
# Erro de Validação: 0.02269347570836544
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 72]
# Erro de Treinamento: 0.06570414826273918
# Erro de Validação: 0.022805050015449524
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 73]
# Erro de Treinamento: 0.06565587408840656
# Erro de Validação: 0.021915815770626068
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 74]
# Erro de Treinamento: 0.07383846025913954
# Erro de Validação: 0.021158277988433838
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 75]
# Erro de Treinamento: 0.06911628879606724
# Erro de Validação: 0.02184433676302433
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 76]
# Erro de Treinamento: 0.04834208358079195
# Erro de Validação: 0.020702295005321503
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 77]
# Erro de Treinamento: 0.09438881650567055
# Erro de Validação: 0.024510949850082397
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 78]
# Erro de Treinamento: 0.12706913333386183
# Erro de Validação: 0.019639182835817337
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 1.0
#
# Epóca [: 79]
# Erro de Treinamento: 0.06415107706561685
# Erro de Validação: 0.01943385973572731
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 80]
# Erro de Treinamento: 0.0891574346460402
# Erro de Validação: 0.019327057525515556
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 81]
# Erro de Treinamento: 0.04760759603232145
# Erro de Validação: 0.019187504425644875
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 82]
# Erro de Treinamento: 0.05442337691783905
# Erro de Validação: 0.023043347522616386
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 83]
# Erro de Treinamento: 0.07321098074316978
# Erro de Validação: 0.018531247973442078
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 84]
# Erro de Treinamento: 0.09443482011556625
# Erro de Validação: 0.017852110788226128
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 85]
# Erro de Treinamento: 0.05480432137846947
# Erro de Validação: 0.029467681422829628
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 86]
# Erro de Treinamento: 0.07841203641146421
# Erro de Validação: 0.01836252026259899
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 87]
# Erro de Treinamento: 0.07762461574748158
# Erro de Validação: 0.017029011622071266
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 88]
# Erro de Treinamento: 0.04864506656304002
# Erro de Validação: 0.02064458653330803
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 89]
# Erro de Treinamento: 0.062069996260106564
# Erro de Validação: 0.01641635037958622
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 90]
# Erro de Treinamento: 0.05027785012498498
# Erro de Validação: 0.016243821009993553
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 91]
# Erro de Treinamento: 0.05126904556527734
# Erro de Validação: 0.016723843291401863
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 92]
# Erro de Treinamento: 0.07074029231444001
# Erro de Validação: 0.015469525009393692
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 93]
# Erro de Treinamento: 0.06918914150446653
# Erro de Validação: 0.015541831962764263
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 94]
# Erro de Treinamento: 0.0458901422098279
# Erro de Validação: 0.017152689397335052
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 95]
# Erro de Treinamento: 0.05865622451528907
# Erro de Validação: 0.014745195396244526
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 96]
# Erro de Treinamento: 0.045638732612133026
# Erro de Validação: 0.014808944426476955
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 97]
# Erro de Treinamento: 0.04181414330378175
# Erro de Validação: 0.014249186031520367
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 98]
# Erro de Treinamento: 0.04249584162607789
# Erro de Validação: 0.014911198057234287
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 99]
# Erro de Treinamento: 0.038493291824124753
# Erro de Validação: 0.014067195355892181
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 100]
# Erro de Treinamento: 0.05490423692390323
# Erro de Validação: 0.013891792856156826
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 101]
# Erro de Treinamento: 0.05569201009348035
# Erro de Validação: 0.013749542646110058
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 102]
# Erro de Treinamento: 0.04235335672274232
# Erro de Validação: 0.013228158466517925
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 103]
# Erro de Treinamento: 0.044139331206679344
# Erro de Validação: 0.01361472625285387
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 104]
# Erro de Treinamento: 0.04890393512323499
# Erro de Validação: 0.013002258725464344
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 105]
# Erro de Treinamento: 0.08161471085622907
# Erro de Validação: 0.01303411740809679
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 106]
# Erro de Treinamento: 0.0802967268973589
# Erro de Validação: 0.01330992579460144
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 107]
# Erro de Treinamento: 0.09234189195558429
# Erro de Validação: 0.012465623207390308
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 108]
# Erro de Treinamento: 0.09728463273495436
# Erro de Validação: 0.012774355709552765
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 109]
# Erro de Treinamento: 0.034133181208744645
# Erro de Validação: 0.01710752211511135
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 110]
# Erro de Treinamento: 0.09456102689728141
# Erro de Validação: 0.01383302267640829
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 111]
# Erro de Treinamento: 0.07417117711156607
# Erro de Validação: 0.0128016984090209
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 112]
# Erro de Treinamento: 0.06449614372104406
# Erro de Validação: 0.011873858980834484
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 113]
# Erro de Treinamento: 0.0458293198607862
# Erro de Validação: 0.012589730322360992
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 114]
# Erro de Treinamento: 0.042141702957451344
# Erro de Validação: 0.01168650109320879
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 115]
# Erro de Treinamento: 0.057201874908059835
# Erro de Validação: 0.01145754661411047
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 116]
# Erro de Treinamento: 0.05171139212325215
# Erro de Validação: 0.01206071674823761
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 117]
# Erro de Treinamento: 0.03820144338533282
# Erro de Validação: 0.0111464262008667
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 118]
# Erro de Treinamento: 0.04560316354036331
# Erro de Validação: 0.010823555290699005
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 119]
# Erro de Treinamento: 0.03558515012264252
# Erro de Validação: 0.01173236221075058
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 120]
# Erro de Treinamento: 0.0377533258870244
# Erro de Validação: 0.011163364164531231
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 121]
# Erro de Treinamento: 0.04094527941197157
# Erro de Validação: 0.0103093096986413
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 122]
# Erro de Treinamento: 0.07540612248703837
# Erro de Validação: 0.010187556967139244
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 123]
# Erro de Treinamento: 0.052769051399081945
# Erro de Validação: 0.011937149800360203
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 124]
# Erro de Treinamento: 0.0360923265106976
# Erro de Validação: 0.009958527982234955
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 125]
# Erro de Treinamento: 0.05171340657398105
# Erro de Validação: 0.009893729351460934
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 126]
# Erro de Treinamento: 0.048348420299589634
# Erro de Validação: 0.010245402343571186
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 127]
# Erro de Treinamento: 0.06187686137855053
# Erro de Validação: 0.00962523277848959
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 128]
# Erro de Treinamento: 0.029498972231522202
# Erro de Validação: 0.013585376553237438
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 129]
# Erro de Treinamento: 0.05073551321402192
# Erro de Validação: 0.00939201470464468
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 130]
# Erro de Treinamento: 0.04083807813003659
# Erro de Validação: 0.009360902942717075
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 131]
# Erro de Treinamento: 0.031112337484955788
# Erro de Validação: 0.009956425987184048
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 132]
# Erro de Treinamento: 0.033849469386041164
# Erro de Validação: 0.009070227853953838
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 133]
# Erro de Treinamento: 0.03814441338181496
# Erro de Validação: 0.008961464278399944
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 134]
# Erro de Treinamento: 0.039083142299205065
# Erro de Validação: 0.008975268341600895
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 135]
# Erro de Treinamento: 0.048968499060720205
# Erro de Validação: 0.008939187042415142
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 136]
# Erro de Treinamento: 0.04291017400100827
# Erro de Validação: 0.009258152917027473
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 137]
# Erro de Treinamento: 0.03345475951209664
# Erro de Validação: 0.008534408174455166
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 138]
# Erro de Treinamento: 0.030166818294674158
# Erro de Validação: 0.008484202437102795
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 139]
# Erro de Treinamento: 0.03506595827639103
# Erro de Validação: 0.008592029102146626
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 140]
# Erro de Treinamento: 0.03901723073795438
# Erro de Validação: 0.00828054640442133
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 141]
# Erro de Treinamento: 0.030688056722283363
# Erro de Validação: 0.008139044977724552
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 142]
# Erro de Treinamento: 0.032586155692115426
# Erro de Validação: 0.008680010214447975
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 143]
# Erro de Treinamento: 0.03378641093149781
# Erro de Validação: 0.007953737862408161
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 144]
# Erro de Treinamento: 0.026624780148267746
# Erro de Validação: 0.007850000634789467
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 145]
# Erro de Treinamento: 0.030823023640550673
# Erro de Validação: 0.00849184487015009
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 146]
# Erro de Treinamento: 0.037214942276477814
# Erro de Validação: 0.007703202310949564
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 147]
# Erro de Treinamento: 0.05729192914441228
# Erro de Validação: 0.0075680906884372234
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 148]
# Erro de Treinamento: 0.019473868422210217
# Erro de Validação: 0.011017613112926483
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 149]
# Erro de Treinamento: 0.0782815981656313
# Erro de Validação: 0.00742548331618309
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 150]
# Erro de Treinamento: 0.0316264929715544
# Erro de Validação: 0.007405667100101709
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 151]
# Erro de Treinamento: 0.02485617366619408
# Erro de Validação: 0.007473568897694349
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 152]
# Erro de Treinamento: 0.03144581476226449
# Erro de Validação: 0.007324334233999252
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 153]
# Erro de Treinamento: 0.030068767722696066
# Erro de Validação: 0.007175919134169817
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 154]
# Erro de Treinamento: 0.03274722793139517
# Erro de Validação: 0.00724188843742013
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 155]
# Erro de Treinamento: 0.038611707277596
# Erro de Validação: 0.007029757369309664
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 156]
# Erro de Treinamento: 0.04857898596674204
# Erro de Validação: 0.006901262328028679
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 157]
# Erro de Treinamento: 0.06914376188069582
# Erro de Validação: 0.006910805124789476
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 158]
# Erro de Treinamento: 0.14458445692434907
# Erro de Validação: 0.006796248722821474
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 159]
# Erro de Treinamento: 0.03898437600582838
# Erro de Validação: 0.03881879895925522
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 160]
# Erro de Treinamento: 0.11475144186988473
# Erro de Validação: 0.007153376936912537
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 1.0
#
# Epóca [: 161]
# Erro de Treinamento: 0.07452561380341649
# Erro de Validação: 0.007495983969420195
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 162]
# Erro de Treinamento: 0.09772638091817498
# Erro de Validação: 0.007679934147745371
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 163]
# Erro de Treinamento: 0.05757575901225209
# Erro de Validação: 0.008057334460318089
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 164]
# Erro de Treinamento: 0.06897545792162418
# Erro de Validação: 0.007556309457868338
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 165]
# Erro de Treinamento: 0.04028383269906044
# Erro de Validação: 0.008283007889986038
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 166]
# Erro de Treinamento: 0.04086546506732702
# Erro de Validação: 0.006832069251686335
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 167]
# Erro de Treinamento: 0.03742087888531387
# Erro de Validação: 0.00691160699352622
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 168]
# Erro de Treinamento: 0.02453509997576475
# Erro de Validação: 0.006724663078784943
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 169]
# Erro de Treinamento: 0.02734827995300293
# Erro de Validação: 0.006663335952907801
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 170]
# Erro de Treinamento: 0.027103789849206805
# Erro de Validação: 0.00649290019646287
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 171]
# Erro de Treinamento: 0.026254542637616396
# Erro de Validação: 0.006328750401735306
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 172]
# Erro de Treinamento: 0.024024044163525105
# Erro de Validação: 0.006337419617921114
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 173]
# Erro de Treinamento: 0.022698808228597045
# Erro de Validação: 0.006108460947871208
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 174]
# Erro de Treinamento: 0.024661435279995203
# Erro de Validação: 0.006047592964023352
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 175]
# Erro de Treinamento: 0.02666456811130047
# Erro de Validação: 0.006074173375964165
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 176]
# Erro de Treinamento: 0.02563093858771026
# Erro de Validação: 0.006125403102487326
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 177]
# Erro de Treinamento: 0.02867498667910695
# Erro de Validação: 0.005813177675008774
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 178]
# Erro de Treinamento: 0.021749042090959847
# Erro de Validação: 0.005908393766731024
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 179]
# Erro de Treinamento: 0.025228510843589902
# Erro de Validação: 0.005758529994636774
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 180]
# Erro de Treinamento: 0.02159526152536273
# Erro de Validação: 0.005630916450172663
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 181]
# Erro de Treinamento: 0.02212978294119239
# Erro de Validação: 0.005761572625488043
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 182]
# Erro de Treinamento: 0.02298261015675962
# Erro de Validação: 0.005549605470150709
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 183]
# Erro de Treinamento: 0.025571872480213642
# Erro de Validação: 0.005477725062519312
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 184]
# Erro de Treinamento: 0.026307139080017805
# Erro de Validação: 0.005523333791643381
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 185]
# Erro de Treinamento: 0.03398520010523498
# Erro de Validação: 0.005358489230275154
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 186]
# Erro de Treinamento: 0.02019330789335072
# Erro de Validação: 0.005571820307523012
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 187]
# Erro de Treinamento: 0.03236631280742586
# Erro de Validação: 0.005221377592533827
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 188]
# Erro de Treinamento: 0.06451058969832957
# Erro de Validação: 0.005173146724700928
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 189]
# Erro de Treinamento: 0.017204574774950743
# Erro de Validação: 0.007185040507465601
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 190]
# Erro de Treinamento: 0.04908073216211051
# Erro de Validação: 0.0051600574515759945
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 191]
# Erro de Treinamento: 0.036047938745468855
# Erro de Validação: 0.005092366132885218
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 192]
# Erro de Treinamento: 0.04730560933239758
# Erro de Validação: 0.005267662461847067
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 193]
# Erro de Treinamento: 0.019352510571479797
# Erro de Validação: 0.005029984749853611
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 194]
# Erro de Treinamento: 0.03748383850324899
# Erro de Validação: 0.00506386486813426
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 195]
# Erro de Treinamento: 0.021920430939644575
# Erro de Validação: 0.006085832137614489
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 196]
# Erro de Treinamento: 0.03283369354903698
# Erro de Validação: 0.004918936174362898
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 197]
# Erro de Treinamento: 0.049637154676020145
# Erro de Validação: 0.004897385835647583
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 198]
# Erro de Treinamento: 0.02313075214624405
# Erro de Validação: 0.006238266360014677
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 199]
# Erro de Treinamento: 0.04144346807152033
# Erro de Validação: 0.0048173400573432446
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 200]
# Erro de Treinamento: 0.0320381629280746
# Erro de Validação: 0.004874793812632561
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 201]
# Erro de Treinamento: 0.036502925446256995
# Erro de Validação: 0.004847416654229164
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 202]
# Erro de Treinamento: 0.024983915500342846
# Erro de Validação: 0.004716698545962572
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 203]
# Erro de Treinamento: 0.030032805632799864
# Erro de Validação: 0.0047816005535423756
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 204]
# Erro de Treinamento: 0.027550960425287485
# Erro de Validação: 0.004737724084407091
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 205]
# Erro de Treinamento: 0.02413313719443977
# Erro de Validação: 0.0045899092219769955
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 206]
# Erro de Treinamento: 0.02782614785246551
# Erro de Validação: 0.004629600793123245
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 207]
# Erro de Treinamento: 0.019446962047368288
# Erro de Validação: 0.004626337438821793
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 208]
# Erro de Treinamento: 0.018792115384712815
# Erro de Validação: 0.004575714003294706
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 209]
# Erro de Treinamento: 0.027779974741861224
# Erro de Validação: 0.004593702498823404
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 210]
# Erro de Treinamento: 0.04147465340793133
# Erro de Validação: 0.004425238352268934
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 211]
# Erro de Treinamento: 0.044784527737647295
# Erro de Validação: 0.00434835022315383
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 212]
# Erro de Treinamento: 0.020452423254027963
# Erro de Validação: 0.004929954651743174
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 213]
# Erro de Treinamento: 0.03817734797485173
# Erro de Validação: 0.004411404021084309
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 214]
# Erro de Treinamento: 0.0235170756932348
# Erro de Validação: 0.00432233652099967
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 215]
# Erro de Treinamento: 0.021688978653401136
# Erro de Validação: 0.004240535199642181
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 216]
# Erro de Treinamento: 0.0240820701001212
# Erro de Validação: 0.004325677175074816
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 217]
# Erro de Treinamento: 0.046295314095914364
# Erro de Validação: 0.004196233116090298
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 218]
# Erro de Treinamento: 0.039811577182263136
# Erro de Validação: 0.004170271568000317
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 219]
# Erro de Treinamento: 0.01997330319136381
# Erro de Validação: 0.004579673986881971
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 220]
# Erro de Treinamento: 0.03053287835791707
# Erro de Validação: 0.004160641692578793
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 221]
# Erro de Treinamento: 0.021871379110962152
# Erro de Validação: 0.004078807309269905
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 222]
# Erro de Treinamento: 0.026901495759375393
# Erro de Validação: 0.004245660733431578
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 223]
# Erro de Treinamento: 0.0259351636050269
# Erro de Validação: 0.004024425987154245
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 224]
# Erro de Treinamento: 0.01952653704211116
# Erro de Validação: 0.003983479458838701
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 225]
# Erro de Treinamento: 0.024304999504238367
# Erro de Validação: 0.0041170683689415455
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 226]
# Erro de Treinamento: 0.028744315030053258
# Erro de Validação: 0.0039872280322015285
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 227]
# Erro de Treinamento: 0.017677095951512456
# Erro de Validação: 0.003914996515959501
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 228]
# Erro de Treinamento: 0.01758252934087068
# Erro de Validação: 0.004000640939921141
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 229]
# Erro de Treinamento: 0.029799326788634062
# Erro de Validação: 0.0038547127041965723
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 230]
# Erro de Treinamento: 0.02321280271280557
# Erro de Validação: 0.003809129586443305
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 231]
# Erro de Treinamento: 0.02281399886123836
# Erro de Validação: 0.0039819697849452496
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 232]
# Erro de Treinamento: 0.02517793234437704
# Erro de Validação: 0.0037691928446292877
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 233]
# Erro de Treinamento: 0.016325881937518716
# Erro de Validação: 0.0037152376025915146
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 234]
# Erro de Treinamento: 0.01856675837188959
# Erro de Validação: 0.0037800243590027094
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 235]
# Erro de Treinamento: 0.02085131360217929
# Erro de Validação: 0.0036700190976262093
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 236]
# Erro de Treinamento: 0.0226660129847005
# Erro de Validação: 0.0036717962939292192
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 237]
# Erro de Treinamento: 0.0178969360422343
# Erro de Validação: 0.0036635305732488632
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 238]
# Erro de Treinamento: 0.018115486367605627
# Erro de Validação: 0.003590172389522195
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 239]
# Erro de Treinamento: 0.026276372373104095
# Erro de Validação: 0.0036051999777555466
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 240]
# Erro de Treinamento: 0.018166716443374753
# Erro de Validação: 0.0036803316324949265
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 241]
# Erro de Treinamento: 0.024206151021644473
# Erro de Validação: 0.003499465761706233
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 242]
# Erro de Treinamento: 0.02358664746861905
# Erro de Validação: 0.0035763243213295937
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 243]
# Erro de Treinamento: 0.026060963748022914
# Erro de Validação: 0.003491888754069805
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 244]
# Erro de Treinamento: 0.023024830734357238
# Erro de Validação: 0.0034333153162151575
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 245]
# Erro de Treinamento: 0.026487068156711757
# Erro de Validação: 0.003765609348192811
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 246]
# Erro de Treinamento: 0.04391583299729973
# Erro de Validação: 0.003402628004550934
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 247]
# Erro de Treinamento: 0.029728592024184763
# Erro de Validação: 0.0038726439233869314
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 248]
# Erro de Treinamento: 0.055912547977641225
# Erro de Validação: 0.003614152781665325
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 249]
# Erro de Treinamento: 0.036747717997059226
# Erro de Validação: 0.0035059095825999975
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 250]
# Erro de Treinamento: 0.01763509027659893
# Erro de Validação: 0.00338603719137609
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 251]
# Erro de Treinamento: 0.019119483418762684
# Erro de Validação: 0.0034329642076045275
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 252]
# Erro de Treinamento: 0.015847935806959867
# Erro de Validação: 0.0033885035663843155
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 253]
# Erro de Treinamento: 0.014998500468209386
# Erro de Validação: 0.0033418582752346992
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 254]
# Erro de Treinamento: 0.018670706311240792
# Erro de Validação: 0.00333570153452456
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 255]
# Erro de Treinamento: 0.014301654417067766
# Erro de Validação: 0.0033306528348475695
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 256]
# Erro de Treinamento: 0.018505005398765206
# Erro de Validação: 0.003227467415854335
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 257]
# Erro de Treinamento: 0.04598361381795257
# Erro de Validação: 0.0032932646572589874
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 258]
# Erro de Treinamento: 0.04120162269100547
# Erro de Validação: 0.003858087817206979
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 259]
# Erro de Treinamento: 0.02719823457300663
# Erro de Validação: 0.0031858657021075487
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 260]
# Erro de Treinamento: 0.08308216510340571
# Erro de Validação: 0.003171744989231229
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 261]
# Erro de Treinamento: 0.044786761165596545
# Erro de Validação: 0.007116200402379036
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 262]
# Erro de Treinamento: 0.050507493724580854
# Erro de Validação: 0.0032040439546108246
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 263]
# Erro de Treinamento: 0.1336239310912788
# Erro de Validação: 0.003241487080231309
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 264]
# Erro de Treinamento: 0.13509020069614053
# Erro de Validação: 0.003996748011559248
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 265]
# Erro de Treinamento: 0.03715072269551456
# Erro de Validação: 0.003809439716860652
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 266]
# Erro de Treinamento: 0.10093782050535083
# Erro de Validação: 0.0035797879099845886
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 267]
# Erro de Treinamento: 0.022269654786214232
# Erro de Validação: 0.009697339497506618
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 268]
# Erro de Treinamento: 0.0692424587905407
# Erro de Validação: 0.0035046094562858343
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 269]
# Erro de Treinamento: 0.04079139279201627
# Erro de Validação: 0.004072419833391905
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 270]
# Erro de Treinamento: 0.06792115292046219
# Erro de Validação: 0.0036765497643500566
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 271]
# Erro de Treinamento: 0.036875848891213536
# Erro de Validação: 0.0034071241971105337
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 272]
# Erro de Treinamento: 0.01952385262120515
# Erro de Validação: 0.0032667710911482573
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 273]
# Erro de Treinamento: 0.02068004838656634
# Erro de Validação: 0.00330530502833426
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 274]
# Erro de Treinamento: 0.017376741743646562
# Erro de Validação: 0.003204919630661607
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 275]
# Erro de Treinamento: 0.02856854780111462
# Erro de Validação: 0.003092060796916485
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 276]
# Erro de Treinamento: 0.024767978582531214
# Erro de Validação: 0.0030367898289114237
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 277]
# Erro de Treinamento: 0.017866452573798597
# Erro de Validação: 0.0030222469940781593
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 278]
# Erro de Treinamento: 0.018136934144422412
# Erro de Validação: 0.0028896499425172806
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 279]
# Erro de Treinamento: 0.022885595331899822
# Erro de Validação: 0.002893036464229226
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 280]
# Erro de Treinamento: 0.017256674356758595
# Erro de Validação: 0.0029754266142845154
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 281]
# Erro de Treinamento: 0.017733316286467016
# Erro de Validação: 0.0028457995504140854
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 282]
# Erro de Treinamento: 0.01832334592472762
# Erro de Validação: 0.002829682780429721
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 283]
# Erro de Treinamento: 0.015466996235772967
# Erro de Validação: 0.002835956634953618
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 284]
# Erro de Treinamento: 0.013324290339369327
# Erro de Validação: 0.0027601139154285192
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 285]
# Erro de Treinamento: 0.021542400354519486
# Erro de Validação: 0.0027658056933432817
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 286]
# Erro de Treinamento: 0.027135160751640797
# Erro de Validação: 0.0027797056827694178
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 287]
# Erro de Treinamento: 0.02168898592935875
# Erro de Validação: 0.0026896328199654818
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 288]
# Erro de Treinamento: 0.021252221427857876
# Erro de Validação: 0.0027664725203067064
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 289]
# Erro de Treinamento: 0.01685569284018129
# Erro de Validação: 0.002664216561242938
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 290]
# Erro de Treinamento: 0.016054032545071095
# Erro de Validação: 0.0026634770911186934
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 291]
# Erro de Treinamento: 0.021215217653661966
# Erro de Validação: 0.0026434985920786858
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 292]
# Erro de Treinamento: 0.022282742662355304
# Erro de Validação: 0.002607552567496896
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 293]
# Erro de Treinamento: 0.028062025783583522
# Erro de Validação: 0.0026675534900277853
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 294]
# Erro de Treinamento: 0.01474582008086145
# ...
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 903]
# Erro de Treinamento: 0.020875880145467818
# Erro de Validação: 0.0006046205526217818
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 904]
# Erro de Treinamento: 0.01679279217205476
# Erro de Validação: 0.0005537027609534562
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 905]
# Erro de Treinamento: 0.022505534696392715
# Erro de Validação: 0.0006487668724730611
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 906]
# Erro de Treinamento: 0.01457611913792789
# Erro de Validação: 0.0006688155699521303
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 907]
# Erro de Treinamento: 0.021923099528066814
# Erro de Validação: 0.0005943845608271658
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 908]
# Erro de Treinamento: 0.016942655871389434
# Erro de Validação: 0.0007077243062667549
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 909]
# Erro de Treinamento: 0.021053200936876237
# Erro de Validação: 0.0005742853390984237
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 910]
# Erro de Treinamento: 0.028640532516874373
# Erro de Validação: 0.0005450884927995503
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 911]
# Erro de Treinamento: 0.021195627778070047
# Erro de Validação: 0.0005193979595787823
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 912]
# Erro de Treinamento: 0.019968950597103685
# Erro de Validação: 0.000653884548228234
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 913]
# Erro de Treinamento: 0.02945410693064332
# Erro de Validação: 0.0005706620868295431
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 914]
# Erro de Treinamento: 0.02828037372091785
# Erro de Validação: 0.0005154384416528046
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 915]
# Erro de Treinamento: 0.01647681836038828
# Erro de Validação: 0.0006965966895222664
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 916]
# Erro de Treinamento: 0.024841087637469172
# Erro de Validação: 0.0006290320307016373
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 917]
# Erro de Treinamento: 0.01248572242911905
# Erro de Validação: 0.0005165939219295979
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 918]
# Erro de Treinamento: 0.0175180648220703
# Erro de Validação: 0.0005496602971106768
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 919]
# Erro de Treinamento: 0.025879111577523872
# Erro de Validação: 0.0005590805667452514
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 920]
# Erro de Treinamento: 0.021493772670510225
# Erro de Validação: 0.0005066850571893156
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 921]
# Erro de Treinamento: 0.025418537901714444
# Erro de Validação: 0.0005636760615743697
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 922]
# Erro de Treinamento: 0.017717195965815336
# Erro de Validação: 0.0005998822744004428
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 923]
# Erro de Treinamento: 0.011990934275672771
# Erro de Validação: 0.000516401429194957
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 924]
# Erro de Treinamento: 0.01413804735057056
# Erro de Validação: 0.0005264207720756531
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 925]
# Erro de Treinamento: 0.016716464844648726
# Erro de Validação: 0.0005993307568132877
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 926]
# Erro de Treinamento: 0.015175352862570435
# Erro de Validação: 0.0005062151467427611
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 927]
# Erro de Treinamento: 0.013844696164596826
# Erro de Validação: 0.0005319609772413969
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 928]
# Erro de Treinamento: 0.016024525510147214
# Erro de Validação: 0.0005141106084920466
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 929]
# Erro de Treinamento: 0.022125452058389783
# Erro de Validação: 0.0005015900242142379
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 930]
# Erro de Treinamento: 0.014574860571883619
# Erro de Validação: 0.0005726370145566761
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 931]
# Erro de Treinamento: 0.017647358850808814
# Erro de Validação: 0.0004872613644693047
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 932]
# Erro de Treinamento: 0.013156050568795763
# Erro de Validação: 0.00047547242138534784
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 933]
# Erro de Treinamento: 0.027024210547097027
# Erro de Validação: 0.000531393860001117
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 934]
# Erro de Treinamento: 0.011981616393313743
# Erro de Validação: 0.0012528959196060896
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 935]
# Erro de Treinamento: 0.03379425732418895
# Erro de Validação: 0.0004777108260896057
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 936]
# Erro de Treinamento: 0.01427095830149483
# Erro de Validação: 0.0004837204178329557
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 937]
# Erro de Treinamento: 0.013054737923084758
# Erro de Validação: 0.0005363066447898746
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 938]
# Erro de Treinamento: 0.017544709538924508
# Erro de Validação: 0.00048109027557075024
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 939]
# Erro de Treinamento: 0.014379622763954103
# Erro de Validação: 0.00046656059566885233
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 940]
# Erro de Treinamento: 0.03630363100091927
# Erro de Validação: 0.0005801452207379043
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 941]
# Erro de Treinamento: 0.09204445104114711
# Erro de Validação: 0.0007485441747121513
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 942]
# Erro de Treinamento: 0.018360235553700477
# Erro de Validação: 0.0007042479701340199
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 943]
# Erro de Treinamento: 0.11940117308404297
# Erro de Validação: 0.0004974683397449553
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 944]
# Erro de Treinamento: 0.02365510235540569
# Erro de Validação: 0.0024171106051653624
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 945]
# Erro de Treinamento: 0.04143250311608426
# Erro de Validação: 0.0005259188474155962
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 946]
# Erro de Treinamento: 0.05745779548306018
# Erro de Validação: 0.0005423024413175881
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 947]
# Erro de Treinamento: 0.010086862370371819
# Erro de Validação: 0.0031270578037947416
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 948]
# Erro de Treinamento: 0.05677876083063893
# Erro de Validação: 0.0005666628712788224
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 949]
# Erro de Treinamento: 0.02566140072303824
# Erro de Validação: 0.0005414699553512037
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 950]
# Erro de Treinamento: 0.023953656142111868
# Erro de Validação: 0.0007340873125940561
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 951]
# Erro de Treinamento: 0.04863446103991009
# Erro de Validação: 0.0005407394492067397
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 952]
# Erro de Treinamento: 0.05245748348534107
# Erro de Validação: 0.0006746654980815947
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 953]
# Erro de Treinamento: 0.06538328435271978
# Erro de Validação: 0.0007219303515739739
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 954]
# Erro de Treinamento: 0.12814904260449111
# Erro de Validação: 0.0021470552310347557
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 955]
# Erro de Treinamento: 0.037086131022078916
# Erro de Validação: 0.0008927068556658924
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 956]
# Erro de Treinamento: 0.13469966428237967
# Erro de Validação: 0.0008140800637193024
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 957]
# Erro de Treinamento: 0.04705071169883013
# Erro de Validação: 0.004409543704241514
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 958]
# Erro de Treinamento: 0.04154621053021401
# Erro de Validação: 0.0009450188372284174
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 959]
# Erro de Treinamento: 0.020891252541332506
# Erro de Validação: 0.0008921884000301361
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 960]
# Erro de Treinamento: 0.022282761725364253
# Erro de Validação: 0.0012197884498164058
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 961]
# Erro de Treinamento: 0.023820092377718538
# Erro de Validação: 0.0013935090973973274
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 962]
# Erro de Treinamento: 0.017143793898867443
# Erro de Validação: 0.0009394311928190291
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 963]
# Erro de Treinamento: 0.023355553625151515
# Erro de Validação: 0.0009334216010756791
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 964]
# Erro de Treinamento: 0.020415388396941125
# Erro de Validação: 0.001703081768937409
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 965]
# Erro de Treinamento: 0.029298961628228426
# Erro de Validação: 0.001156151993200183
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 966]
# Erro de Treinamento: 0.03083139838417992
# Erro de Validação: 0.0009269062429666519
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 967]
# Erro de Treinamento: 0.018744398781564087
# Erro de Validação: 0.00225195474922657
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 968]
# Erro de Treinamento: 0.028214499820023775
# Erro de Validação: 0.0009674171451479197
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 969]
# Erro de Treinamento: 0.019304822315461934
# Erro de Validação: 0.0008224988705478609
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 970]
# Erro de Treinamento: 0.018561818375019357
# Erro de Validação: 0.0009506147471256554
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 971]
# Erro de Treinamento: 0.023085144493961707
# Erro de Validação: 0.0011548347538337111
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 972]
# Erro de Treinamento: 0.023079236038029194
# Erro de Validação: 0.0008173860260285437
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 973]
# Erro de Treinamento: 0.018829603301128373
# Erro de Validação: 0.000737030291929841
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 974]
# Erro de Treinamento: 0.022234432952245697
# Erro de Validação: 0.0009282122482545674
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 975]
# Erro de Treinamento: 0.031841092073591426
# Erro de Validação: 0.0010160017991438508
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 976]
# Erro de Treinamento: 0.016535572591237724
# Erro de Validação: 0.000698022311553359
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 977]
# Erro de Treinamento: 0.061125201638787985
# Erro de Validação: 0.0007874733419157565
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 978]
# Erro de Treinamento: 0.06060519733000547
# Erro de Validação: 0.006010917481034994
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 979]
# Erro de Treinamento: 0.037062730407342315
# Erro de Validação: 0.0006957080331631005
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 980]
# Erro de Treinamento: 0.06299824675079435
# Erro de Validação: 0.0007024880615063012
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 981]
# Erro de Treinamento: 0.036723432305734605
# Erro de Validação: 0.0013128042919561267
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 982]
# Erro de Treinamento: 0.02863826387329027
# Erro de Validação: 0.0007585969869978726
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 983]
# Erro de Treinamento: 0.02301211713347584
# Erro de Validação: 0.0009642879012972116
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 984]
# Erro de Treinamento: 0.03433697661967017
# Erro de Validação: 0.0009652645676396787
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 985]
# Erro de Treinamento: 0.015411151864100248
# Erro de Validação: 0.0006893957615830004
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 986]
# Erro de Treinamento: 0.03064640157390386
# Erro de Validação: 0.0007500876672565937
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 987]
# Erro de Treinamento: 0.02022676490014419
# Erro de Validação: 0.0011008520377799869
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 988]
# Erro de Treinamento: 0.0284538718406111
# Erro de Validação: 0.0008705707732588053
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 989]
# Erro de Treinamento: 0.02742174477316439
# Erro de Validação: 0.001135871745646
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 990]
# Erro de Treinamento: 0.02354193018982187
# Erro de Validação: 0.0012364655267447233
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 991]
# Erro de Treinamento: 0.032628605142235756
# Erro de Validação: 0.0007313527166843414
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 992]
# Erro de Treinamento: 0.02102848212234676
# Erro de Validação: 0.0008557785768061876
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 993]
# Erro de Treinamento: 0.0157955409376882
# Erro de Validação: 0.00066596973920241
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 994]
# Erro de Treinamento: 0.01942270770086907
# Erro de Validação: 0.0007371544488705695
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 995]
# Erro de Treinamento: 0.021831039513926953
# Erro de Validação: 0.0007532332674600184
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 996]
# Erro de Treinamento: 0.01651548981317319
# Erro de Validação: 0.0007850768161006272
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 997]
# Erro de Treinamento: 0.025037772255018353
# Erro de Validação: 0.0007219757535494864
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 998]
# Erro de Treinamento: 0.030302027909783646
# Erro de Validação: 0.0007232194184325635
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 999]
# Erro de Treinamento: 0.01836035421001725
# Erro de Validação: 0.0014597559347748756
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0

# %% [markdown]
# ## Métricas e resultados
# - Plotando as curvas de perda para treino e validação

# %%
# Criando os graficos
plt.plot(train_loss_all_epoch, label='Treino')
plt.plot(val_loss_all_epoch, label='Validação')

# Adicionando título e rótulos aos eixos
plt.title('Curva de Perda por Época', fontsize=14)
plt.xlabel('Épocas', fontsize=12)
plt.ylabel('Perda (Loss)', fontsize=12)

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True, linestyle='--', alpha=0.7)  # Adicionando grade
plt.tight_layout()  # Ajuste para não cortar o gráfico
plt.show()

# %% [markdown]
# - Plotando as curvas de acuracia para treino e validação

# %%
# Criando os graficos
plt.plot(train_accuracy_all_epoch, label='Treino')
plt.plot(val_accuracy_all_epoch, label='Validação')

# Adicionando título e rótulos aos eixos
plt.title('Curva de Acuracia por Época', fontsize=14)
plt.xlabel('Épocas', fontsize=12)
plt.ylabel('Perda (Loss)', fontsize=12)

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True, linestyle='--', alpha=0.7)  # Adicionando grade
plt.tight_layout()  # Ajuste para não cortar o gráfico
plt.show()

# %% [markdown]
# - Plotando a matriz de confusão

# %%
# Montando a matriz
net.train(False)
for data in data_test:
    x_test, y_test = data
    x_test = x_test.to(torch.float32)
    y_pred = net(x_test)
    y_pred = torch.Tensor.argmax(y_pred, dim=1)
    cm = confusion_matrix(y_test, y_pred, labels=range(3))

# Exibindo a matriz de confusão graficamente
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['sedosa', 'versicolor', 'virginica'])
fig, ax = plt.subplots(figsize=(4, 4))
disp.plot(ax=ax, cmap='Blues', colorbar=False)

# Melhorando o gráfico
ax.set_title('Matriz de Confusão para Dados de Treino', fontsize=14)
ax.set_xlabel('Classe Predita', fontsize=12)
ax.set_ylabel('Classe Verdadeira', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# - Exibindo métricas de Classificação

# %%
# Colocando o modelo em modo de avaliação (desabilita dropout, batchnorm, etc.)
net.eval()

# Percorrendo os dados de teste
for data in data_test:
    x_test, y_test = data

    # Garantindo que os dados estejam no formato correto (float32)
    x_test = x_test.to(torch.float32)

    # Realizando a previsão
    with torch.no_grad():  # Desabilita o cálculo de gradientes durante a avaliação
        y_pred = net(x_test)
        # Convertendo as predições para as classes com maior probabilidade
        y_pred = torch.argmax(y_pred, dim=1)

    # Convertendo para arrays NumPy ou listas para usar com classification_report
    y_test = y_test.cpu().numpy() if isinstance(y_test, torch.Tensor) else y_test
    y_pred = y_pred.cpu().numpy() if isinstance(y_pred, torch.Tensor) else y_pred

    # Calculando e imprimindo o relatório de classificação
    print(classification_report(y_test, y_pred, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       0.83      0.91      0.87        11
#            2       0.89      0.80      0.84        10
#
#     accuracy                           0.90        30
#    macro avg       0.91      0.90      0.90        30
# weighted avg       0.90      0.90      0.90        30
