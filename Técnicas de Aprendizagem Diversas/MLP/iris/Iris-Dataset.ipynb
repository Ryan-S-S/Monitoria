# %%
# Importando as libs que iremos usar
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# ## DATASET
# - Importando o dataset que iremos usar

# %%
# Dataset Iris
from sklearn.datasets import load_iris

# Carrega o Dataset
input_data = load_iris()

print(f"Base de dados com {len(input_data['data'])} linhas")
# Out:
# Base de dados com 150 linhas

# %% [markdown]
# - Separa os dados e as labels

# %%
# Principio do Aprendizado de Maquina Supervisionado
data = input_data['data']
labels = input_data['target']

# %% [markdown]
# - Dividindo dados para o processo de *treino*, *teste* e *validação*

# %%
data_train, data_test, labels_train, labels_test = train_test_split(data, labels,
                                                                    test_size=0.2, 
                                                                    random_state=41)

data_train, data_validation, labels_train, labels_validation = train_test_split(data_train, labels_train,
                                                                                test_size=0.1,
                                                                                random_state=1)

print(f'Quantidade de Dados para Treinamento : {len(data_train)}')
print(f'Quantidade de Dados para Validação : {len(data_test)}')
print(f'Quantidade de Dados para Teste : {len(data_validation)}')
# Out:
# Quantidade de Dados para Treinamento : 108
# Quantidade de Dados para Validação : 30
# Quantidade de Dados para Teste : 12

# %%
# Construindo a classe que será usada pelo Torch para acessar o dataset
class DataSet(torch.utils.data.Dataset):
    def __init__(self,data,labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self,idx):
        return self.data[idx], self.labels[idx]

# %%
# Carregando nossos datasets de treino, teste e validação
dataset = DataSet(data_train,labels_train)
data_train = DataLoader(dataset, batch_size=32, shuffle=True, num_workers=0)

dataset = DataSet(data_validation,labels_validation)
data_validation = DataLoader(dataset, batch_size=len(data_validation), shuffle=True, num_workers=0)

dataset = DataSet(data_test,labels_test)
data_test = DataLoader(dataset, batch_size=len(data_test), shuffle=True, num_workers=0)

# %% [markdown]
# ## Modelo de Rede
# - 4 Entradas (4 Caracteristicas da Flor)
# - 2 CAMADAS de Neuronios ocultos
# - 3 Saídas (3 Rotulos de Flor)

# %%
class IrisClassifier(nn.Module) :
    def __init__(self, input_size = 4, 
                 hidden_size1=20, 
                 hidden_size2 = 10, 
                 output_size = 3) :
        
        super().__init__()
        # Camada de entrada --> Primeira camada oculta
        self.fc1 = nn.Linear(input_size, hidden_size1)
        # Primeira camada oculta --> Segunda camada oculta
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        # Segunda camada oculta --> Camada de saída
        self.output = nn.Linear(hidden_size2, output_size)
        # Função de ativação
        self.relu = nn.ReLU()

    # Fluxo dos dados da entrada para saída
    def forward(self, data) :
        data = self.relu(self.fc1(data))
        data = self.relu(self.fc2(data))
        data = self.output(data)
        return data

# %% [markdown]
# ## Instanciando e configurando a rede

# %%
net = IrisClassifier()
learning_rate = 0.01
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate)

# %%
# Processo de treino
def train_one_epoch(model,loss_function,optimizer,data_train):
    model.train()
    current_loss = 0.0
    current_accuracy = 0.0
    total_samples = 0

    for i,data in enumerate(data_train):
        x,y = data
        x = x.to(torch.float)
        optimizer.zero_grad()
        output = model(x)
        loss = loss_function(output,y)
        loss.backward()
        optimizer.step()
        current_loss += loss.item()

        output = output.argmax(dim=1)
        batch_accuracy = torch.eq(output,y)
        batch_accuracy = batch_accuracy.sum()
        current_accuracy += batch_accuracy
        total_samples += len(x)
    return current_loss/(i+1), current_accuracy/total_samples

# %%
# Processo de validação
def validation_one_epoch(model,loss_function, data_validation):
    model.train(False)
    current_loss = 0.0
    current_accuracy = 0.0
    total_samples = 0
    for i,data in enumerate(data_validation):
        x,y = data
        x = x.to(torch.float)
        output = model(x)
        loss = loss_function(output,y)
        current_loss += loss.item()

        output = output.argmax(dim=1)
        batch_accuracy = torch.eq(output,y)
        batch_accuracy = batch_accuracy.sum()
        current_accuracy += batch_accuracy
        total_samples += len(x)
    return current_loss/(i+1), current_accuracy/total_samples

# %% [markdown]
# ## Executando

# %%
epochs = 1000
train_loss_all_epoch = []
train_accuracy_all_epoch = []
val_loss_all_epoch = []
val_accuracy_all_epoch = []
best_val_loss = 1e9

for epoch in range(epochs):

    train_loss_per_epoch, train_accuracy_per_epoch = train_one_epoch(net,criterion,optimizer,data_train)

    train_loss_all_epoch.append(train_loss_per_epoch)
    train_accuracy_all_epoch.append(train_accuracy_per_epoch)

    val_loss_per_epoch,val_accuracy_per_epoch = validation_one_epoch(net,criterion, data_validation)

    val_loss_all_epoch.append(val_loss_per_epoch)
    val_accuracy_all_epoch.append(val_accuracy_per_epoch)

    # Salva o melhor modelo
    if val_loss_per_epoch < best_val_loss:
      best_val_loss = val_loss_per_epoch
      model_path = 'best_model_iris'
      torch.save(net.state_dict(),model_path)

    if(epoch % 1 == 0) :
      print(f'Epóca [: {epoch}]')
      print(f'Erro de Treinamento: {train_loss_per_epoch}')
      print(f'Erro de Validação: {val_loss_per_epoch}')
      print(f'Acurácia de Treinamento: {train_accuracy_per_epoch}')
      print(f'Acurácia de Validação: {val_accuracy_per_epoch}')
      print()
# Out:
# Epóca [: 0]
# Erro de Treinamento: 1.000030279159546
# Erro de Validação: 0.8973372578620911
# Acurácia de Treinamento: 0.5185185074806213
# Acurácia de Validação: 0.75
#
# Epóca [: 1]
# Erro de Treinamento: 0.8917091637849808
# Erro de Validação: 0.8581444621086121
# Acurácia de Treinamento: 0.6296296119689941
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 2]
# Erro de Treinamento: 0.7683506608009338
# Erro de Validação: 0.7637781500816345
# Acurácia de Treinamento: 0.6759259104728699
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 3]
# Erro de Treinamento: 0.6489832848310471
# Erro de Validação: 0.6710866093635559
# Acurácia de Treinamento: 0.6851851940155029
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 4]
# Erro de Treinamento: 0.5522543340921402
# Erro de Validação: 0.6472484469413757
# Acurácia de Treinamento: 0.6851851940155029
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 5]
# Erro de Treinamento: 0.5121466889977455
# Erro de Validação: 0.5698402523994446
# Acurácia de Treinamento: 0.6851851940155029
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 6]
# Erro de Treinamento: 0.4708874672651291
# Erro de Validação: 0.5212432742118835
# Acurácia de Treinamento: 0.6851851940155029
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 7]
# Erro de Treinamento: 0.44159311801195145
# Erro de Validação: 0.47483932971954346
# Acurácia de Treinamento: 0.7129629850387573
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 8]
# Erro de Treinamento: 0.39541665464639664
# Erro de Validação: 0.45880594849586487
# Acurácia de Treinamento: 0.7037037014961243
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 9]
# Erro de Treinamento: 0.37111640721559525
# Erro de Validação: 0.4284912347793579
# Acurácia de Treinamento: 0.75
# Acurácia de Validação: 0.5833333134651184
#
# Epóca [: 10]
# Erro de Treinamento: 0.3625573590397835
# Erro de Validação: 0.3987438678741455
# Acurácia de Treinamento: 0.75
# Acurácia de Validação: 0.75
#
# Epóca [: 11]
# Erro de Treinamento: 0.327727984637022
# Erro de Validação: 0.3518904745578766
# Acurácia de Treinamento: 0.8981481194496155
# Acurácia de Validação: 1.0
#
# Epóca [: 12]
# Erro de Treinamento: 0.31589361280202866
# Erro de Validação: 0.32315793633461
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 13]
# Erro de Treinamento: 0.3323497995734215
# Erro de Validação: 0.2691991627216339
# Acurácia de Treinamento: 0.8981481194496155
# Acurácia de Validação: 1.0
#
# Epóca [: 14]
# Erro de Treinamento: 0.2806181125342846
# Erro de Validação: 0.22957511246204376
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 15]
# Erro de Treinamento: 0.24993904680013657
# Erro de Validação: 0.21824151277542114
# Acurácia de Treinamento: 0.9351851940155029
# Acurácia de Validação: 1.0
#
# Epóca [: 16]
# Erro de Treinamento: 0.19911852292716503
# Erro de Validação: 0.15114018321037292
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 17]
# Erro de Treinamento: 0.19898038357496262
# Erro de Validação: 0.13327105343341827
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 18]
# Erro de Treinamento: 0.16450168751180172
# Erro de Validação: 0.09262367337942123
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 19]
# Erro de Treinamento: 0.15221645310521126
# Erro de Validação: 0.07543914765119553
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 20]
# Erro de Treinamento: 0.1292794719338417
# Erro de Validação: 0.06203797459602356
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 21]
# Erro de Treinamento: 0.10856315679848194
# Erro de Validação: 0.05039886757731438
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 22]
# Erro de Treinamento: 0.11769488267600536
# Erro de Validação: 0.04322740063071251
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 23]
# Erro de Treinamento: 0.1386703522875905
# Erro de Validação: 0.049353182315826416
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 24]
# Erro de Treinamento: 0.1250017862766981
# Erro de Validação: 0.02939281426370144
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 25]
# Erro de Treinamento: 0.11811202391982079
# Erro de Validação: 0.030586669221520424
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 26]
# Erro de Treinamento: 0.11871123313903809
# Erro de Validação: 0.023676449432969093
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 27]
# Erro de Treinamento: 0.1230077501386404
# Erro de Validação: 0.020029302686452866
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 28]
# Erro de Treinamento: 0.11184520740061998
# Erro de Validação: 0.023077966645359993
# Acurácia de Treinamento: 0.9351851940155029
# Acurácia de Validação: 1.0
#
# Epóca [: 29]
# Erro de Treinamento: 0.07395778130739927
# Erro de Validação: 0.040609922260046005
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 30]
# Erro de Treinamento: 0.08795820455998182
# Erro de Validação: 0.026675323024392128
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 31]
# Erro de Treinamento: 0.1072149584069848
# Erro de Validação: 0.014193855226039886
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 32]
# Erro de Treinamento: 0.06782028824090958
# Erro de Validação: 0.013065379112958908
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 33]
# Erro de Treinamento: 0.06413780152797699
# Erro de Validação: 0.011986532248556614
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 34]
# Erro de Treinamento: 0.06658914033323526
# Erro de Validação: 0.01135711744427681
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 35]
# Erro de Treinamento: 0.05387312942184508
# Erro de Validação: 0.010752054862678051
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 36]
# Erro de Treinamento: 0.051361861638724804
# Erro de Validação: 0.009504727087914944
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 37]
# Erro de Treinamento: 0.057041470892727375
# Erro de Validação: 0.008868233300745487
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 38]
# Erro de Treinamento: 0.05414099059998989
# Erro de Validação: 0.008064948953688145
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 39]
# Erro de Treinamento: 0.05626497883349657
# Erro de Validação: 0.007964137941598892
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 40]
# Erro de Treinamento: 0.07660897262394428
# Erro de Validação: 0.007419366389513016
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 41]
# Erro de Treinamento: 0.07858297601342201
# Erro de Validação: 0.008652102202177048
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 42]
# Erro de Treinamento: 0.08829006925225258
# Erro de Validação: 0.014319631271064281
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 43]
# Erro de Treinamento: 0.09101997129619122
# Erro de Validação: 0.013490407727658749
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 1.0
#
# Epóca [: 44]
# Erro de Treinamento: 0.09902132023125887
# Erro de Validação: 0.0085496436804533
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 1.0
#
# Epóca [: 45]
# Erro de Treinamento: 0.06111355219036341
# Erro de Validação: 0.005408638622611761
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 46]
# Erro de Treinamento: 0.05717602279037237
# Erro de Validação: 0.008811918087303638
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 47]
# Erro de Treinamento: 0.05462714214809239
# Erro de Validação: 0.0054534561932086945
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 48]
# Erro de Treinamento: 0.04426747327670455
# Erro de Validação: 0.004843545611947775
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 49]
# Erro de Treinamento: 0.05442457180470228
# Erro de Validação: 0.006208466831594706
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 50]
# Erro de Treinamento: 0.04227440897375345
# Erro de Validação: 0.004818919114768505
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 51]
# Erro de Treinamento: 0.0412493497133255
# Erro de Validação: 0.004048874136060476
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 52]
# Erro de Treinamento: 0.04180222994182259
# Erro de Validação: 0.004912387114018202
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 53]
# Erro de Treinamento: 0.03989773686043918
# Erro de Validação: 0.003713506506755948
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 54]
# Erro de Treinamento: 0.06190558662638068
# Erro de Validação: 0.004442249890416861
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 55]
# Erro de Treinamento: 0.07694530813023448
# Erro de Validação: 0.003814101917669177
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 56]
# Erro de Treinamento: 0.057470472529530525
# Erro de Validação: 0.005467243958264589
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 57]
# Erro de Treinamento: 0.052170938812196255
# Erro de Validação: 0.01747841201722622
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 58]
# Erro de Treinamento: 0.06962500605732203
# Erro de Validação: 0.003989590331912041
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 59]
# Erro de Treinamento: 0.06900767935439944
# Erro de Validação: 0.00664296792820096
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 60]
# Erro de Treinamento: 0.07254279963672161
# Erro de Validação: 0.0040979846380651
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 61]
# Erro de Treinamento: 0.110951435752213
# Erro de Validação: 0.003195306286215782
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 62]
# Erro de Treinamento: 0.0808569174259901
# Erro de Validação: 0.008874270133674145
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 63]
# Erro de Treinamento: 0.10882844217121601
# Erro de Validação: 0.0026102138217538595
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 64]
# Erro de Treinamento: 0.07010867982171476
# Erro de Validação: 0.00394367054104805
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 65]
# Erro de Treinamento: 0.04599511809647083
# Erro de Validação: 0.0041248733177781105
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 66]
# Erro de Treinamento: 0.057615082478150725
# Erro de Validação: 0.007332943845540285
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 67]
# Erro de Treinamento: 0.07626171596348286
# Erro de Validação: 0.003931350540369749
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 68]
# Erro de Treinamento: 0.04124118248000741
# Erro de Validação: 0.0034458711743354797
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 69]
# Erro de Treinamento: 0.042848426615819335
# Erro de Validação: 0.0022487009409815073
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 70]
# Erro de Treinamento: 0.07461524242535233
# Erro de Validação: 0.002283429028466344
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 71]
# Erro de Treinamento: 0.044457955402322114
# Erro de Validação: 0.006521396804600954
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 72]
# Erro de Treinamento: 0.0920107951387763
# Erro de Validação: 0.0027811324689537287
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 73]
# Erro de Treinamento: 0.04339107032865286
# Erro de Validação: 0.007936541922390461
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 74]
# Erro de Treinamento: 0.04319645429495722
# Erro de Validação: 0.0019759268034249544
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 75]
# Erro de Treinamento: 0.054480241145938635
# Erro de Validação: 0.0023604396265000105
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 76]
# Erro de Treinamento: 0.03368103317916393
# Erro de Validação: 0.008671430870890617
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 77]
# Erro de Treinamento: 0.046058506006374955
# Erro de Validação: 0.0021784112323075533
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 78]
# Erro de Treinamento: 0.04753942531533539
# Erro de Validação: 0.0024480640422552824
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 79]
# Erro de Treinamento: 0.04033038858324289
# Erro de Validação: 0.0023379893973469734
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 80]
# Erro de Treinamento: 0.03727736382279545
# Erro de Validação: 0.0019205705029889941
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 81]
# Erro de Treinamento: 0.04130393359810114
# Erro de Validação: 0.0025218152441084385
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 82]
# Erro de Treinamento: 0.03372792946174741
# Erro de Validação: 0.001549332751892507
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 83]
# Erro de Treinamento: 0.03448109427699819
# Erro de Validação: 0.0027155012357980013
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 84]
# Erro de Treinamento: 0.06875796476379037
# Erro de Validação: 0.0014511002227663994
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 85]
# Erro de Treinamento: 0.09654093254357576
# Erro de Validação: 0.0027522456366568804
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 86]
# Erro de Treinamento: 0.07924339082092047
# Erro de Validação: 0.00911189429461956
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 87]
# Erro de Treinamento: 0.05720652197487652
# Erro de Validação: 0.0013638852396979928
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 88]
# Erro de Treinamento: 0.03839520481415093
# Erro de Validação: 0.0017884396947920322
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 89]
# Erro de Treinamento: 0.03427966544404626
# Erro de Validação: 0.0032265959307551384
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 90]
# Erro de Treinamento: 0.06717983609996736
# Erro de Validação: 0.0013466608943417668
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 91]
# Erro de Treinamento: 0.08923938125371933
# Erro de Validação: 0.002798031084239483
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 92]
# Erro de Treinamento: 0.0826581867877394
# Erro de Validação: 0.010017137974500656
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 93]
# Erro de Treinamento: 0.0461663706228137
# Erro de Validação: 0.0014706755755469203
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 94]
# Erro de Treinamento: 0.05751193989999592
# Erro de Validação: 0.0012150185648351908
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 95]
# Erro de Treinamento: 0.03010184969753027
# Erro de Validação: 0.004909527022391558
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 96]
# Erro de Treinamento: 0.05316717363893986
# Erro de Validação: 0.0013988874852657318
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 97]
# Erro de Treinamento: 0.034776748972944915
# Erro de Validação: 0.0011603394523262978
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 98]
# Erro de Treinamento: 0.036019955994561315
# Erro de Validação: 0.0031274694483727217
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 99]
# Erro de Treinamento: 0.04636102123185992
# Erro de Validação: 0.001614585635252297
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 100]
# Erro de Treinamento: 0.054411075660027564
# Erro de Validação: 0.0011071484768763185
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 101]
# Erro de Treinamento: 0.057123744394630194
# Erro de Validação: 0.0016803527250885963
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 102]
# Erro de Treinamento: 0.04100573496543802
# Erro de Validação: 0.0010458353208377957
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 103]
# Erro de Treinamento: 0.05427098413929343
# Erro de Validação: 0.0015361023833975196
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 104]
# Erro de Treinamento: 0.03256949409842491
# Erro de Validação: 0.0010226265294477344
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 105]
# Erro de Treinamento: 0.02849078326835297
# Erro de Validação: 0.0025710617192089558
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 106]
# Erro de Treinamento: 0.03543897718191147
# Erro de Validação: 0.0011756975436583161
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 107]
# Erro de Treinamento: 0.03302132693352178
# Erro de Validação: 0.0011019035009667277
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 108]
# Erro de Treinamento: 0.03467766032554209
# Erro de Validação: 0.0015207886463031173
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 109]
# Erro de Treinamento: 0.043789476447273046
# Erro de Validação: 0.0008934795041568577
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 110]
# Erro de Treinamento: 0.06851869646925479
# Erro de Validação: 0.0008828855934552848
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 111]
# Erro de Treinamento: 0.026640784577466547
# Erro de Validação: 0.012648862786591053
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 112]
# Erro de Treinamento: 0.06641189515357837
# Erro de Validação: 0.0008947236347012222
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 113]
# Erro de Treinamento: 0.04686295485589653
# Erro de Validação: 0.0009044604958035052
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 114]
# Erro de Treinamento: 0.0373847100418061
# Erro de Validação: 0.0021327855065464973
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 115]
# Erro de Treinamento: 0.04985728720203042
# Erro de Validação: 0.001635143649764359
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 116]
# Erro de Treinamento: 0.04163011070340872
# Erro de Validação: 0.0009458192507736385
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 117]
# Erro de Treinamento: 0.049047803855501115
# Erro de Validação: 0.0009319990058429539
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 118]
# Erro de Treinamento: 0.03816085308790207
# Erro de Validação: 0.0034557245671749115
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 119]
# Erro de Treinamento: 0.06827983679249883
# Erro de Validação: 0.0008490629843436182
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 120]
# Erro de Treinamento: 0.05766412115190178
# Erro de Validação: 0.0017421491211280227
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 121]
# Erro de Treinamento: 0.07889879820868373
# Erro de Validação: 0.0034327844623476267
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 122]
# Erro de Treinamento: 0.038283513742499053
# Erro de Validação: 0.0008872660691849887
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 123]
# Erro de Treinamento: 0.02432346175191924
# Erro de Validação: 0.0008897528168745339
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 124]
# Erro de Treinamento: 0.024085364013444632
# Erro de Validação: 0.0011928167659789324
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 125]
# Erro de Treinamento: 0.025777827366255224
# Erro de Validação: 0.0011403877288103104
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 126]
# Erro de Treinamento: 0.027041880413889885
# Erro de Validação: 0.0007697654073126614
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 127]
# Erro de Treinamento: 0.03171292110346258
# Erro de Validação: 0.0008460015524178743
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 128]
# Erro de Treinamento: 0.03305686404928565
# Erro de Validação: 0.0009440849535167217
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 129]
# Erro de Treinamento: 0.03218732005916536
# Erro de Validação: 0.0008872245089150965
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 130]
# Erro de Treinamento: 0.03554405807517469
# Erro de Validação: 0.0008123255684040487
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 131]
# Erro de Treinamento: 0.034779543057084084
# Erro de Validação: 0.0014426438137888908
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 132]
# Erro de Treinamento: 0.026401291135698557
# Erro de Validação: 0.0006221249350346625
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 133]
# Erro de Treinamento: 0.04470856438274495
# Erro de Validação: 0.0006829660851508379
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 134]
# Erro de Treinamento: 0.03424123162403703
# Erro de Validação: 0.0021529325749725103
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 135]
# Erro de Treinamento: 0.02407758476329036
# Erro de Validação: 0.0007450181874446571
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 136]
# Erro de Treinamento: 0.07531954039586708
# Erro de Validação: 0.0007240252452902496
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 137]
# Erro de Treinamento: 0.04395228601060808
# Erro de Validação: 0.011581100523471832
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 138]
# Erro de Treinamento: 0.07694905760581605
# Erro de Validação: 0.0016038307221606374
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 139]
# Erro de Treinamento: 0.13180825300514698
# Erro de Validação: 0.0005629449733532965
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 1.0
#
# Epóca [: 140]
# Erro de Treinamento: 0.02791607279505115
# Erro de Validação: 0.038729362189769745
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 141]
# Erro de Treinamento: 0.1540282405912876
# Erro de Validação: 0.0006375391385518014
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 142]
# Erro de Treinamento: 0.18927002046257257
# Erro de Validação: 0.007817097939550877
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 143]
# Erro de Treinamento: 0.14134978409856558
# Erro de Validação: 0.007827783934772015
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 1.0
#
# Epóca [: 144]
# Erro de Treinamento: 0.04729568469338119
# Erro de Validação: 0.0006944849155843258
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 145]
# Erro de Treinamento: 0.04663379356497899
# Erro de Validação: 0.0013104501413181424
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 146]
# Erro de Treinamento: 0.05296974070370197
# Erro de Validação: 0.0013239821419119835
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 147]
# Erro de Treinamento: 0.08163277572020888
# Erro de Validação: 0.0016665778821334243
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 148]
# Erro de Treinamento: 0.05245084431953728
# Erro de Validação: 0.0012359810061752796
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 149]
# Erro de Treinamento: 0.04408728831913322
# Erro de Validação: 0.0018906540935859084
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 150]
# Erro de Treinamento: 0.04705537389963865
# Erro de Validação: 0.0017229580553248525
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 151]
# Erro de Treinamento: 0.018448443326633424
# Erro de Validação: 0.0009921815944835544
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 152]
# Erro de Treinamento: 0.04874016740359366
# Erro de Validação: 0.0008621665183454752
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 153]
# Erro de Treinamento: 0.026239086408168077
# Erro de Validação: 0.0028928781393915415
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 154]
# Erro de Treinamento: 0.036676155345048755
# Erro de Validação: 0.0012179758632555604
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 155]
# Erro de Treinamento: 0.05090339807793498
# Erro de Validação: 0.0009846907341852784
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 156]
# Erro de Treinamento: 0.02549042459577322
# Erro de Validação: 0.003986775875091553
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 157]
# Erro de Treinamento: 0.037996495608240366
# Erro de Validação: 0.0008398917852900922
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 158]
# Erro de Treinamento: 0.05496529478114098
# Erro de Validação: 0.0007829240639694035
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 159]
# Erro de Treinamento: 0.053273293655365705
# Erro de Validação: 0.003413553349673748
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 160]
# Erro de Treinamento: 0.03415158670395613
# Erro de Validação: 0.0007368075312115252
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 161]
# Erro de Treinamento: 0.027807324077002704
# Erro de Validação: 0.0008091197814792395
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 162]
# Erro de Treinamento: 0.03141043591313064
# Erro de Validação: 0.0010037132306024432
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 163]
# Erro de Treinamento: 0.02281244911137037
# Erro de Validação: 0.0008040971588343382
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 164]
# Erro de Treinamento: 0.026163865230046213
# Erro de Validação: 0.0010221932316198945
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 165]
# Erro de Treinamento: 0.05470027483534068
# Erro de Validação: 0.0010713139781728387
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 166]
# Erro de Treinamento: 0.048717888072133064
# Erro de Validação: 0.0020461061503738165
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 167]
# Erro de Treinamento: 0.02623675297945738
# Erro de Validação: 0.0006388015463016927
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 168]
# Erro de Treinamento: 0.03918231790885329
# Erro de Validação: 0.0006799870170652866
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 169]
# Erro de Treinamento: 0.02051522140391171
# Erro de Validação: 0.0025580290239304304
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 170]
# Erro de Treinamento: 0.0358567690855125
# Erro de Validação: 0.0008815901819616556
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 171]
# Erro de Treinamento: 0.0368907293304801
# Erro de Validação: 0.0006068307557143271
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 172]
# Erro de Treinamento: 0.035844615660607815
# Erro de Validação: 0.001125816605053842
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 173]
# Erro de Treinamento: 0.03741861367598176
# Erro de Validação: 0.0006459216237999499
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 174]
# Erro de Treinamento: 0.020470889285206795
# Erro de Validação: 0.0011557057732716203
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 175]
# Erro de Treinamento: 0.02329756156541407
# Erro de Validação: 0.0008597552659921348
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 176]
# Erro de Treinamento: 0.04260291357059032
# Erro de Validação: 0.0006764698773622513
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 177]
# Erro de Treinamento: 0.042708737310022116
# Erro de Validação: 0.0012535416753962636
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 178]
# Erro de Treinamento: 0.01961932028643787
# Erro de Validação: 0.0005161893204785883
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 179]
# Erro de Treinamento: 0.0300614507868886
# Erro de Validação: 0.0005596057744696736
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 180]
# Erro de Treinamento: 0.019629012793302536
# Erro de Validação: 0.0012668754206970334
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 181]
# Erro de Treinamento: 0.03213709123519948
# Erro de Validação: 0.0006808592588640749
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 182]
# Erro de Treinamento: 0.039392117178067565
# Erro de Validação: 0.0005534801748581231
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 183]
# Erro de Treinamento: 0.01789952372200787
# Erro de Validação: 0.001628195052035153
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 184]
# Erro de Treinamento: 0.027608625852735713
# Erro de Validação: 0.0005515609518624842
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 185]
# Erro de Treinamento: 0.023782961419783533
# Erro de Validação: 0.0004984333645552397
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 186]
# Erro de Treinamento: 0.0212598224170506
# Erro de Validação: 0.0007775319390930235
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 187]
# Erro de Treinamento: 0.020161543136055116
# Erro de Validação: 0.0005364269600249827
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 188]
# Erro de Treinamento: 0.019722193101188168
# Erro de Validação: 0.0005179867148399353
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 189]
# Erro de Treinamento: 0.021040147919848096
# Erro de Validação: 0.0006696167401969433
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 190]
# Erro de Treinamento: 0.034727264544926584
# Erro de Validação: 0.0006147922249510884
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 191]
# Erro de Treinamento: 0.028442622104194015
# Erro de Validação: 0.0006103693158365786
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 192]
# Erro de Treinamento: 0.04192314203828573
# Erro de Validação: 0.00040917363367043436
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 193]
# Erro de Treinamento: 0.019317389465868473
# Erro de Validação: 0.0033366463612765074
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 194]
# Erro de Treinamento: 0.045743255876004696
# Erro de Validação: 0.0003688950091600418
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 195]
# Erro de Treinamento: 0.04631321952911094
# Erro de Validação: 0.000364347972208634
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 196]
# Erro de Treinamento: 0.019644235959276557
# Erro de Validação: 0.0014576740795746446
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 197]
# Erro de Treinamento: 0.03764542820863426
# Erro de Validação: 0.0004644746659323573
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 198]
# Erro de Treinamento: 0.018763657077215612
# Erro de Validação: 0.0003488931979518384
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 199]
# Erro de Treinamento: 0.036505543743260205
# Erro de Validação: 0.0006396748940460384
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 200]
# Erro de Treinamento: 0.034558609331725165
# Erro de Validação: 0.0005534486845135689
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 201]
# Erro de Treinamento: 0.028971341671422124
# Erro de Validação: 0.00033323411480523646
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 202]
# Erro de Treinamento: 0.029622903559356928
# Erro de Validação: 0.0004303405585233122
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 203]
# Erro de Treinamento: 0.024822990177199244
# Erro de Validação: 0.0005161534645594656
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 204]
# Erro de Treinamento: 0.018857652437873185
# Erro de Validação: 0.00034823897294700146
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 205]
# Erro de Treinamento: 0.03772567352280021
# Erro de Validação: 0.0004813890263903886
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 206]
# Erro de Treinamento: 0.02773577393963933
# Erro de Validação: 0.002263698959723115
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 207]
# Erro de Treinamento: 0.03396148094907403
# Erro de Validação: 0.0003177146427333355
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 208]
# Erro de Treinamento: 0.029314586077816784
# Erro de Validação: 0.0003047103527933359
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 209]
# Erro de Treinamento: 0.030806859955191612
# Erro de Validação: 0.0008582717273384333
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 210]
# Erro de Treinamento: 0.03520331368781626
# Erro de Validação: 0.0005095753003843129
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 211]
# Erro de Treinamento: 0.037605243967846036
# Erro de Validação: 0.000623154453933239
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 212]
# Erro de Treinamento: 0.03774374583736062
# Erro de Validação: 0.000552117417100817
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 213]
# Erro de Treinamento: 0.02183815510943532
# Erro de Validação: 0.00029957827064208686
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 214]
# Erro de Treinamento: 0.027897104620933533
# Erro de Validação: 0.00037870032247155905
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 215]
# Erro de Treinamento: 0.021541030146181583
# Erro de Validação: 0.00046434279647655785
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 216]
# Erro de Treinamento: 0.01840418705251068
# Erro de Validação: 0.0003126045921817422
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 217]
# Erro de Treinamento: 0.01894701604032889
# Erro de Validação: 0.00039162157918326557
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 218]
# Erro de Treinamento: 0.017577286111190915
# Erro de Validação: 0.0004475738387554884
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 219]
# Erro de Treinamento: 0.03343119687633589
# Erro de Validação: 0.0003846317995339632
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 220]
# Erro de Treinamento: 0.017150532716186717
# Erro de Validação: 0.0006842643488198519
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 221]
# Erro de Treinamento: 0.02842795167816803
# Erro de Validação: 0.0002584545873105526
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 222]
# Erro de Treinamento: 0.028278555917495396
# Erro de Validação: 0.0002499881375115365
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 223]
# Erro de Treinamento: 0.017484282943769358
# Erro de Validação: 0.00082821847172454
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 224]
# Erro de Treinamento: 0.03859784742962802
# Erro de Validação: 0.000302348576951772
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 225]
# Erro de Treinamento: 0.019282438326627016
# Erro de Validação: 0.00023724923084955662
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 226]
# Erro de Treinamento: 0.04302920636837371
# Erro de Validação: 0.00042060751002281904
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 227]
# Erro de Treinamento: 0.028458463224524166
# Erro de Validação: 0.0008421873790211976
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 228]
# Erro de Treinamento: 0.021257184766000137
# Erro de Validação: 0.00022596778580918908
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 229]
# Erro de Treinamento: 0.036461269155552145
# Erro de Validação: 0.0002537360123824328
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 230]
# Erro de Treinamento: 0.0307277487590909
# Erro de Validação: 0.00043827175977639854
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 231]
# Erro de Treinamento: 0.022485304856672883
# Erro de Validação: 0.00021715991897508502
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 232]
# Erro de Treinamento: 0.0311823773663491
# Erro de Validação: 0.0003027115890290588
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 233]
# Erro de Treinamento: 0.025052458717254922
# Erro de Validação: 0.00029922902467660606
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 234]
# Erro de Treinamento: 0.02240181085653603
# Erro de Validação: 0.0004062283260282129
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 235]
# Erro de Treinamento: 0.026020323392003775
# Erro de Validação: 0.0002799531794153154
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 236]
# Erro de Treinamento: 0.029632274759933352
# Erro de Validação: 0.00020732848497573286
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 237]
# Erro de Treinamento: 0.025043177360203117
# Erro de Validação: 0.0007996608619578183
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 238]
# Erro de Treinamento: 0.04928621067665517
# Erro de Validação: 0.0002918908139690757
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 239]
# Erro de Treinamento: 0.013941602133854758
# Erro de Validação: 0.00025537083274684846
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 240]
# Erro de Treinamento: 0.06309977918863297
# Erro de Validação: 0.0002553769445512444
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 241]
# Erro de Treinamento: 0.07726596074644476
# Erro de Validação: 0.0009952926775440574
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 242]
# Erro de Treinamento: 0.06297072593588382
# Erro de Validação: 0.00023665488697588444
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 243]
# Erro de Treinamento: 0.04496267344802618
# Erro de Validação: 0.0011224487097933888
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 244]
# Erro de Treinamento: 0.11707449145615101
# Erro de Validação: 0.0006877085543237627
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 245]
# Erro de Treinamento: 0.025351672200486064
# Erro de Validação: 0.0032716095447540283
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 246]
# Erro de Treinamento: 0.22357692204241175
# Erro de Validação: 0.00031337179825641215
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 1.0
#
# Epóca [: 247]
# Erro de Treinamento: 0.2106894387397915
# Erro de Validação: 0.003087929217144847
# Acurácia de Treinamento: 0.9444444179534912
# Acurácia de Validação: 1.0
#
# Epóca [: 248]
# Erro de Treinamento: 0.08919753134250641
# Erro de Validação: 0.001802891492843628
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 249]
# Erro de Treinamento: 0.08578267401026096
# Erro de Validação: 0.000501427217386663
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 250]
# Erro de Treinamento: 0.04524433333426714
# Erro de Validação: 0.008897512219846249
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 251]
# Erro de Treinamento: 0.07213777163997293
# Erro de Validação: 0.00040041698957793415
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 252]
# Erro de Treinamento: 0.03562828456051648
# Erro de Validação: 0.0004646737652365118
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 253]
# Erro de Treinamento: 0.023475302761653438
# Erro de Validação: 0.0009079377050511539
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 254]
# Erro de Treinamento: 0.029724154621362686
# Erro de Validação: 0.0006746595609001815
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 255]
# Erro de Treinamento: 0.025009276578202844
# Erro de Validação: 0.0005958554684184492
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 256]
# Erro de Treinamento: 0.024515484226867557
# Erro de Validação: 0.000760441820602864
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 257]
# Erro de Treinamento: 0.04074246436357498
# Erro de Validação: 0.0007898374460637569
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 258]
# Erro de Treinamento: 0.018289660714799538
# Erro de Validação: 0.0005027955630794168
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 259]
# Erro de Treinamento: 0.033062945018173195
# Erro de Validação: 0.0004925216780975461
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 260]
# Erro de Treinamento: 0.04148353496566415
# Erro de Validação: 0.0008136159158311784
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 261]
# Erro de Treinamento: 0.02548618381842971
# Erro de Validação: 0.00040246601565741
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 262]
# Erro de Treinamento: 0.031997259822674096
# Erro de Validação: 0.00038573378697037697
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 263]
# Erro de Treinamento: 0.02606914541684091
# Erro de Validação: 0.000814960862044245
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 264]
# Erro de Treinamento: 0.02985474350862205
# Erro de Validação: 0.0013498124899342656
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 265]
# Erro de Treinamento: 0.035891148960217834
# Erro de Validação: 0.0004177912778686732
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 266]
# Erro de Treinamento: 0.022875244343595114
# Erro de Validação: 0.0003863289311993867
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 267]
# Erro de Treinamento: 0.027321352856233716
# Erro de Validação: 0.0006417197291739285
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 268]
# Erro de Treinamento: 0.02861692610895261
# Erro de Validação: 0.001150590949691832
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 269]
# Erro de Treinamento: 0.02769264904782176
# Erro de Validação: 0.0004234066291246563
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 270]
# Erro de Treinamento: 0.044379565166309476
# Erro de Validação: 0.0004012531426269561
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 271]
# Erro de Treinamento: 0.02098217651655432
# Erro de Validação: 0.0015815513907000422
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 272]
# Erro de Treinamento: 0.03003879403695464
# Erro de Validação: 0.00035152328200638294
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 273]
# Erro de Treinamento: 0.024029728840105236
# Erro de Validação: 0.0003229709400329739
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 274]
# Erro de Treinamento: 0.027020241250284016
# Erro de Validação: 0.0004652685020118952
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 275]
# Erro de Treinamento: 0.02808632139931433
# Erro de Validação: 0.0006918730796314776
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 276]
# Erro de Treinamento: 0.018087351112626493
# Erro de Validação: 0.0003056805580854416
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 277]
# Erro de Treinamento: 0.0224223199984408
# Erro de Validação: 0.00030819454696029425
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 278]
# Erro de Treinamento: 0.023027424511383288
# Erro de Validação: 0.0005705793737433851
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 279]
# Erro de Treinamento: 0.019187674115528353
# Erro de Validação: 0.0003521719772834331
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 280]
# Erro de Treinamento: 0.025569497607648373
# Erro de Validação: 0.0003126590163446963
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 281]
# Erro de Treinamento: 0.019358058460056782
# Erro de Validação: 0.00037722557317465544
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 282]
# Erro de Treinamento: 0.017583282708073966
# Erro de Validação: 0.00034630089066922665
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 283]
# Erro de Treinamento: 0.01810775098419981
# Erro de Validação: 0.0003568762040231377
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 284]
# Erro de Treinamento: 0.01848565970431082
# Erro de Validação: 0.00030450246413238347
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 285]
# Erro de Treinamento: 0.019254611630458385
# Erro de Validação: 0.00029660266591235995
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 286]
# Erro de Treinamento: 0.019373308372450992
# Erro de Validação: 0.0003091282269451767
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 287]
# Erro de Treinamento: 0.03296652063727379
# Erro de Validação: 0.0003222052182536572
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 288]
# Erro de Treinamento: 0.01703660261409823
# Erro de Validação: 0.0008753655129112303
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 289]
# ...
#
# Epóca [: 901]
# Erro de Treinamento: 0.008452503365333541
# Erro de Validação: 4.165140489931218e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 902]
# Erro de Treinamento: 0.012599811307154596
# Erro de Validação: 3.765858491533436e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 903]
# Erro de Treinamento: 0.06473974849723163
# Erro de Validação: 5.186038833926432e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 904]
# Erro de Treinamento: 0.388140994386049
# Erro de Validação: 9.212528675561771e-05
# Acurácia de Treinamento: 0.9629629850387573
# Acurácia de Validação: 1.0
#
# Epóca [: 905]
# Erro de Treinamento: 0.08700448623858392
# Erro de Validação: 0.11014541238546371
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 906]
# Erro de Treinamento: 0.4222277116496116
# Erro de Validação: 0.0013776550767943263
# Acurácia de Treinamento: 0.9166666865348816
# Acurácia de Validação: 1.0
#
# Epóca [: 907]
# Erro de Treinamento: 0.09480279323179275
# Erro de Validação: 0.0029155320953577757
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 908]
# Erro de Treinamento: 0.1582964276894927
# Erro de Validação: 0.014311474747955799
# Acurácia de Treinamento: 0.9537037014961243
# Acurácia de Validação: 1.0
#
# Epóca [: 909]
# Erro de Treinamento: 0.0979993820656091
# Erro de Validação: 0.0019157245988026261
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 910]
# Erro de Treinamento: 0.04986700462177396
# Erro de Validação: 0.0023249650839716196
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 911]
# Erro de Treinamento: 0.049106890975963324
# Erro de Validação: 0.003452508943155408
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 912]
# Erro de Treinamento: 0.03172522597014904
# Erro de Validação: 0.005708683282136917
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 913]
# Erro de Treinamento: 0.041758228559046984
# Erro de Validação: 0.003490486415103078
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 914]
# Erro de Treinamento: 0.04501329595223069
# Erro de Validação: 0.002284137299284339
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 915]
# Erro de Treinamento: 0.024007524247281253
# Erro de Validação: 0.0021314446348696947
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 916]
# Erro de Treinamento: 0.01960256858728826
# Erro de Validação: 0.0019106668187305331
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 917]
# Erro de Treinamento: 0.019550213706679642
# Erro de Validação: 0.001459989813156426
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 918]
# Erro de Treinamento: 0.021911223884671926
# Erro de Validação: 0.001196394208818674
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 919]
# Erro de Treinamento: 0.01890803150308784
# Erro de Validação: 0.0011436333879828453
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 920]
# Erro de Treinamento: 0.03613131435122341
# Erro de Validação: 0.0009620512719266117
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 921]
# Erro de Treinamento: 0.018376570631517097
# Erro de Validação: 0.0012713860487565398
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 922]
# Erro de Treinamento: 0.022601342119742185
# Erro de Validação: 0.0009273409959860146
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 923]
# Erro de Treinamento: 0.016700710984878242
# Erro de Validação: 0.0007714192033745348
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 924]
# Erro de Treinamento: 0.019894201774150133
# Erro de Validação: 0.0007628589519299567
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 925]
# Erro de Treinamento: 0.018598707691126037
# Erro de Validação: 0.0006682649254798889
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 926]
# Erro de Treinamento: 0.023160520009696484
# Erro de Validação: 0.0006257896893657744
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 927]
# Erro de Treinamento: 0.04186480294447392
# Erro de Validação: 0.0006597547908313572
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 928]
# Erro de Treinamento: 0.033377327665220946
# Erro de Validação: 0.0006623851950280368
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 929]
# Erro de Treinamento: 0.018958563605337986
# Erro de Validação: 0.0005144638707861304
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 930]
# Erro de Treinamento: 0.01486165844835341
# Erro de Validação: 0.0005502728163264692
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 931]
# Erro de Treinamento: 0.01847968576475978
# Erro de Validação: 0.0005100687267258763
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 932]
# Erro de Treinamento: 0.015561691543553025
# Erro de Validação: 0.00044815929140895605
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 933]
# Erro de Treinamento: 0.020334971603006124
# Erro de Validação: 0.0004685299936681986
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 934]
# Erro de Treinamento: 0.01731362802820513
# Erro de Validação: 0.00040777609683573246
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 935]
# Erro de Treinamento: 0.017095406365115196
# Erro de Validação: 0.00042339172796346247
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 936]
# Erro de Treinamento: 0.01608811001642607
# Erro de Validação: 0.00042941924766637385
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 937]
# Erro de Treinamento: 0.022000458993716165
# Erro de Validação: 0.00035438165650703013
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 938]
# Erro de Treinamento: 0.018751997966319323
# Erro de Validação: 0.00034274556674063206
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 939]
# Erro de Treinamento: 0.014153855103359092
# Erro de Validação: 0.00037404827889986336
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 940]
# Erro de Treinamento: 0.014471399728790857
# Erro de Validação: 0.00031329193734563887
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 941]
# Erro de Treinamento: 0.013323046354344115
# Erro de Validação: 0.0002953354560304433
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 942]
# Erro de Treinamento: 0.013587322915554978
# Erro de Validação: 0.000281864166026935
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 943]
# Erro de Treinamento: 0.02025083568878472
# Erro de Validação: 0.0002717572497203946
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 944]
# Erro de Treinamento: 0.023662294493988156
# Erro de Validação: 0.0002643137995619327
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 945]
# Erro de Treinamento: 0.014017881978361402
# Erro de Validação: 0.00031042081536725163
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 946]
# Erro de Treinamento: 0.015005724562797695
# Erro de Validação: 0.00026933630579151213
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 947]
# Erro de Treinamento: 0.012790816023880325
# Erro de Validação: 0.00022938135953154415
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 948]
# Erro de Treinamento: 0.017114491551183164
# Erro de Validação: 0.00022146811534184963
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 949]
# Erro de Treinamento: 0.013263753746286966
# Erro de Validação: 0.0002092469803756103
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 950]
# Erro de Treinamento: 0.013569836504757404
# Erro de Validação: 0.00020151033822912723
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 951]
# Erro de Treinamento: 0.0178012389333162
# Erro de Validação: 0.00022798258578404784
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 952]
# Erro de Treinamento: 0.015569500159472227
# Erro de Validação: 0.0001804325293051079
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 953]
# Erro de Treinamento: 0.01741132292227121
# Erro de Validação: 0.00018382456619292498
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 954]
# Erro de Treinamento: 0.013304430445714388
# Erro de Validação: 0.00017322803614661098
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 955]
# Erro de Treinamento: 0.013501097302651033
# Erro de Validação: 0.00019393657566979527
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 956]
# Erro de Treinamento: 0.013056109921308234
# Erro de Validação: 0.000153184708324261
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 957]
# Erro de Treinamento: 0.011744450606784085
# Erro de Validação: 0.00014719706086907536
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 958]
# Erro de Treinamento: 0.018886859179474413
# Erro de Validação: 0.00014403791283257306
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 959]
# Erro de Treinamento: 0.012604583753272891
# Erro de Validação: 0.00022406724747270346
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 960]
# Erro de Treinamento: 0.02267226460389793
# Erro de Validação: 0.0001636445667827502
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 961]
# Erro de Treinamento: 0.01389289740473032
# Erro de Validação: 0.0001224883017130196
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 962]
# Erro de Treinamento: 0.014246042221202515
# Erro de Validação: 0.00011076076043536887
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 963]
# Erro de Treinamento: 0.011488832446048036
# Erro de Validação: 0.0001168036469607614
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 964]
# Erro de Treinamento: 0.011784670067754632
# Erro de Validação: 0.00012010609498247504
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 965]
# Erro de Treinamento: 0.012018894718494266
# Erro de Validação: 9.641900396673009e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 966]
# Erro de Treinamento: 0.01116388486843789
# Erro de Validação: 8.893070480553433e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 967]
# Erro de Treinamento: 0.01755661230708938
# Erro de Validação: 9.473636600887403e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 968]
# Erro de Treinamento: 0.010890563844441203
# Erro de Validação: 0.00013659342948812991
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 969]
# Erro de Treinamento: 0.01737531996332109
# Erro de Validação: 8.440699457423761e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 970]
# Erro de Treinamento: 0.009586509286236833
# Erro de Validação: 6.0961596318520606e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 971]
# Erro de Treinamento: 0.00954019054188393
# Erro de Validação: 5.660007809638046e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 972]
# Erro de Treinamento: 0.008381707781154546
# Erro de Validação: 5.5427022743970156e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 973]
# Erro de Treinamento: 0.010405887733213603
# Erro de Validação: 4.597243605530821e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 974]
# Erro de Treinamento: 0.009069423776963959
# Erro de Validação: 4.365807035355829e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 975]
# Erro de Treinamento: 0.007346347334532766
# Erro de Validação: 3.981433837907389e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 976]
# Erro de Treinamento: 0.011848570487927645
# Erro de Validação: 4.0767514292383566e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 977]
# Erro de Treinamento: 0.0065952067998296116
# Erro de Validação: 5.763898298027925e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 978]
# Erro de Treinamento: 0.019095362396910787
# Erro de Validação: 3.639725400716998e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 979]
# Erro de Treinamento: 0.01576204331649933
# Erro de Validação: 4.467140752240084e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 980]
# Erro de Treinamento: 0.024633302908114274
# Erro de Validação: 5.064768993179314e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 981]
# Erro de Treinamento: 0.013349749991903082
# Erro de Validação: 4.390469621284865e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 982]
# Erro de Treinamento: 0.011638696040790819
# Erro de Validação: 3.3496693504275754e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 983]
# Erro de Treinamento: 0.03341461128729861
# Erro de Validação: 3.436042970861308e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 984]
# Erro de Treinamento: 0.029726157089726257
# Erro de Validação: 6.160817429190502e-05
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 985]
# Erro de Treinamento: 0.014957506267819554
# Erro de Validação: 3.47581080859527e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 986]
# Erro de Treinamento: 0.01860227162251249
# Erro de Validação: 2.9811402782797813e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 987]
# Erro de Treinamento: 0.010093254866660573
# Erro de Validação: 3.766743611777201e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 988]
# Erro de Treinamento: 0.020498355388554046
# Erro de Validação: 3.040741830773186e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 989]
# Erro de Treinamento: 0.019730326253920794
# Erro de Validação: 4.325082045397721e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 990]
# Erro de Treinamento: 0.02584675172693096
# Erro de Validação: 3.4400003642076626e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 991]
# Erro de Treinamento: 0.023714289933195687
# Erro de Validação: 0.0001226643071277067
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 992]
# Erro de Treinamento: 0.038447769577032886
# Erro de Validação: 3.308937812107615e-05
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 993]
# Erro de Treinamento: 0.033290799576207064
# Erro de Validação: 4.9955346185015514e-05
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 994]
# Erro de Treinamento: 0.033192586688528536
# Erro de Validação: 0.00013562939420808107
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 995]
# Erro de Treinamento: 0.04759380445830175
# Erro de Validação: 4.4887168769491836e-05
# Acurácia de Treinamento: 0.9722222089767456
# Acurácia de Validação: 1.0
#
# Epóca [: 996]
# Erro de Treinamento: 0.004712006033514626
# Erro de Validação: 3.5940138332080096e-05
# Acurácia de Treinamento: 1.0
# Acurácia de Validação: 1.0
#
# Epóca [: 997]
# Erro de Treinamento: 0.033788148226449266
# Erro de Validação: 3.1500043405685574e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0
#
# Epóca [: 998]
# Erro de Treinamento: 0.02097243747994071
# Erro de Validação: 0.00017895601922646165
# Acurácia de Treinamento: 0.9907407164573669
# Acurácia de Validação: 1.0
#
# Epóca [: 999]
# Erro de Treinamento: 0.03823535035189707
# Erro de Validação: 3.482774263829924e-05
# Acurácia de Treinamento: 0.9814814925193787
# Acurácia de Validação: 1.0

# %% [markdown]
# ## Métricas e resultados
# - Plotando as curvas de perda para treino e validação

# %%
# Criando os graficos
plt.plot(train_loss_all_epoch, label='Treino')
plt.plot(val_loss_all_epoch, label='Validação')

# Adicionando título e rótulos aos eixos
plt.title('Curva de Perda por Época', fontsize=14)
plt.xlabel('Épocas', fontsize=12)
plt.ylabel('Perda (Loss)', fontsize=12)

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True, linestyle='--', alpha=0.7)  # Adicionando grade
plt.tight_layout()  # Ajuste para não cortar o gráfico
plt.show()

# %% [markdown]
# - Plotando as curvas de acuracia para treino e validação

# %%
# Criando os graficos
plt.plot(train_accuracy_all_epoch, label='Treino')
plt.plot(val_accuracy_all_epoch, label='Validação')

# Adicionando título e rótulos aos eixos
plt.title('Curva de Acurácia por Época', fontsize=14)
plt.xlabel('Épocas', fontsize=12)
plt.ylabel('Acurácia (accuracy)', fontsize=12)

# Adicionando legenda
plt.legend()

# Exibindo o gráfico
plt.grid(True, linestyle='--', alpha=0.7)  # Adicionando grade
plt.tight_layout()  # Ajuste para não cortar o gráfico
plt.show()

# %% [markdown]
# - Plotando a matriz de confusão

# %%
# Montando a matriz
net.train(False)
for data in data_test:
    x_test, y_test = data
    x_test = x_test.to(torch.float32)
    y_pred = net(x_test)
    y_pred = torch.Tensor.argmax(y_pred, dim=1)
    cm = confusion_matrix(y_test, y_pred, labels=range(3))

# Exibindo a matriz de confusão graficamente
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['sedosa', 'versicolor', 'virginica'])
fig, ax = plt.subplots(figsize=(4, 4))
disp.plot(ax=ax, cmap='Blues', colorbar=False)

# Melhorando o gráfico
ax.set_title('Matriz de Confusão para Dados de Treino', fontsize=14)
ax.set_xlabel('Classe Predita', fontsize=12)
ax.set_ylabel('Classe Verdadeira', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# - Exibindo métricas de Classificação

# %%
# Calculando e imprimindo o relatório de classificação
print(classification_report(y_test, y_pred, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       0.91      0.91      0.91        11
#            2       0.90      0.90      0.90        10
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.94      0.94        30
# weighted avg       0.93      0.93      0.93        30
