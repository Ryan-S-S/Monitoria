# %% [markdown]
# <a href="https://colab.research.google.com/github/Ryan-S-S/Monitoria/blob/main/T%C3%A9cnicas%20de%20Aprendizagem%20Diversas/Redes%20Convolucionais/CIFAR%2010/CIFAR10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR 10 - AlexNet

# %%
# Importações
import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision.transforms as transforms
from torchvision.datasets import CIFAR10

import numpy as np

import random
import time

# %%
# Definição da semente aleatória para que todos os experimentos possam ser reproduzidos.

## Configurações
# Hyperparameters
RANDOM_SEED = 1
LEARNING_RATE = 0.0001
BATCH_SIZE = 256
NUM_EPOCHS = 40

# Architecture
NUM_CLASSES = 10

# Other
DEVICE = "cuda:0"

SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
# Variveis Globais
DATA_DIR = './'
CATEGORIES = ['Avião', 'Automóvel','Passáro','Gato','Cervo','Cachorro', 'Sapo', 'Cavalo', 'Navio', 'Caminhão']

# %%
# Dados
cifar10_train = CIFAR10(DATA_DIR, train=True, download=True)
cifar10_test = CIFAR10(DATA_DIR, train=False, download=True)
# Out:
# 100%|██████████| 170M/170M [00:20<00:00, 8.49MB/s]

# %%
# Visualização da Quantidade de dados
print(f"Quantidade de Dados para Treinamento : {len(cifar10_train)}")
print(f"Quantidade de Dados para Teste : {len(cifar10_test)}" )
# Out:
# Quantidade de Dados para Treinamento : 50000
# Quantidade de Dados para Teste : 10000

# %%
# Preparando a Transformação e Normalização dos dados
import torchvision.transforms as tt

prep_transform = transforms.Compose([transforms.Resize((70, 70)),
                                       transforms.RandomCrop((64, 64)),
                                       #transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616)),
                                       transforms.ToTensor()])

# %%
# Normalizando e Tensor dos dados

train_size = int(len(cifar10_train) * 0.8) # 80% Dados de Treinamento
valid_size = len(cifar10_train) - train_size # 20% Dados de Validação

tensor_train = CIFAR10(DATA_DIR, train=True, download=False, transform=prep_transform)
tensor_test = CIFAR10(DATA_DIR, train=False, download=False, transform=prep_transform)
tensor_train, tensor_validation = torch.utils.data.random_split(tensor_train, [train_size, valid_size])

# %%
from torch.utils.data import DataLoader
train_loader = DataLoader(tensor_train, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(tensor_test, batch_size=BATCH_SIZE, shuffle=True)
validation_loader=DataLoader(tensor_validation, batch_size=BATCH_SIZE, shuffle=True)

# %%
# Dados sobre imagens
print('Conjunto de Treinamento:\n')
for images, labels in train_loader:
    print('Dimensões do lote de imagens:', images.size())
    print('Dimensões do lote de rotulos:', labels.size())
    print(labels[:10])
    break

print('\nConjunto de Validação:\n')
for images, labels in validation_loader:
    print('Dimensões do lote de imagens:', images.size())
    print('Dimensões do lote de rotulos:', labels.size())
    print(labels[:10])
    break

print('\nConjunto de Teste :\n')
for images, labels in train_loader:
    print('Dimensões do lote de imagens:', images.size())
    print('Dimensões do lote de rotulos:', labels.size())
    print(labels[:10])
    break
# Out:
# Conjunto de Treinamento:
#
# Dimensões do lote de imagens: torch.Size([256, 3, 64, 64])
# Dimensões do lote de rotulos: torch.Size([256])
# tensor([9, 1, 5, 5, 0, 5, 1, 0, 4, 2])
#
# Conjunto de Validação:
#
# Dimensões do lote de imagens: torch.Size([256, 3, 64, 64])
# Dimensões do lote de rotulos: torch.Size([256])
# tensor([4, 6, 3, 0, 5, 1, 6, 7, 0, 3])
#
# Conjunto de Teste :
#
# Dimensões do lote de imagens: torch.Size([256, 3, 64, 64])
# Dimensões do lote de rotulos: torch.Size([256])
# tensor([4, 2, 2, 4, 3, 2, 2, 7, 4, 2])

# %%
# Modelo da Rede
class AlexNet(nn.Module):
    def __init__(self, num_classes):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),

            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),

            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),

            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),

            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = x.view(x.size(0), 256 * 6 * 6)
        logits = self.classifier(x)
        probas = F.softmax(logits, dim=1)
        return logits

# %%
torch.manual_seed(RANDOM_SEED)

model = AlexNet(NUM_CLASSES)
model.to(DEVICE)
lossfunc = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
import numpy as np
from itertools import product

# Função de Acurácia e Erro

def compute_accuracy(model, data_loader, device):
    model.eval()
    with torch.no_grad():
        correct_pred, num_examples = 0, 0
        for i, (features, targets) in enumerate(data_loader):

            features = features.to(device)
            targets = targets.to(device)

            logits = model(features)
            if isinstance(logits, torch.distributed.rpc.api.RRef):
                logits = logits.local_value()
            _, predicted_labels = torch.max(logits, 1)
            num_examples += targets.size(0)
            correct_pred += (predicted_labels == targets).sum()
    return correct_pred.float()/num_examples * 100


def compute_epoch_loss(model, data_loader, device):
    model.eval()
    curr_loss, num_examples = 0., 0
    with torch.no_grad():
        for features, targets in data_loader:
            features = features.to(device)
            targets = targets.to(device)
            logits = model(features)
            if isinstance(logits, torch.distributed.rpc.api.RRef):
                logits = logits.local_value()
            loss = F.cross_entropy(logits, targets, reduction='sum')
            num_examples += targets.size(0)
            curr_loss += loss

        curr_loss = curr_loss / num_examples
        return curr_loss

# %%
def train_network(num_epochs, model, optimizer, device,
                               train_loader, valid_loader=None,
                               loss_fn=None, logging_interval=100,
                               skip_epoch_stats=False):

    log_dict = {'train_loss_per_batch': [],
                'train_acc_per_epoch': [],
                'train_loss_per_epoch': [],
                'valid_acc_per_epoch': [],
                'valid_loss_per_epoch': []}

    if loss_fn is None:
        loss_fn = F.cross_entropy

    start_time = time.time()
    for epoch in range(num_epochs):

        model.train()
        for batch_idx, (features, targets) in enumerate(train_loader):

            features = features.to(device)
            targets = targets.to(device)

            # FORWARD AND BACK PROP
            logits = model(features)
            if isinstance(logits, torch.distributed.rpc.api.RRef):
                logits = logits.local_value()
            loss = loss_fn(logits, targets)
            optimizer.zero_grad()

            loss.backward()

            # UPDATE MODEL PARAMETERS
            optimizer.step()

            # LOGGING
            log_dict['train_loss_per_batch'].append(loss.item())

            if not batch_idx % logging_interval:
                print('Epoca: %03d/%03d | Lote %04d/%04d | Taxa de Erro: %.4f'
                      % (epoch+1, num_epochs, batch_idx,
                          len(train_loader), loss))

        if not skip_epoch_stats:
            model.eval()

            with torch.set_grad_enabled(False):  # save memory during inference

                train_acc = compute_accuracy(model, train_loader, device)
                train_loss = compute_epoch_loss(model, train_loader, device)
                print('***Epoca: %03d/%03d | Treinamento. Acc.: %.3f%% | Taxa de Erro: %.3f' % (
                      epoch+1, num_epochs, train_acc, train_loss))
                log_dict['train_loss_per_epoch'].append(train_loss.item())
                log_dict['train_acc_per_epoch'].append(train_acc.item())

                if valid_loader is not None:
                    valid_acc = compute_accuracy(model, valid_loader, device)
                    valid_loss = compute_epoch_loss(model, valid_loader, device)
                    print('***Epoca: %03d/%03d | Validação. Acc.: %.3f%% | Taxa de Erro: %.3f' % (
                          epoch+1, num_epochs, valid_acc, valid_loss))
                    log_dict['valid_loss_per_epoch'].append(valid_loss.item())
                    log_dict['valid_acc_per_epoch'].append(valid_acc.item())

        print('Tempo Decorrido: %.2f min' % ((time.time() - start_time)/60))

    print('Tempo de Treinamento Total: %.2f min' % ((time.time() - start_time)/60))

    return log_dict

# %%
log_dict = train_network(NUM_EPOCHS, model, optimizer, DEVICE, train_loader, validation_loader, lossfunc, logging_interval=50)
# Out:
# /tmp/ipython-input-1987918842.py:40: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   print('Epoca: %03d/%03d | Lote %04d/%04d | Taxa de Erro: %.4f'
# Epoca: 001/040 | Lote 0000/0157 | Taxa de Erro: 2.3031
# Epoca: 001/040 | Lote 0050/0157 | Taxa de Erro: 2.0061
# Epoca: 001/040 | Lote 0100/0157 | Taxa de Erro: 1.8204
# Epoca: 001/040 | Lote 0150/0157 | Taxa de Erro: 1.7182
# ***Epoca: 001/040 | Treinamento. Acc.: 32.712% | Taxa de Erro: 1.722
# ***Epoca: 001/040 | Validação. Acc.: 32.290% | Taxa de Erro: 1.727
# Tempo Decorrido: 0.93 min
# Epoca: 002/040 | Lote 0000/0157 | Taxa de Erro: 1.7060
# Epoca: 002/040 | Lote 0050/0157 | Taxa de Erro: 1.6823
# Epoca: 002/040 | Lote 0100/0157 | Taxa de Erro: 1.6913
# Epoca: 002/040 | Lote 0150/0157 | Taxa de Erro: 1.6213
# ***Epoca: 002/040 | Treinamento. Acc.: 39.115% | Taxa de Erro: 1.602
# ***Epoca: 002/040 | Validação. Acc.: 39.250% | Taxa de Erro: 1.619
# Tempo Decorrido: 1.81 min
# Epoca: 003/040 | Lote 0000/0157 | Taxa de Erro: 1.5858
# Epoca: 003/040 | Lote 0050/0157 | Taxa de Erro: 1.4216
# Epoca: 003/040 | Lote 0100/0157 | Taxa de Erro: 1.5737
# Epoca: 003/040 | Lote 0150/0157 | Taxa de Erro: 1.4724
# ***Epoca: 003/040 | Treinamento. Acc.: 49.775% | Taxa de Erro: 1.341
# ***Epoca: 003/040 | Validação. Acc.: 48.060% | Taxa de Erro: 1.373
# Tempo Decorrido: 2.70 min
# Epoca: 004/040 | Lote 0000/0157 | Taxa de Erro: 1.3383
# Epoca: 004/040 | Lote 0050/0157 | Taxa de Erro: 1.4069
# Epoca: 004/040 | Lote 0100/0157 | Taxa de Erro: 1.3630
# Epoca: 004/040 | Lote 0150/0157 | Taxa de Erro: 1.3636
# ***Epoca: 004/040 | Treinamento. Acc.: 53.890% | Taxa de Erro: 1.252
# ***Epoca: 004/040 | Validação. Acc.: 52.580% | Taxa de Erro: 1.293
# Tempo Decorrido: 3.58 min
# Epoca: 005/040 | Lote 0000/0157 | Taxa de Erro: 1.2788
# Epoca: 005/040 | Lote 0050/0157 | Taxa de Erro: 1.3503
# Epoca: 005/040 | Lote 0100/0157 | Taxa de Erro: 1.3063
# Epoca: 005/040 | Lote 0150/0157 | Taxa de Erro: 1.1437
# ***Epoca: 005/040 | Treinamento. Acc.: 57.547% | Taxa de Erro: 1.156
# ***Epoca: 005/040 | Validação. Acc.: 55.460% | Taxa de Erro: 1.211
# Tempo Decorrido: 4.46 min
# Epoca: 006/040 | Lote 0000/0157 | Taxa de Erro: 1.1024
# Epoca: 006/040 | Lote 0050/0157 | Taxa de Erro: 1.1615
# Epoca: 006/040 | Lote 0100/0157 | Taxa de Erro: 1.1469
# Epoca: 006/040 | Lote 0150/0157 | Taxa de Erro: 1.1403
# ***Epoca: 006/040 | Treinamento. Acc.: 57.818% | Taxa de Erro: 1.148
# ***Epoca: 006/040 | Validação. Acc.: 56.230% | Taxa de Erro: 1.211
# Tempo Decorrido: 5.35 min
# Epoca: 007/040 | Lote 0000/0157 | Taxa de Erro: 1.1485
# Epoca: 007/040 | Lote 0050/0157 | Taxa de Erro: 1.1043
# Epoca: 007/040 | Lote 0100/0157 | Taxa de Erro: 1.0252
# Epoca: 007/040 | Lote 0150/0157 | Taxa de Erro: 1.0810
# ***Epoca: 007/040 | Treinamento. Acc.: 62.985% | Taxa de Erro: 1.021
# ***Epoca: 007/040 | Validação. Acc.: 59.490% | Taxa de Erro: 1.113
# Tempo Decorrido: 6.23 min
# Epoca: 008/040 | Lote 0000/0157 | Taxa de Erro: 1.0794
# Epoca: 008/040 | Lote 0050/0157 | Taxa de Erro: 1.0474
# Epoca: 008/040 | Lote 0100/0157 | Taxa de Erro: 0.9468
# Epoca: 008/040 | Lote 0150/0157 | Taxa de Erro: 1.1108
# ***Epoca: 008/040 | Treinamento. Acc.: 64.312% | Taxa de Erro: 0.995
# ***Epoca: 008/040 | Validação. Acc.: 60.980% | Taxa de Erro: 1.108
# Tempo Decorrido: 7.12 min
# Epoca: 009/040 | Lote 0000/0157 | Taxa de Erro: 0.9513
# Epoca: 009/040 | Lote 0050/0157 | Taxa de Erro: 1.1153
# Epoca: 009/040 | Lote 0100/0157 | Taxa de Erro: 1.1075
# Epoca: 009/040 | Lote 0150/0157 | Taxa de Erro: 0.9697
# ***Epoca: 009/040 | Treinamento. Acc.: 66.877% | Taxa de Erro: 0.912
# ***Epoca: 009/040 | Validação. Acc.: 63.200% | Taxa de Erro: 1.055
# Tempo Decorrido: 8.01 min
# Epoca: 010/040 | Lote 0000/0157 | Taxa de Erro: 0.8834
# Epoca: 010/040 | Lote 0050/0157 | Taxa de Erro: 0.9743
# Epoca: 010/040 | Lote 0100/0157 | Taxa de Erro: 0.8889
# Epoca: 010/040 | Lote 0150/0157 | Taxa de Erro: 1.0048
# ***Epoca: 010/040 | Treinamento. Acc.: 68.975% | Taxa de Erro: 0.864
# ***Epoca: 010/040 | Validação. Acc.: 64.680% | Taxa de Erro: 1.017
# Tempo Decorrido: 8.88 min
# Epoca: 011/040 | Lote 0000/0157 | Taxa de Erro: 0.8404
# Epoca: 011/040 | Lote 0050/0157 | Taxa de Erro: 0.8529
# Epoca: 011/040 | Lote 0100/0157 | Taxa de Erro: 0.8740
# Epoca: 011/040 | Lote 0150/0157 | Taxa de Erro: 0.8764
# ***Epoca: 011/040 | Treinamento. Acc.: 68.980% | Taxa de Erro: 0.863
# ***Epoca: 011/040 | Validação. Acc.: 63.310% | Taxa de Erro: 1.046
# Tempo Decorrido: 9.78 min
# Epoca: 012/040 | Lote 0000/0157 | Taxa de Erro: 0.7249
# Epoca: 012/040 | Lote 0050/0157 | Taxa de Erro: 0.7544
# Epoca: 012/040 | Lote 0100/0157 | Taxa de Erro: 0.8682
# Epoca: 012/040 | Lote 0150/0157 | Taxa de Erro: 0.8302
# ***Epoca: 012/040 | Treinamento. Acc.: 71.210% | Taxa de Erro: 0.807
# ***Epoca: 012/040 | Validação. Acc.: 64.440% | Taxa de Erro: 1.029
# Tempo Decorrido: 10.66 min
# Epoca: 013/040 | Lote 0000/0157 | Taxa de Erro: 0.8744
# Epoca: 013/040 | Lote 0050/0157 | Taxa de Erro: 0.7966
# Epoca: 013/040 | Lote 0100/0157 | Taxa de Erro: 0.8334
# Epoca: 013/040 | Lote 0150/0157 | Taxa de Erro: 0.8371
# ***Epoca: 013/040 | Treinamento. Acc.: 75.308% | Taxa de Erro: 0.694
# ***Epoca: 013/040 | Validação. Acc.: 67.770% | Taxa de Erro: 0.944
# Tempo Decorrido: 11.55 min
# Epoca: 014/040 | Lote 0000/0157 | Taxa de Erro: 0.7771
# Epoca: 014/040 | Lote 0050/0157 | Taxa de Erro: 0.7687
# Epoca: 014/040 | Lote 0100/0157 | Taxa de Erro: 0.6957
# Epoca: 014/040 | Lote 0150/0157 | Taxa de Erro: 0.7869
# ***Epoca: 014/040 | Treinamento. Acc.: 76.015% | Taxa de Erro: 0.671
# ***Epoca: 014/040 | Validação. Acc.: 67.320% | Taxa de Erro: 0.951
# Tempo Decorrido: 12.43 min
# Epoca: 015/040 | Lote 0000/0157 | Taxa de Erro: 0.8636
# Epoca: 015/040 | Lote 0050/0157 | Taxa de Erro: 0.6011
# Epoca: 015/040 | Lote 0100/0157 | Taxa de Erro: 0.7338
# Epoca: 015/040 | Lote 0150/0157 | Taxa de Erro: 0.6672
# ***Epoca: 015/040 | Treinamento. Acc.: 78.047% | Taxa de Erro: 0.626
# ***Epoca: 015/040 | Validação. Acc.: 68.630% | Taxa de Erro: 0.935
# Tempo Decorrido: 13.32 min
# Epoca: 016/040 | Lote 0000/0157 | Taxa de Erro: 0.5248
# Epoca: 016/040 | Lote 0050/0157 | Taxa de Erro: 0.6122
# Epoca: 016/040 | Lote 0100/0157 | Taxa de Erro: 0.6197
# Epoca: 016/040 | Lote 0150/0157 | Taxa de Erro: 0.6659
# ***Epoca: 016/040 | Treinamento. Acc.: 78.643% | Taxa de Erro: 0.603
# ***Epoca: 016/040 | Validação. Acc.: 68.610% | Taxa de Erro: 0.947
# Tempo Decorrido: 14.20 min
# Epoca: 017/040 | Lote 0000/0157 | Taxa de Erro: 0.5629
# Epoca: 017/040 | Lote 0050/0157 | Taxa de Erro: 0.7052
# Epoca: 017/040 | Lote 0100/0157 | Taxa de Erro: 0.6844
# Epoca: 017/040 | Lote 0150/0157 | Taxa de Erro: 0.8480
# ***Epoca: 017/040 | Treinamento. Acc.: 80.572% | Taxa de Erro: 0.550
# ***Epoca: 017/040 | Validação. Acc.: 69.720% | Taxa de Erro: 0.919
# Tempo Decorrido: 15.09 min
# Epoca: 018/040 | Lote 0000/0157 | Taxa de Erro: 0.5867
# Epoca: 018/040 | Lote 0050/0157 | Taxa de Erro: 0.5540
# Epoca: 018/040 | Lote 0100/0157 | Taxa de Erro: 0.5575
# Epoca: 018/040 | Lote 0150/0157 | Taxa de Erro: 0.5535
# ***Epoca: 018/040 | Treinamento. Acc.: 78.437% | Taxa de Erro: 0.608
# ***Epoca: 018/040 | Validação. Acc.: 67.210% | Taxa de Erro: 1.022
# Tempo Decorrido: 15.98 min
# Epoca: 019/040 | Lote 0000/0157 | Taxa de Erro: 0.5999
# Epoca: 019/040 | Lote 0050/0157 | Taxa de Erro: 0.4320
# Epoca: 019/040 | Lote 0100/0157 | Taxa de Erro: 0.5719
# Epoca: 019/040 | Lote 0150/0157 | Taxa de Erro: 0.5367
# ***Epoca: 019/040 | Treinamento. Acc.: 84.082% | Taxa de Erro: 0.453
# ***Epoca: 019/040 | Validação. Acc.: 70.080% | Taxa de Erro: 0.912
# Tempo Decorrido: 16.86 min
# Epoca: 020/040 | Lote 0000/0157 | Taxa de Erro: 0.4463
# Epoca: 020/040 | Lote 0050/0157 | Taxa de Erro: 0.4887
# Epoca: 020/040 | Lote 0100/0157 | Taxa de Erro: 0.6100
# Epoca: 020/040 | Lote 0150/0157 | Taxa de Erro: 0.4357
# ***Epoca: 020/040 | Treinamento. Acc.: 83.620% | Taxa de Erro: 0.471
# ***Epoca: 020/040 | Validação. Acc.: 69.630% | Taxa de Erro: 0.990
# Tempo Decorrido: 17.75 min
# Epoca: 021/040 | Lote 0000/0157 | Taxa de Erro: 0.4860
# Epoca: 021/040 | Lote 0050/0157 | Taxa de Erro: 0.5911
# Epoca: 021/040 | Lote 0100/0157 | Taxa de Erro: 0.5945
# Epoca: 021/040 | Lote 0150/0157 | Taxa de Erro: 0.5359
# ***Epoca: 021/040 | Treinamento. Acc.: 85.973% | Taxa de Erro: 0.404
# ***Epoca: 021/040 | Validação. Acc.: 69.050% | Taxa de Erro: 0.959
# Tempo Decorrido: 18.63 min
# Epoca: 022/040 | Lote 0000/0157 | Taxa de Erro: 0.5078
# Epoca: 022/040 | Lote 0050/0157 | Taxa de Erro: 0.4314
# Epoca: 022/040 | Lote 0100/0157 | Taxa de Erro: 0.4907
# Epoca: 022/040 | Lote 0150/0157 | Taxa de Erro: 0.3855
# ***Epoca: 022/040 | Treinamento. Acc.: 85.847% | Taxa de Erro: 0.407
# ***Epoca: 022/040 | Validação. Acc.: 69.850% | Taxa de Erro: 1.007
# Tempo Decorrido: 19.51 min
# Epoca: 023/040 | Lote 0000/0157 | Taxa de Erro: 0.4533
# Epoca: 023/040 | Lote 0050/0157 | Taxa de Erro: 0.3389
# Epoca: 023/040 | Lote 0100/0157 | Taxa de Erro: 0.3295
# Epoca: 023/040 | Lote 0150/0157 | Taxa de Erro: 0.4577
# ***Epoca: 023/040 | Treinamento. Acc.: 86.205% | Taxa de Erro: 0.389
# ***Epoca: 023/040 | Validação. Acc.: 68.820% | Taxa de Erro: 1.015
# Tempo Decorrido: 20.40 min
# Epoca: 024/040 | Lote 0000/0157 | Taxa de Erro: 0.3380
# Epoca: 024/040 | Lote 0050/0157 | Taxa de Erro: 0.4220
# Epoca: 024/040 | Lote 0100/0157 | Taxa de Erro: 0.3826
# Epoca: 024/040 | Lote 0150/0157 | Taxa de Erro: 0.2724
# ***Epoca: 024/040 | Treinamento. Acc.: 89.037% | Taxa de Erro: 0.317
# ***Epoca: 024/040 | Validação. Acc.: 70.430% | Taxa de Erro: 0.997
# Tempo Decorrido: 21.28 min
# Epoca: 025/040 | Lote 0000/0157 | Taxa de Erro: 0.2506
# Epoca: 025/040 | Lote 0050/0157 | Taxa de Erro: 0.3943
# Epoca: 025/040 | Lote 0100/0157 | Taxa de Erro: 0.3358
# Epoca: 025/040 | Lote 0150/0157 | Taxa de Erro: 0.4569
# ***Epoca: 025/040 | Treinamento. Acc.: 90.052% | Taxa de Erro: 0.288
# ***Epoca: 025/040 | Validação. Acc.: 70.410% | Taxa de Erro: 1.006
# Tempo Decorrido: 22.17 min
# Epoca: 026/040 | Lote 0000/0157 | Taxa de Erro: 0.3147
# Epoca: 026/040 | Lote 0050/0157 | Taxa de Erro: 0.2975
# Epoca: 026/040 | Lote 0100/0157 | Taxa de Erro: 0.2853
# Epoca: 026/040 | Lote 0150/0157 | Taxa de Erro: 0.3270
# ***Epoca: 026/040 | Treinamento. Acc.: 90.893% | Taxa de Erro: 0.262
# ***Epoca: 026/040 | Validação. Acc.: 70.590% | Taxa de Erro: 1.076
# Tempo Decorrido: 23.05 min
# Epoca: 027/040 | Lote 0000/0157 | Taxa de Erro: 0.3226
# Epoca: 027/040 | Lote 0050/0157 | Taxa de Erro: 0.3426
# Epoca: 027/040 | Lote 0100/0157 | Taxa de Erro: 0.2645
# Epoca: 027/040 | Lote 0150/0157 | Taxa de Erro: 0.4015
# ***Epoca: 027/040 | Treinamento. Acc.: 91.973% | Taxa de Erro: 0.236
# ***Epoca: 027/040 | Validação. Acc.: 71.230% | Taxa de Erro: 1.029
# Tempo Decorrido: 23.94 min
# Epoca: 028/040 | Lote 0000/0157 | Taxa de Erro: 0.2468
# Epoca: 028/040 | Lote 0050/0157 | Taxa de Erro: 0.3419
# Epoca: 028/040 | Lote 0100/0157 | Taxa de Erro: 0.3014
# Epoca: 028/040 | Lote 0150/0157 | Taxa de Erro: 0.2874
# ***Epoca: 028/040 | Treinamento. Acc.: 91.887% | Taxa de Erro: 0.231
# ***Epoca: 028/040 | Validação. Acc.: 70.400% | Taxa de Erro: 1.113
# Tempo Decorrido: 24.83 min
# Epoca: 029/040 | Lote 0000/0157 | Taxa de Erro: 0.2604
# Epoca: 029/040 | Lote 0050/0157 | Taxa de Erro: 0.1897
# Epoca: 029/040 | Lote 0100/0157 | Taxa de Erro: 0.3006
# Epoca: 029/040 | Lote 0150/0157 | Taxa de Erro: 0.2362
# ***Epoca: 029/040 | Treinamento. Acc.: 92.467% | Taxa de Erro: 0.214
# ***Epoca: 029/040 | Validação. Acc.: 69.950% | Taxa de Erro: 1.133
# Tempo Decorrido: 25.71 min
# Epoca: 030/040 | Lote 0000/0157 | Taxa de Erro: 0.1905
# Epoca: 030/040 | Lote 0050/0157 | Taxa de Erro: 0.2524
# Epoca: 030/040 | Lote 0100/0157 | Taxa de Erro: 0.2166
# Epoca: 030/040 | Lote 0150/0157 | Taxa de Erro: 0.2224
# ***Epoca: 030/040 | Treinamento. Acc.: 93.852% | Taxa de Erro: 0.176
# ***Epoca: 030/040 | Validação. Acc.: 70.790% | Taxa de Erro: 1.159
# Tempo Decorrido: 26.59 min
# Epoca: 031/040 | Lote 0000/0157 | Taxa de Erro: 0.1618
# Epoca: 031/040 | Lote 0050/0157 | Taxa de Erro: 0.2124
# Epoca: 031/040 | Lote 0100/0157 | Taxa de Erro: 0.2356
# Epoca: 031/040 | Lote 0150/0157 | Taxa de Erro: 0.2643
# ***Epoca: 031/040 | Treinamento. Acc.: 92.850% | Taxa de Erro: 0.208
# ***Epoca: 031/040 | Validação. Acc.: 70.020% | Taxa de Erro: 1.198
# Tempo Decorrido: 27.47 min
# Epoca: 032/040 | Lote 0000/0157 | Taxa de Erro: 0.1689
# Epoca: 032/040 | Lote 0050/0157 | Taxa de Erro: 0.2073
# Epoca: 032/040 | Lote 0100/0157 | Taxa de Erro: 0.2223
# Epoca: 032/040 | Lote 0150/0157 | Taxa de Erro: 0.1783
# ***Epoca: 032/040 | Treinamento. Acc.: 93.820% | Taxa de Erro: 0.174
# ***Epoca: 032/040 | Validação. Acc.: 70.350% | Taxa de Erro: 1.184
# Tempo Decorrido: 28.36 min
# Epoca: 033/040 | Lote 0000/0157 | Taxa de Erro: 0.1680
# Epoca: 033/040 | Lote 0050/0157 | Taxa de Erro: 0.1257
# Epoca: 033/040 | Lote 0100/0157 | Taxa de Erro: 0.1952
# Epoca: 033/040 | Lote 0150/0157 | Taxa de Erro: 0.1905
# ***Epoca: 033/040 | Treinamento. Acc.: 93.345% | Taxa de Erro: 0.188
# ***Epoca: 033/040 | Validação. Acc.: 70.040% | Taxa de Erro: 1.266
# Tempo Decorrido: 29.23 min
# Epoca: 034/040 | Lote 0000/0157 | Taxa de Erro: 0.2030
# Epoca: 034/040 | Lote 0050/0157 | Taxa de Erro: 0.2177
# Epoca: 034/040 | Lote 0100/0157 | Taxa de Erro: 0.1445
# Epoca: 034/040 | Lote 0150/0157 | Taxa de Erro: 0.1609
# ***Epoca: 034/040 | Treinamento. Acc.: 94.295% | Taxa de Erro: 0.161
# ***Epoca: 034/040 | Validação. Acc.: 70.250% | Taxa de Erro: 1.282
# Tempo Decorrido: 30.11 min
# Epoca: 035/040 | Lote 0000/0157 | Taxa de Erro: 0.1119
# Epoca: 035/040 | Lote 0050/0157 | Taxa de Erro: 0.1566
# Epoca: 035/040 | Lote 0100/0157 | Taxa de Erro: 0.2043
# Epoca: 035/040 | Lote 0150/0157 | Taxa de Erro: 0.1543
# ***Epoca: 035/040 | Treinamento. Acc.: 94.320% | Taxa de Erro: 0.158
# ***Epoca: 035/040 | Validação. Acc.: 69.830% | Taxa de Erro: 1.306
# Tempo Decorrido: 30.99 min
# Epoca: 036/040 | Lote 0000/0157 | Taxa de Erro: 0.1668
# Epoca: 036/040 | Lote 0050/0157 | Taxa de Erro: 0.2263
# Epoca: 036/040 | Lote 0100/0157 | Taxa de Erro: 0.1397
# Epoca: 036/040 | Lote 0150/0157 | Taxa de Erro: 0.1980
# ***Epoca: 036/040 | Treinamento. Acc.: 96.345% | Taxa de Erro: 0.110
# ***Epoca: 036/040 | Validação. Acc.: 70.710% | Taxa de Erro: 1.278
# Tempo Decorrido: 31.87 min
# Epoca: 037/040 | Lote 0000/0157 | Taxa de Erro: 0.1059
# Epoca: 037/040 | Lote 0050/0157 | Taxa de Erro: 0.1447
# Epoca: 037/040 | Lote 0100/0157 | Taxa de Erro: 0.1715
# Epoca: 037/040 | Lote 0150/0157 | Taxa de Erro: 0.1208
# ***Epoca: 037/040 | Treinamento. Acc.: 96.327% | Taxa de Erro: 0.110
# ***Epoca: 037/040 | Validação. Acc.: 71.530% | Taxa de Erro: 1.338
# Tempo Decorrido: 32.75 min
# Epoca: 038/040 | Lote 0000/0157 | Taxa de Erro: 0.1361
# Epoca: 038/040 | Lote 0050/0157 | Taxa de Erro: 0.1492
# Epoca: 038/040 | Lote 0100/0157 | Taxa de Erro: 0.1863
# Epoca: 038/040 | Lote 0150/0157 | Taxa de Erro: 0.1327
# ***Epoca: 038/040 | Treinamento. Acc.: 96.607% | Taxa de Erro: 0.097
# ***Epoca: 038/040 | Validação. Acc.: 71.380% | Taxa de Erro: 1.307
# Tempo Decorrido: 33.63 min
# Epoca: 039/040 | Lote 0000/0157 | Taxa de Erro: 0.0974
# Epoca: 039/040 | Lote 0050/0157 | Taxa de Erro: 0.0511
# Epoca: 039/040 | Lote 0100/0157 | Taxa de Erro: 0.1128
# Epoca: 039/040 | Lote 0150/0157 | Taxa de Erro: 0.1595
# ***Epoca: 039/040 | Treinamento. Acc.: 96.893% | Taxa de Erro: 0.093
# ***Epoca: 039/040 | Validação. Acc.: 71.310% | Taxa de Erro: 1.321
# Tempo Decorrido: 34.50 min
# Epoca: 040/040 | Lote 0000/0157 | Taxa de Erro: 0.1040
# Epoca: 040/040 | Lote 0050/0157 | Taxa de Erro: 0.1343
# Epoca: 040/040 | Lote 0100/0157 | Taxa de Erro: 0.1149
# Epoca: 040/040 | Lote 0150/0157 | Taxa de Erro: 0.0764
# ***Epoca: 040/040 | Treinamento. Acc.: 97.152% | Taxa de Erro: 0.087
# ***Epoca: 040/040 | Validação. Acc.: 71.250% | Taxa de Erro: 1.388
# Tempo Decorrido: 35.38 min
# Tempo de Treinamento Total: 35.38 min

# %% [markdown]
# # Métricas de Avaliação

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(np.arange(1, NUM_EPOCHS+1), log_dict['train_acc_per_epoch'], label='Training')
plt.plot(np.arange(1, NUM_EPOCHS+1), log_dict['valid_acc_per_epoch'], label='Validation')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
with torch.set_grad_enabled(False):

    train_acc = compute_accuracy(model=model,
                                 data_loader=train_loader,
                                 device=DEVICE)

    test_acc = compute_accuracy(model=model,
                                data_loader=test_loader,
                                device=DEVICE)

    valid_acc = compute_accuracy(model=model,
                                 data_loader=validation_loader,
                                 device=DEVICE)


print(f'Treinamento ACC: {train_acc:.2f}%')
print(f'Validação ACC: {valid_acc:.2f}%')
print(f'Teste ACC: {test_acc:.2f}%')
# Out:
# Treinamento ACC: 97.15%
# Validação ACC: 70.90%
# Teste ACC: 71.64%

# %% [markdown]
# # Teste com uma Imagem

# %%
import sysconfig
from PIL import Image
img = Image.open('./Gato.jpeg')

# %%
img_tensor = prep_transform(img)

# %%
plt.imshow(img_tensor.permute(1,2, 0))

# %%
batch = img_tensor.unsqueeze(0).to(DEVICE)

# %%
import operator
output = model(batch)
logits = torch.nn.functional.softmax(output, dim=1) * 100
prob_dict = {}

for i, classname in enumerate(CATEGORIES):
  prob = logits[0][i].item()
  prob_dict[classname] = [prob]

result = max(prob_dict.items(), key=operator.itemgetter(1))
result
# Out:
# ('Gato', [69.82888793945312])
